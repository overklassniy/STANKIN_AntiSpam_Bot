# %% [markdown]
# # Дообучение RuBert для определения спам сообщений

# %% [markdown]
# ## Импорт необходимых библиотек

# %% [markdown]
# > Ячейки с установкой библиотек были приведены к типу `Raw`, чтобы они не выполнялись при автоматическом запуске всех ячеек.

# %% [raw]
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %% [raw]
# !pip install langdetect

# %%
from langdetect import detect  # для создания выборок сообщений на русском языке

# %% [raw]
# !pip install transformers[torch] datasets torch scikit-learn

# %%
import torch

# %%
from copy import deepcopy

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
from datasets import Dataset

# %%
from torch.utils.data import DataLoader

# %%
from transformers import TrainingArguments, Trainer

# %%
from transformers import pipeline

# %%
import sys
sys.path.append('../utils')
from preprocessing import preprocess_text

# %% [markdown]
# ## Чтение обработанного датасета

# %%
df = pd.read_csv('../data/preprocessed.csv', index_col=0)

# %%
df.head()
# Out:
#                                                 text  label  emojis  newlines  \
# 0  Добрый день! Отличается ли перечень необходимы...      0       0         0
# 1              Узбекистан. Рассматриваются обе формы      0       0         0
# 2  Здравствуйте, а как проходит поступление после...      0       0         0
# 3                          Спасибо большое за ответ!      0       0         0
# 4  Здравствуйте, а когда будет день открытых двер...      0       0         0
#
#    whitespaces  links  tags                                  text_preprocessed
# 0            0      0     0  добрый день отличается ли перечень необходимых...
# 1            0      0     0               узбекистан рассматриваются обе формы
# 2            0      0     0  здравствуйте а как проходит поступление после ...
# 3            0      0     0                           спасибо большое за ответ
# 4            0      0     0  здравствуйте а когда будет день открытых двере...

# %% [markdown]
# ### Датасет без обработки

# %%
only_text = deepcopy(df[['text', 'label']])

# %%
dataset = only_text.to_dict('records')

# %%
ru_dataset = []

# %%
for d in dataset:
    if not(1072 <= ord(d['text'][0].lower()) <= 1103):
        continue
    ru_dataset.append({"text": d['text'], "label": d['label']})

# %%
ru_dataset
# Out:
# [{'text': 'Добрый день! Отличается ли перечень необходимых документов для иностранных граждан?',
#   'label': 0},
#  {'text': 'Узбекистан. Рассматриваются обе формы', 'label': 0},
#  {'text': 'Здравствуйте, а как проходит поступление после колледжа? Внутренний экзамен или только ЕГЭ? И возможно ли всё ещё поступление сразу на второй курс?',
#   'label': 0},
#  {'text': 'Спасибо большое за ответ!', 'label': 0},
#  {'text': 'Здравствуйте, а когда будет день открытых дверей и во сколько?',
#   'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'Здравствуйте, необходимо для посещения дня открытым дверей где-то регистрироваться',
#   'label': 0},
#  {'text': 'Добрый день! Да, необходимо пройти быструю регистрацию на сайте https://info.stankin.ru/dod',
#   'label': 0},
#  {'text': 'Лучшая специальность! Жаль с моими баллами не пройти(', 'label': 0},
#  {'text': 'Было бы неплохо, если бы прикладывались ссылки для просмотра результатов экзаменов.)',
#   'label': 0},
#  {'text': 'Здравствуйте. Не смог найти списки поступающих на сайте. Ещё не опубликованы? Спасибо',
#   'label': 0},
#  {'text': 'теперь увидел, спасибо. а как часто списки обновляются?',
#   'label': 0},
#  {'text': 'Подскажите, где найти ранжированные списки поступающих этого года по основному конкурсу',
#   'label': 0},
#  {'text': 'Вопрос к поступающим абитуриентам: какая ориентировка на подачу заявления на согласие? В последний момент или как? Жду любых деловых комментариев и советов. Иван Сергеевич. Был ответ -в последнюю очередь. Насчет последнего момента с Вами не согласен. Если все начнут подавать согласия в 17-00 11 августа, то: 1-запросы обрушат сайт университета; 2- никто не узнает своего рейтинга до 12 августа. Приемная комиссия ночью не работает. Эффект будет обратным-никто не сорентируется в местах- не будет реальной информации при крайнем времени подачи. С Уважением, Иван Сергеевич.',
#   'label': 0},
#  {'text': 'А когда будут данные , о зачислении в магистратуру?', 'label': 0},
#  {'text': 'Добрый день!\nПодскажите пожалуйста, когда будет выпущен приказ по направлению 38.04.03, очно-заочная форма обучения?',
#   'label': 0},
#  {'text': 'Благодарю!', 'label': 0},
#  {'text': 'здравствуйте. если подано согласие, но в конце дня оказывается что не прохожу по баллам, переподать на другую группу уже не получится. как тогда поступать?',
#   'label': 0},
#  {'text': 'день добрый, а как теперь понять, зачислен ли ты?', 'label': 0},
#  {'text': 'а когда закончится обработка? и после ее окончания, если мое место по согласия входит в количестве мест, то я прохожу?',
#   'label': 0},
#  {'text': 'а когда закончится обработка?', 'label': 0},
#  {'text': 'Приветствую. Вопрос: прием согласий закончен, списки +- есть, 17 будет приказ. А что дальше? Будет какое-нибудь собрание для поступивших?',
#   'label': 0},
#  {'text': 'Когда закончится обработка?', 'label': 0},
#  {'text': 'Добрый день. Согласие на зачисление, поданное через ЛК на сайте университета посредством нажатия кнопки - это и есть официальное согласие? скан подписанного заявления никуда не направляли',
#   'label': 0},
#  {'text': 'Доброго дня, В каком общежитии поселят абитуриентов 09.03.04?',
#   'label': 0},
#  {'text': 'Результаты поступивших в магистратуру есть уже и списки?',
#   'label': 0},
#  {'text': 'Очень понятно, спасибо Вам!', 'label': 0},
#  {'text': 'Здравствуйте! Подскажите, пожалуйста, если в приказе, в столбце "Сведения об общежитии", стоит пометка "Да", значит ли это, что университет уже предоставил студенту место для проживания в общежитии?',
#   'label': 0},
#  {'text': 'Урааааа🙈👍😂', 'label': 0},
#  {'text': 'Понял\nСпасибо!', 'label': 0},
#  {'text': 'Сегодня приказ? И что за статус "набор завершён"?', 'label': 0},
#  {'text': 'Сегодня должны быть приказы. А набор завершён - значит набрали на это направление всех. Есть донабор по каким-то направлениями, в ЛК написано',
#   'label': 0},
#  {'text': 'Собрания будут в онлайн формате?', 'label': 0},
#  {'text': 'до какого числа будет идти прием документов на эти направления?',
#   'label': 0},
#  {'text': 'Не планируете открывать прием согласий для людей, которые ранее не подавали на эти направления подготовки?',
#   'label': 0},
#  {'text': 'Эм где открыли?', 'label': 0},
#  {'text': 'Здравствуйте', 'label': 0},
#  {'text': 'Но можно подать, если при подаче документов до 29 июля указал направления, на которые идет дополнительное зачисление',
#   'label': 0},
#  {'text': 'Доброго дня! Есть ли финальная информация об орг. собраниях, в частности по направлению 09.03.03? Очень интересует дата проведения. Спасибо',
#   'label': 0},
#  {'text': 'Таки, ждать сегодня какую-нибудь информацию? Или теперь до понедельника? Просто в ЛК написано не позднее 20-ого, но ПК то до 18:00 работает.',
#   'label': 0},
#  {'text': 'Ура. Сведения всё же появились. Большое спасибо.', 'label': 0},
#  {'text': 'а будут беседы в вк для первокурсников?', 'label': 0},
#  {'text': 'некоторые студенты уже создали группы своих направлений',
#   'label': 0},
#  {'text': 'а где это можно найти?', 'label': 0},
#  {'text': 'в подслушано станкина есть специальное обсуждение, также на стене есть информация',
#   'label': 0},
#  {'text': 'А когда начинается обучение для перваков в станкине?', 'label': 0},
#  {'text': 'И заселение в общагу', 'label': 0},
#  {'text': 'Вопрос для тех, кто отвечает за допнабор', 'label': 0},
#  {'text': 'Здравствуйте, а если нет приписного свидетельства? \nЕго почему-то не выдавали ранее',
#   'label': 0},
#  {'text': 'А разве я успею до 20? \nВозможно это сделать в самой Москве, для общаги же свидетельство не нужно.',
#   'label': 0},
#  {'text': 'Ну, то есть возможно его чуть позже принести', 'label': 0},
#  {'text': 'Было классно)', 'label': 0},
#  {'text': 'Подскажите пожалуйста как ребёнка в "школу юных" записать?',
#   'label': 0},
#  {'text': 'Спасибо большое', 'label': 0},
#  {'text': 'Доброе утро. Занятия сегодня  будут в школе юных?', 'label': 0},
#  {'text': 'Во сколько начало?', 'label': 0},
#  {'text': 'Дети еще в школе до 15, странно вы время выбираете!', 'label': 0},
#  {'text': 'А мне нравится, что в 12. Молодцы', 'label': 0},
#  {'text': 'Вы не понимаете меня я не про день открытых дверей Я про занятия в школе юных!',
#   'label': 0},
#  {'text': 'Сбросьте пожалуйста контактный телефон школы юных.', 'label': 0},
#  {'text': 'вот она сила 💪 общения', 'label': 0},
#  {'text': 'Принял. Спасибо', 'label': 0},
#  {'text': 'получается Станкин и трудоустройством занимается?', 'label': 0},
#  {'text': 'Это очень круто🤣', 'label': 0},
#  {'text': 'Поддерживаю!!!', 'label': 0},
#  {'text': 'Чем завершился процесс выведения орбитального блока на целевую геостационарную орбиту?',
#   'label': 0},
#  {'text': 'Интересно в этом году обучение будет по «WI FI» или в аудиториях 🧐',
#   'label': 0},
#  {'text': 'Будем очень надеяться, что обучение будет в аудиториях с Wi-Fi😇',
#   'label': 0},
#  {'text': 'Добры день!\n\n"Ангара" успешно доставила в космос разгонный блок "Персей" с макетом спутника.\nОрбитальный блок в составе разгонного блока "Персей" и габаритно-массового макета полезной нагрузки отделился от третьей ступени тяжелой ракеты-носителя "Ангара-А5"',
#   'label': 0},
#  {'text': 'Добрый день. Пуск Ангары был в конце декабря 2021 г. В настоящее время есть достоверная информация, что разгонный блок с ГММ полностью выполнили цели и задачи?',
#   'label': 0},
#  {'text': 'Здравствуйте, когда начнутся вступительные экзамены?', 'label': 0},
#  {'text': 'могут ли иностранные абитуриенты сдавать экзамены онлайн',
#   'label': 0},
#  {'text': 'Спасибо за ответ', 'label': 0},
#  {'text': 'Поздравляем победителей!!! 👏👏👏МОЛОДЦЫ РЕБЯТА!!! 👍👍👍', 'label': 0},
#  {'text': 'Смотреть с чатом интереснее🤗', 'label': 0},
#  {'text': 'Это не только для москвы?', 'label': 0},
#  {'text': 'Принять участие в мероприятиях проекта "Инженерные субботы" могут только учащиеся школ г. Москвы.',
#   'label': 0},
#  {'text': 'Промахнулась 😢', 'label': 0},
#  {'text': 'Добрый день, я хотел бы посетит унивнрситет на день открытых дверей, как я могу это сделать?',
#   'label': 0},
#  {'text': 'Добрый день, Александр, для посещения университета в  рамках  дня открытых дверей необходимо пройти регистрацию на сайте: https://info.stankin.ru/dod',
#   'label': 0},
#  {'text': 'я окончил Станкин в 2008 году, хотел прийти, с преподователями встретиться, в столовую зайти, чай с эклером выпить',
#   'label': 0},
#  {'text': 'Дает ли Московская медаль "За успехи в обучении" доп.баллы или только Федеральная медаль имеет преимущества?',
#   'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'Здравствуйте! Есть ли возможность получить доступ к фотографиям со дня открытых дверей 23.04?🙏',
#   'label': 0},
#  {'text': 'Нарек Гений', 'label': 0},
#  {'text': 'Нужна ли медсправка абитуриентам при подаче документов на поступление?',
#   'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'Кто может быть в качестве сопровождающего? И сопровождающий обязательно нужен?',
#   'label': 0},
#  {'text': 'Добрый день, а у вас есть альбом с фотографиями?', 'label': 0},
#  {'text': 'Здравствуйте! Есть ли военный учебный центр, военная кафедра в институте?',
#   'label': 0},
#  {'text': 'Доброе время суток. Благодарю за информацию', 'label': 0},
#  {'text': 'Добрый день. Расскажите по направления 09.03.01, 09.03.02, 09',
#   'label': 0},
#  {'text': 'А также 09.03.03 и 09.03.04. Чем отличаются и где больше программирования?',
#   'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'Доброе время суток. Благодарю за информацию', 'label': 0},
#  {'text': 'Здравствуйте! Прошу уточнить где располагаются учебные корпуса факультетов:\nИВТ, прикладная информатика, информ.системы и технологии.',
#   'label': 0},
#  {'text': 'Спасибо за инфо.', 'label': 0},
#  {'text': 'Подскажите пожалуйста, а общежития всем иногородним предоставляется?',
#   'label': 0},
#  {'text': 'Ещё вопрос об учебных планах на направления 09.03.01 и 09.03.02, где их можно посмотреть?? Ссылку можно дать?',
#   'label': 0},
#  {'text': 'Доброго дня\nкак тут мало народу', 'label': 0},
#  {'text': 'тот же вопрос', 'label': 0},
#  {'text': 'Никак не могу найти учебные планы', 'label': 0},
#  {'text': 'Спасибо!', 'label': 0},
#  {'text': 'Спасибо, остался вопрос об условиях предоставления общежития',
#   'label': 0},
#  {'text': 'Добрый день. В общежитиях есть интернет? Или только свой мобильный. Как ребята готовятся к занятиям?',
#   'label': 0},
#  {'text': 'Тоже интересует', 'label': 0},
#  {'text': 'Добрый день! Скажите пожалуйста, если мы подаем документы через госуслуги, цифровой аттестат приравнивается к бумажному?? Можно бумажный оригинал будет привезти уже после зачисления??',
#   'label': 0},
#  {'text': 'Здравствуйте, на госуслугах стоит статус принято к рассмотрению, когда появлюсь в ранжированных списках?',
#   'label': 0},
#  {'text': 'Подскажите пожалуйста, в перечне ИД есть "Участие и (или) результаты участия в\nолимпиадах школьников (не используемые для\nполучения особых прав и (или) особого\nпреимущества при поступлении на обучение по конкретным условиям поступления)". Это про какие олимпиады идет речь?',
#   'label': 0},
#  {'text': 'Есть еще "Участие и (или) результаты участия\nв олимпиадах и иных интеллектуальных и (или)\nтворческих конкурсах, физкультурных\nмероприятиях и спортивных мероприятиях,\nпроводимых в соответствии с частью 2 статьи 77\nФедерального закона № 273\n-ФЗ в целях выявления и поддержки лиц, проявивших\nвыдающиеся способности". Это про перечневые здесь говорится (РСОШ), я правильно понимаю?',
#   'label': 0},
#  {'text': 'Здравствуйте. Подскажите, как просмотреть стоимость платного обучения на сайте.',
#   'label': 0},
#  {'text': 'Это рсош и всош с перечнем можно ознакомиться здесь: https://ntcontest.ru/about/news/RSOSH-2021-22/?ysclid=l571b6xqg6281543192',
#   'label': 0},
#  {'text': 'здесь подразумеваются все остальные олимпиады', 'label': 0},
#  {'text': 'А как участие в олимпиадах подтвердить, за участие же грамоты не дают',
#   'label': 0},
#  {'text': 'И за какие года нужно участие и результаты олимпиад?', 'label': 0},
#  {'text': 'Первым делом, наверное, нужно уточнить. Можно получить 10 баллов максимум за индивидуальные достижения. Т.е. при условии если у Вас много ИД получить можно всего 10 баллов дополнительно. Всё равно каким количеством они будут набраны. За участие в олимпиадах дают как участнику свидетельство. Пришлите пожалуйста своё портфолио нам на почту и мы обязательно всё оценим. Ещё лучший вариант приехать лично подавать документы по адресу: Вадковский пер. д. 1 и взять с собой своё портфолио. Мы обязательно всё посмотрим и поможем во всем разобраться.',
#   'label': 0},
#  {'text': 'Здравствуйте. Помогите пожалуйста. Где найти бланк заполнения заявления для поступления в Станкин',
#   'label': 0},
#  {'text': 'Добрый день. Как надо заполнить строку в заявлении, если поступаете на платную форму обучения',
#   'label': 0},
#  {'text': 'Добрый день, каким способом Вы подаете документы к нам?',
#   'label': 0},
#  {'text': 'Электронным, через сайт.', 'label': 0},
#  {'text': 'запишитесь на ZOOM консультацию и мы Вам поможем', 'label': 0},
#  {'text': 'Благодарю', 'label': 0},
#  {'text': 'Добрый день! Подскажите пожалуйста, как быстро обрабатываются заявления, поданные онлайн??',
#   'label': 0},
#  {'text': 'Добрый день. Мы стараемся максимально быстро это делать, но не всегда всё зависит только от нас',
#   'label': 0},
#  {'text': 'всем абитуриентам дают общежитие?', 'label': 0},
#  {'text': 'В этом году увеличили количество мест в общежитии. В прошлом году всем имеющим право и поступившим на бюджетную форму предоставили общежитие',
#   'label': 0},
#  {'text': 'Добрый вечер! После выхода приказов о зачислении, когда необходимо явиться в ВУЗ для оформления студенческого билета и и т.п?',
#   'label': 0},
#  {'text': 'Обо всём мы дополнительно сообщим. Следите за новостями, а пока держим 🤞🏻',
#   'label': 0},
#  {'text': 'Здравствуйте✌\nКогда появится возможность зайти в личный кабинет?',
#   'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'Где подать согласие, если через госуслуги заявление подавалось?',
#   'label': 0},
#  {'text': 'И почему несоответствие такое', 'label': 0},
#  {'text': 'Что значит обращение обратным письмом?)', 'label': 0},
#  {'text': 'Хорошо, спасибо.', 'label': 0},
#  {'text': 'с днем рождения, СТАНКИН🥳', 'label': 0},
#  {'text': 'здравствуйте, где можно посмотреть списки подавших документы?',
#   'label': 0},
#  {'text': 'нашёл, разобрался', 'label': 0},
#  {'text': 'Отлично', 'label': 0},
#  {'text': 'Добрый день, как можно скорректировать сведения в личном кабинете анкетные, если документы уже приняты?',
#   'label': 0},
#  {'text': 'Здравствуйте. Что такое «ваше место по согласиям» ?', 'label': 0},
#  {'text': 'Положено ли общежитие, если по целевому поступаешь?', 'label': 0},
#  {'text': 'скажите, что за оператор у меня просят', 'label': 0},
#  {'text': 'Здравствуйте. А через госуслуги можно тоже подать документы или непосредственно через Ваш сайт?',
#   'label': 0},
#  {'text': 'Добрый день! Подскажите пожалуйста, если хотим прийти подать документы нам надо записываться на приём или можно просто прийти',
#   'label': 0},
#  {'text': 'Прошу вашей помощи. Мы подали документы в станкин. Но поняли что не хотим участвовать в конкурсе. Я звонила 5 раз. Писала. Просила убрать нас из списков. Действий никаких.',
#   'label': 0},
#  {'text': 'Подскажите что мне нужно сделать что б нас все таки убрали из списков???',
#   'label': 0},
#  {'text': 'Заявление написано на почту pk. В личном кабинете удалились.',
#   'label': 0},
#  {'text': 'Помогите птжалуйста!!!', 'label': 0},
#  {'text': 'Добрый день! Подскажите пожалуйста, если спецквота не будет выбрана полностью, оставшиеся места перейдут в основные места? Если да, то после какого числа это произойдёт?',
#   'label': 0},
#  {'text': 'Можно ли согласие на зачисление подать очно в институте, если заявление через госуслуги подавалось?(там сейчас сбой)',
#   'label': 0},
#  {'text': 'здравствуйте, можно. Приезжайте, подавайте. Приемная комиссия работает каждый день с 10:00 до 18:00',
#   'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'Можно ли в рейтинговых списках увидеть, от какого именно предприятия целевая квота?',
#   'label': 0},
#  {'text': 'Хотя бы количество мест и заявок', 'label': 0},
#  {'text': 'Добрый вечер, а где можно посмотреть списки подавших документы?',
#   'label': 0},
#  {'text': 'Добрый вечер! \nКонкурсные списки находятся на сайте Приёмной комиссии: https://priem.stankin.ru/bakalavriatispetsialitet/ranked-lists/',
#   'label': 0},
#  {'text': 'Добрый день, почему в списках нумерация задвоена. И список получается не совсем ранжированный.',
#   'label': 0},
#  {'text': 'Ведутся технические работы. Актуальная информация в ЛК https://info.stankin.ru/lk/login',
#   'label': 0},
#  {'text': 'А есть какой то чат для абитуриентоа по поступлению, где общаются, например?',
#   'label': 0},
#  {'text': 'Добрый день! Подскажите пожалуйста до скольки 03.08.2022 будет работать приёмная комиссия.',
#   'label': 0},
#  {'text': 'Утро доброе. До 18:00, но учтите , абитуриент до этого времени должен предоставить документы необходимые для поступления. А не придти до 18:00',
#   'label': 0},
#  {'text': 'Здравствуйте', 'label': 0},
#  {'text': 'Можете скинуть направления и цены на платной основе', 'label': 0},
#  {'text': 'С этой информацией Вы можете ознакомиться на сайте Приёмной комиссии:\nhttps://priem.stankin.ru/bakalavriatispetsialitet/pustayastranitsa_sstv/',
#   'label': 0},
#  {'text': 'А как подать согласие в вуз?', 'label': 0},
#  {'text': 'В случае, если Вы не оставляли у нас оригинал документа об образовании, рекомендуем Вам как можно скорее это сделать. К тому же, лично Вы сможете сразу подать и заявление о согласии на зачисление. \nТакже, пока нет очередей, рекомендуем Вам поторопиться, так как сроки ограничены — последний день приёма документов, необходимых для зачисления (то есть оригинала документа об образовании и заявления о согласии на зачисление), 3 августа.',
#   'label': 0},
#  {'text': 'Могу я самостоятельно явиться в вуз?', 'label': 0},
#  {'text': 'Конечно можете', 'label': 0},
#  {'text': 'Когда будет настроена соответствующая сортировка внутри ранжированного списка?',
#   'label': 0},
#  {'text': 'Здравствуйте! Получили письмо на электронную почту  с предложением привезти оригинал и согласие лично. Подали заявление через ЕПГУ и планировали использовать  возможность подать согласие и аттестат через ЕПГУ. Возникли какие-то сложности с документами? Учетная запись на госуслугах подтверждена, результаты ЕГЭ прошлого, 2021, года, аттестат также подтвержден.',
#   'label': 0},
#  {'text': 'Вам сообщили о возможности подать лично несмотря на статус который у Вас на упомянутом сервисе. Т.к. всякое может быть и запасной вариант у Вас должен быть',
#   'label': 0},
#  {'text': 'Спасибо.', 'label': 0},
#  {'text': 'можно пожалуйста ссылку', 'label': 0},
#  {'text': 'на списки', 'label': 0},
#  {'text': 'спасибо', 'label': 0},
#  {'text': 'Добрый день! Подскажите пожалуйста с какой периодичностью обновляются ранжированные списки.',
#   'label': 0},
#  {'text': 'Это только 9 или 10 августа', 'label': 0},
#  {'text': 'Приказ о зачислении в приоритетную волну (БВИ, квоты) выйдет послезавтра, 30 июля. Приказ о зачислении в основной этап (бюджет) — 9 августа.',
#   'label': 0},
#  {'text': 'А можете посказать, до скольки будет работать очная приемка 3 августа?',
#   'label': 0},
#  {'text': 'Добрый день! Подскажите  во сколько выйдут приказы по приоритетному этапу?',
#   'label': 0},
#  {'text': 'до 18:00 должна', 'label': 0},
#  {'text': 'хотелось бы услышать мнение станкина', 'label': 0},
#  {'text': 'Спасибо. А в связи с выходом приказов количество основных бюджетных мест в личном кабинете когда пересчитается?',
#   'label': 0},
#  {'text': 'Здравствуйте. Скажите на робототехнике 77 бюджетных мест. Сколько из них уже занято целевиками, квотниками и льготниками? Какое количество осталось для основного потока по баллам?',
#   'label': 0},
#  {'text': 'Т.е. количество оставшихся мест после квотников-льготников только в ЛК можно увидеть и узнать?',
#   'label': 0},
#  {'text': 'Здравствуйте, не могу подать согласие', 'label': 0},
#  {'text': 'Больше никуда его не подавал', 'label': 0},
#  {'text': 'Добрый день! Подскажите до какого часа завтра будет работать приёмная комиссия?? Просто многие вузы продлили приём согласий до 23.59 из-за госуслуг.',
#   'label': 0},
#  {'text': 'Здравствуйте', 'label': 0},
#  {'text': 'Можете подсказать сколько мест по направлениям бюджетным',
#   'label': 0},
#  {'text': 'Согласие на зачисление можете скинуть, пожалуйста', 'label': 0},
#  {'text': 'У вас на сайте вуза 85 бюджетных мест на направление 15.03.05, а в ЛК Абитуриена 60',
#   'label': 0},
#  {'text': 'Почему не 85?', 'label': 0},
#  {'text': 'Вот именно', 'label': 0},
#  {'text': 'Я туда подал', 'label': 0},
#  {'text': 'Я тоже', 'label': 0},
#  {'text': 'И я вылетел только что', 'label': 0},
#  {'text': 'На 61', 'label': 0},
#  {'text': 'Я на 63', 'label': 0},
#  {'text': 'Я скачиваю pdf file согласия', 'label': 0},
#  {'text': 'А он не ошибку выдаёт', 'label': 0},
#  {'text': 'На сайте я на 63 месте, а на ранжированных списках на 47. Как это может быть?',
#   'label': 0},
#  {'text': 'Возможно увеличение бюджетных мест завтра?', 'label': 0},
#  {'text': 'И на сколько', 'label': 0},
#  {'text': 'Ранжированные списки последний раз обновлялись в 11 утра! Это накануне стопа по приему! Невозможно оценить ситуацию!',
#   'label': 0},
#  {'text': 'Добрый день! Хочу уточнить, если абитуриент подал документы через Госуслуги, у него последняя возможность подать оригинал и согласие ( нажать кнопку) через Госуслуги тоже 03.08 до 18.00',
#   'label': 0},
#  {'text': 'здравствуйте, могу ли я забрать аттестат после 18.00 ? Если да, то до скольких тогда ?',
#   'label': 0},
#  {'text': 'Добрый вечер, приёмная комиссия сейчас не принимает звонки? Как уточнить статус заявления?',
#   'label': 0},
#  {'text': 'Статус заявления можно уточнить в личном кабинете абитуриента. Приёмная комиссия завершила работу на сегодня.',
#   'label': 0},
#  {'text': 'Мы подали через госуслуги', 'label': 0},
#  {'text': 'Там не прогружает', 'label': 0},
#  {'text': 'И вы же приём продлили до 23:59?', 'label': 0},
#  {'text': 'Нет, приём завершили в 18:00.', 'label': 0},
#  {'text': 'Почему на госуслугах написано в 23:59?', 'label': 0},
#  {'text': 'Если мы подали в 17:40, оно будет принято?', 'label': 0},
#  {'text': 'Мы не можем отвечать за сторонние сервисы. Согласно нашим Правилам приёма, мы были обязаны завершить принимать согласия в 18:00.',
#   'label': 0},
#  {'text': 'Да.', 'label': 0},
#  {'text': 'А когда будет следующее обновление ранжированных списков на бакалавриат/специалитет? У многих абитуриентов стоят галочки об оригинале согласия на зачисление, но не стоят об оригинале документа об образовании. Они могут всё-таки появиться позднее, или их считать выбывшими из конкурса?',
#   'label': 0},
#  {'text': 'Тоже интересует этот вопрос, может надо уже брать документы и идти где доп зачисления начались?? Или есть шанс пройти к вам?',
#   'label': 0},
#  {'text': 'Уже многие вузы всё обновили, и с ГУ разобрались', 'label': 0},
#  {'text': 'то есть конкурс на зачисление ведется по одному фильтру списка "согласие на зачисление"?   (галочка в поле "документ об образовании" не обязательна)',
#   'label': 0},
#  {'text': 'Поясните пожалуйста. Абитуриенты с госуслуг для зачисления должны были подать либо оригинал аттестата, либо аттестат в электронном виде через госуслуги. Вот эти электронные аттестаты не видны в конкурсных списках, так? Это точно?',
#   'label': 0},
#  {'text': 'Хм. А ведь эти аттестаты _должны быть_ в конкурсных списках как: "предоставлен электронный документ"',
#   'label': 0},
#  {'text': 'Не вижу никакой проблемы: либо в этой же графе ставить галочку, т. к. электронный приравнен к оригиналу, либо вместо галочки ставить "оригинал", "электронный". А сейчас введены в заблуждение многие абитуриенты, которые не видели и, соответственно, не могли учесть абитуриентов, подавших документы с госуслуг.',
#   'label': 0},
#  {'text': 'А вы завтра до скольки работаете', 'label': 0},
#  {'text': 'Добрый день! А во сколько будут приказы 9 августа??', 'label': 0},
#  {'text': 'И ещё вопрос: ранжированные списки ещё будут обновляться до 9 числа?',
#   'label': 0},
#  {'text': 'Здравствуйте! А в личном кабинете абитуриента будет как-то отражена информация о зачислении?',
#   'label': 0},
#  {'text': 'Добрый день, есть ли предположительно время публикации приказа о зачислении?',
#   'label': 0},
#  {'text': 'Очень волнуемся, что до сих пор не учли наше письмо в почте, по поводу общежития.',
#   'label': 0},
#  {'text': 'приятного аппетита! ждем приказ )', 'label': 0},
#  {'text': 'Ура!', 'label': 0},
#  {'text': 'Здравствуйте, а где можно будет найти информацию по поводу общежития?',
#   'label': 0},
#  {'text': 'Но ведь там ничего нет?', 'label': 0},
#  {'text': 'Или позже информация будет?', 'label': 0},
#  {'text': 'Ура!🎉🎉🎉', 'label': 0},
#  {'text': 'Спасибо💯🤩', 'label': 0},
#  {'text': 'Совсем скоро начало студенческих деньков, так ещё и после школьных... Начинаю уже скучать по школе 😂👍',
#   'label': 0},
#  {'text': 'Если уже есть карта Сбера, наверное нет необходимости заводить еще одну?',
#   'label': 0},
#  {'text': 'Отлично! а это когда будет?', 'label': 0},
#  {'text': 'спасибо! 🤝', 'label': 0},
#  {'text': 'Добрый день, скажите пожалуйста а нужно выбирать профиль на 27.03.04?',
#   'label': 0},
#  {'text': 'Когда заселение в общежитие, где узнать информацию?(надо брать билеты) Нужна ли доверенность нотариальная, если ребенку нет 18 лет?',
#   'label': 0},
#  {'text': 'До подачи заявления в приёмной комиссии уверяли, что мест в общежитиях Станкина (именно Станкина) всем хватит. Начались пугалки про малое количество мест и заселение в какие-то Кузьминки. Где правда?',
#   'label': 0},
#  {'text': 'После шести можно забрать аттестат?', 'label': 0},
#  {'text': 'В личном кабинете абитуриента написана вся информация)',
#   'label': 0},
#  {'text': 'Спасибо!', 'label': 0},
#  {'text': 'Нужно завести другой личный кабинет? В Лк абитуриента нет информации',
#   'label': 0},
#  {'text': 'То есть общежитие не в Кузьминках будет? 🤔', 'label': 0},
#  {'text': 'Кому можно позвонить/написать, чтобы две подруги, поступившие на одну специальность, при распределении оказались в одной группе?',
#   'label': 0},
#  {'text': 'Добрый день, а если я приеду 31 августа, мне достанется нормальная комната в общежитии? И достанется ли вообще?',
#   'label': 0},
#  {'text': 'Здравствуйте, приписное свидетельство обязательно нужно или можно позже принести?',
#   'label': 0},
#  {'text': 'Когда можно узнать, по какому адресу находится общежитие?',
#   'label': 0},
#  {'text': 'Здравствуйте! Какие направления заселяют в данное общежитие?',
#   'label': 0},
#  {'text': 'Добрый вечер администрация и участники, были сегодня в общежитии 3, смотрели комнату. В комнатах "евро ремонт", сразу появляется стимул учиться, а если без шуток, это ужас😱, как в таком гадюшнике жить можно, ума не приложу🤦\u200d♂️ Всё заранно, везде грязь и причём это во всех комнатах, не только в одной! Я не знаю про какой ремонт вы говорите🤷\u200d♂\nPs: если у кого-то возникли сомнения в выше сказанном, у меня есть фото и видео)',
#   'label': 0},
#  {'text': 'Ужас! Спасибо за информацию. Я тоже родитель первокурсницы, эту информацию переслала в чат Станкина с вопросом о заселении в нем.',
#   'label': 0},
#  {'text': 'Подскажите, что за чат Станкина?', 'label': 0},
#  {'text': 'В этот чат, к котором сейчас общаемся. Я ранее сюда пересылала инфу о ремонте общежития, скопированную из телеграмм-канала Станкина.',
#   'label': 0},
#  {'text': 'А вам ответили кого селят в отремонтированное общежитие?',
#   'label': 0},
#  {'text': 'Ничего нового… Культурно «послали» в единый деканат)', 'label': 0},
#  {'text': 'Вы-родитель первокурсника?', 'label': 0},
#  {'text': 'Да', 'label': 0},
#  {'text': 'В л/с', 'label': 0},
#  {'text': 'Подскажите, где первокурснику можно получить справку-подтверждение о том, что он-студент? (нужно родителям в организацию)',
#   'label': 0},
#  {'text': 'Спасибо за ответ🤝', 'label': 0},
#  {'text': 'До встречи 1 октября', 'label': 0},
#  {'text': 'Отлично 👍', 'label': 0},
#  {'text': 'Когда новый хохотон?', 'label': 0},
#  {'text': 'Эх, не успели, все места быстро разобрали. Ждём новых мастер- классов 😀👍🏻',
#   'label': 0},
#  {'text': 'БОЛЬШЕ МЕРЧА', 'label': 0},
#  {'text': 'Ура!!!!!!!!! Поздравляем ребят!!!!!!!! Желаем всем десятиклассникам успехов на сочинении!!!!!!!! 🥳',
#   'label': 0},
#  {'text': 'Подскажите,  пожалуйста,  а в Станкине есть вечерняя или заочная форма обучения?',
#   'label': 0},
#  {'text': 'Ответ: 4', 'label': 0},
#  {'text': 'Добрый день, а во сколько начинается ОЧНЫЙ формат дня открытых дверей 28 января ?',
#   'label': 0},
#  {'text': 'И нужно ли регистрироваться на него ?', 'label': 0},
#  {'text': 'на сайте бы тогда убрали ОЧНО', 'label': 0},
#  {'text': 'увидел, что поправили', 'label': 0},
#  {'text': 'спасибо за отличную обратную связь', 'label': 0},
#  {'text': 'Здравствуйте, а когда начнутся курсы? Писем пока нет с уведомлением.',
#   'label': 0},
#  {'text': 'А конкретика еще не известна? С какого числа? По каким дням? В какое время? Спасибо.',
#   'label': 0},
#  {'text': 'Не возможно дозвониться ни по одному номеру ВУЗА, вроде сегодня вечером ждёте гостей, а в вузе никого? Подскажите, пожалуйста, по содержанию сегодняшнего ДОД и 18 марта будут отличия, кроме того, что в марте будет трансляция онлайн? По лабораториях так же можно будет походить? Или сегодня расширенная версия?',
#   'label': 0},
#  {'text': 'Автоматизация технологических процессов и производств.',
#   'label': 0},
#  {'text': 'Супер  поздравления!!! 😄  Спасибо!!!', 'label': 0},
#  {'text': 'Ну, я считаю, было круто!\nСпасибо организаторам за такой клёвый день открытых дверей ;D',
#   'label': 0},
#  {'text': 'На егэ так же сделаю обязательно', 'label': 0},
#  {'text': 'Иногородним предоставляете общежитие?', 'label': 0},
#  {'text': 'Добрый день! Подскажите пожалуйста, осуществляется ли прием в МГТУ СТАНКИН без сдачи ЕГЭ(по вступительным экзаменам)  для выпускников 11 классов,ЛНР. До какого числа можно подать документы? И есть ли квота для выпускников ЛНР?',
#   'label': 0},
#  {'text': 'Спасибо, очень ждём.', 'label': 0},
#  {'text': 'Здравствуйте, возникла проблема, сайт не работает.', 'label': 0},
#  {'text': 'Прийти посмотреть как-нибудь можно?', 'label': 0},
#  {'text': 'Всем привет, а когда день открытых дверей?', 'label': 0},
#  {'text': 'Вопрос по целевому обучению. Какие условия поступления после 11 класса?',
#   'label': 0},
#  {'text': 'В здании около м. Нижегородская какие факультеты учатся?',
#   'label': 0},
#  {'text': 'А что это за направление, где чертежи, как на видео?', 'label': 0},
#  {'text': 'В Компасе тоже учат работать?', 'label': 0},
#  {'text': 'Добрый вечер. Я иностранный студент, который очень хочет поступить в Университет Станкин, и мне нужна ваша помощь.',
#   'label': 0},
#  {'text': 'Названиями', 'label': 0},
#  {'text': 'Автоматизация технологических процессов и производств', 'label': 0},
#  {'text': 'Мехатроника и робототехника', 'label': 0},
#  {'text': 'Мехатроник робототехник', 'label': 0},
#  {'text': 'Прикладная информатика', 'label': 0},
#  {'text': 'Майн', 'label': 0},
#  {'text': 'Жиз', 'label': 0},
#  {'text': 'Русский - 81\nМатематики - 76\n(Планирую поступать на "Автоматизация технологических процессов и производств")',
#   'label': 0},
#  {'text': 'русский - 83\nматематика- 78', 'label': 0},
#  {'text': 'Русский 93, математика 70. В планах 15.03.06', 'label': 0},
#  {'text': 'Вопрос! Где можно посмотреть проходные баллы на платку??! Кроме мест и стоимости ничего не нашла😳',
#   'label': 0},
#  {'text': 'А с такими баллами возможно поступить?', 'label': 0},
#  {'text': 'А подскажите,  пожалуйста,  если после 27 июля понимаешь, что прошёл, необходимо до 03.08 привезти оригинал аттестата или это можно сделать онлаййн?',
#   'label': 0},
#  {'text': 'Минимальный проходной за 2022 был 212 баллов. \nСредний - 227.\nИнформатика будет 90+, что в сумме даст 247-257 баллов(без учëта дополнительных баллов за личные достижения) . \nПоэтому, думаю, что вполне реально.',
#   'label': 0},
#  {'text': 'Добрый день, когда завершаться технические работы?', 'label': 0},
#  {'text': 'Каким образом распределяются места в общежитии?всем ли первокурсников хватает?',
#   'label': 0},
#  {'text': 'Нужно ли проходить вступительное испытание если идёшь по целевой квоте?',
#   'label': 0},
#  {'text': 'При том, что не сдавал ЕГЭ', 'label': 0},
#  {'text': 'Добрый вечер! Подскажите проходные баллы на бюджет на IT?',
#   'label': 0},
#  {'text': 'Я из новой республики', 'label': 0},
#  {'text': 'Спасибо!', 'label': 0},
#  {'text': 'На контракт у вас тоже конкурс или всех принимаете? До какого числа принимаете заявление на контракт?',
#   'label': 0},
#  {'text': 'Добрый день. Сын победитель Больших вызовов,  диплом пришёл по Эл.почте. Достаточно ли электронной версии для учета ИД, или надо с организатором связываться, чтобы высылали на бумаге?',
#   'label': 0},
#  {'text': 'Добрый день по отдельной квоте можно поступать по ЕГЭ? Абитуриент относится к категории поступающих по ЕГЭ и ВИ, документы в таком случаем подаем же до 25?',
#   'label': 0},
#  {'text': 'Спасибо.', 'label': 0},
#  {'text': 'Что такое медианный балл?', 'label': 0},
#  {'text': 'Здравствуйте, участие в конкурсах от МГТУ "СТАНКИН" (не всероссийских) дает ли какой-то балл в ИД?',
#   'label': 0},
#  {'text': 'Здравствуйте. Подскажите пожалуйста. Если абитуриент после подачи документов уже определился с выбором вуза, должен ли он самостоятельно извещать оставшиеся вузы о том, что в их конкурсе на зачисление он не участвует.',
#   'label': 0},
#  {'text': 'Добрый день! Подскажите, пожалуйста, дает ли дополнительный балл призеру Всероссийской олимпиады по обществознанию? И категория значка ГТО  5 ступени золото? Спасибо',
#   'label': 0},
#  {'text': 'Спасибо большое', 'label': 0},
#  {'text': 'Добрый день.\nУточните пожалуйста, есть ли возможность поступить в аспирантуру на бюджетное место по направлению Экономика 5.2?',
#   'label': 0},
#  {'text': 'Есть ли онлайн курсы по информатике в Станкин?', 'label': 0},
#  {'text': 'Может кто-то посоветует, для поступления в следующем году.',
#   'label': 0},
#  {'text': 'Добрый день! Подскажите пожалуйста, если подал документы на бюджет и не прошел по конкурсу, на платный можно успеть подать документы после этого или как то надо параллельно подавать или как лучше сделать, чтобы не остаться вообще и без платного и без бюджета, пока будешь ждать результат ?',
#   'label': 0},
#  {'text': 'Добрый день! Подскажите, пожалуйста, аттестат с отличием и золотая медаль дают дополнительные баллы к общему баллу ЕГЭ при поступлении?',
#   'label': 0},
#  {'text': 'Можно уточнить за серебряный значок ГТО -2 балла?', 'label': 0},
#  {'text': 'Спасибо, отлично.', 'label': 0},
#  {'text': 'Имеет ли значение федеральная медаль или Московская?', 'label': 0},
#  {'text': 'Здравствуйте,  без аттестата , поступающий , создать личный кабинет не может, правильно? Наличие выданного аттестата обязательно для регистрации личного кабинета?',
#   'label': 0},
#  {'text': 'а за волонтерство есть допбаллы?', 'label': 0},
#  {'text': 'Сколько бюджетных мест по направлению Менеджмент и Экономика?',
#   'label': 0},
#  {'text': 'А в прошлом году сколько было?', 'label': 0},
#  {'text': 'Подскажите, пожалуйста, какие условия для получения общежития?',
#   'label': 0},
#  {'text': 'Сколько составляет стипендия? Есть ли какие-то надбавки?',
#   'label': 0},
#  {'text': 'А по отдельной квоте , самим  высчитывать, например, Прикладная информатика 96 мест, по квоте 9 или 10?',
#   'label': 0},
#  {'text': 'А есть надбавка по потери кормильца?', 'label': 0},
#  {'text': 'А стоимость проживания в общежитии какая? Общежития предоставляются на весь период обучения?',
#   'label': 0},
#  {'text': 'Благодарю!', 'label': 0},
#  {'text': 'Спасибо.', 'label': 0},
#  {'text': 'Здравствуйте, подскажите, пожалуйста, можно ли где-то найти статистику приема в аспирантуру за прошлые годы? Хотя бы приказы',
#   'label': 0},
#  {'text': 'Подскажите, пожалуйста, по машиностроению', 'label': 0},
#  {'text': 'А на информатику?', 'label': 0},
#  {'text': 'нет', 'label': 0},
#  {'text': 'бакалавриат или магистратура', 'label': 0},
#  {'text': 'программа информатика и вычислительная техника, проходной балл на бюджет',
#   'label': 0},
#  {'text': 'спасибо, понял', 'label': 0},
#  {'text': 'Здравствуйте, когда завершится подача документов? и когда экзамены ?',
#   'label': 0},
#  {'text': 'спасибо большое', 'label': 0},
#  {'text': 'А когда решат проблему с дистанционной подачей документов?',
#   'label': 0},
#  {'text': 'Здравствуйте, когда будет доступна электронная подача документов через официальный сайт?',
#   'label': 0},
#  {'text': 'Здравствуйте,сколько часов волонтёрства необходимо,чтобы получить баллы за него ? Все верифицированы должны быть?',
#   'label': 0},
#  {'text': 'А если книжки нет, а есть часы на сайте доброе.ру?', 'label': 0},
#  {'text': 'Добрый день! \nЯ абитуриент из Таджикистана, ранее я писала на почту одному из представителей вашего университета , мне сказали что для поступления необходимо перечень документов куда входит документ об образовании ( аттестат) .\nВ Таджикистане аттестат выдают только в июле, а подача документов до 20 го , я отправила все необходимые документы, однако вместо аттестата отправила справку об окончании школы, мне до сих пор не ответили и уже прием документов окончен .\nСкажите пожалуйста, что мне делать?\nМожете ли вы мне помочь?',
#   'label': 0},
#  {'text': 'Я бы хотела поступить на бакалавриат экономика', 'label': 0},
#  {'text': 'На контракт', 'label': 0},
#  {'text': 'Благодарю, а регистрироваться на сайте который указан в закрепленных сообщениях ?',
#   'label': 0},
#  {'text': 'Да', 'label': 0},
#  {'text': 'Спасибо большое)', 'label': 0},
#  {'text': 'Это уже после вступительных экзаменов, в августе должна буду отнести?',
#   'label': 0},
#  {'text': 'Кстати какие экзамены нужно сдавать ?', 'label': 0},
#  {'text': 'Могу сдать как только получу аттестат в июле?', 'label': 0},
#  {'text': 'Это окно открывается после того как нажимаю "Хотите подать заявление? Зарегистрируйтесь."',
#   'label': 0},
#  {'text': 'Здравствуйте! Подскажите, пожалуйста, где можно посмотреть конкурс предыдущих лет на бюджет и на предоставление общежития?',
#   'label': 0},
#  {'text': 'Спасибо! А нет конкретных приказов на зачисление с конкурсной таблицей?',
#   'label': 0},
#  {'text': 'Понятно, спасибо', 'label': 0},
#  {'text': 'Добрый вечер! Подскажите, пожалуйста, подать заявку на целевое обучение можно только в одном вузе?',
#   'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'А обращаться по поводу целевого обучения необходимо самим в организацию или же через вуз?',
#   'label': 0},
#  {'text': 'Поняла, спасибо', 'label': 0},
#  {'text': 'Подскажите что такое медианный балл?', 'label': 0},
#  {'text': 'есть возможность, что минимальный балл на бюджет будет ниже медиального?',
#   'label': 0},
#  {'text': 'Понимаю, спасибо', 'label': 0},
#  {'text': 'Ещё вопрос, каким образом распределяются места между тремя общежитиями? Это зависит от направления?',
#   'label': 0},
#  {'text': 'А где можно посмотреть сколько выделяется мест на конкретное направление?',
#   'label': 0},
#  {'text': 'Спасибо!', 'label': 0},
#  {'text': 'Доброе утро! Подскажите пожалуйста, мой сын выпускник  университета. Планирует поспутать в магистратуру, направление медицинская робототехника. В этом году будет набор на данное направление ? Какое количество мест. Заранее спасибо.',
#   'label': 0},
#  {'text': 'Здравствуйте! Не могу найти своего учебного заведения при подаче документов. Как решить эту проблему?',
#   'label': 0},
#  {'text': 'Через официальный сайт, во вкладке "Сведения об образовании"',
#   'label': 0},
#  {'text': 'А, всё, увидел. Спасибо', 'label': 0},
#  {'text': 'А где можно найти код подразделения учебного заведения?',
#   'label': 0},
#  {'text': 'Понятно', 'label': 0},
#  {'text': 'Добрый день. А за итоговое  сочинение нет дополнительных баллов?',
#   'label': 0},
#  {'text': 'Добрый день! \nПодскажите пожалуйста по поводу перевода из другого вуза к кому общаться? (Магистратура)',
#   'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'Добрый день. Я правильно понимаю, что в выходные дни приемная комиссия работает с 10-15 по адресу МОСКВА, ВАДКОВСКИЙ ПЕР., Д.1?\nКакие документы надо иметь при себе?',
#   'label': 0},
#  {'text': 'Или сейчас можно онлайн оформить?', 'label': 0},
#  {'text': 'А фото зачем?))', 'label': 0},
#  {'text': 'Спасибо. Онлайн подавать через ваш официальный сайт или через госуслуги?',
#   'label': 0},
#  {'text': 'Понял, спасибо. Подскажите, какие даты вступительных экзаменов в июле? Я так понимаю они будут проводиться дистанционно?',
#   'label': 0},
#  {'text': 'Все консультации и экзамены в будние дни. Печально для работающих..',
#   'label': 0},
#  {'text': 'Да, но есть такие места, где запрещено на работе  пользоваться различными девайсами и нет интернета',
#   'label': 0},
#  {'text': 'Спасибо за консультацию', 'label': 0},
#  {'text': 'Я бы с удовольствием, но дата и время вступительных экзаменов все затрудняет',
#   'label': 0},
#  {'text': 'Добрый день. Смотрю таблицу "Количество бюджетных мест".             В первом столбце это количество мест с квотами указано? Или только места без квот? Например, специальность 09.03.01- 108 бюджетных мест, квоты 11,11,1,2,10. В общем конкурсе 108 мест или 108 минус все квоты? Спасибо.',
#   'label': 0},
#  {'text': 'Может этот вопрос уже был, но я спрошу))) реально так мало платных мест?',
#   'label': 0},
#  {'text': 'Подскажите, что опять случилось с сервисом дистанционной подачи? Он уже не заработает?',
#   'label': 0},
#  {'text': 'А как подать документы на сайте? В А то лк предоставляется только после подачи',
#   'label': 0},
#  {'text': 'Добрый день, подскажите , стал ли доступен сайт , для дистанционной подачи документов ?',
#   'label': 0},
#  {'text': 'Благодарю за ответ.', 'label': 0},
#  {'text': 'Добрый день. А при подаче заявление на поступление через личный кабинет нужно писать одно заявление и указывать все специальности или на каждую специальность свое заявление?',
#   'label': 0},
#  {'text': 'Подскажите, пожалуйста, при подаче документов через ЛК, через сколько примерно подтверждают паспорт?',
#   'label': 0},
#  {'text': 'Добрый вечер, где можно посмотреть с какими компаниями можно заключить целевое? А также договор можно будет рассматривать онлайн или обязательно приехать?',
#   'label': 0},
#  {'text': "Здравствуйте,решил узнать по поводу согласия на обработку данных. Я открыл образец и увидел что туда входят и  ''результаты вступительных испытаний''\nПолучается что документ о распространении данных нужно прислать после сдачи вступительных испытаний??",
#   'label': 0},
#  {'text': 'Добрый вечер, после подачи документов ,  через личный кабинет, через сколько времени фамилия , появляется в списках?',
#   'label': 0},
#  {'text': 'добрый вечер, где можно отслеживать списки поступающих?',
#   'label': 0},
#  {'text': 'Доброе утро, подскажите, пожалуйста, у вас на сайте есть списки подавших документов, там можно выбрать категорию льготы, я вижу  там особую и целевую, отдельной нет, это просто не подали ещё документов никто по ней ? Я правильно понимаю она потом будет отображается по названию-отдельная квота.',
#   'label': 0},
#  {'text': 'Ещё вопрос сын собирается поступать по отдельной квоте в ваш вуз,справка выдана по образцу Минобробразования, нужно ли ещё свидетельство о рождении, для подтверждения данных справки.',
#   'label': 0},
#  {'text': 'Спасибо .', 'label': 0},
#  {'text': 'Доброе утро, возникло два вопроса:\n1. При подачи документов в аспирантуру по машиностроению оказалось, что из всех специальностей из группы из бюджетных мест состоит только одна. Правильно ли я понимаю, что тогда бюджетных мест меньшинство?\n2. Подскажите, программа вступительных испытаний единая для всей группы специальностей машиностроения? То есть вопросы могут попасться в билете их всех блоков?',
#   'label': 0},
#  {'text': 'Как проводятся вступительные испытания для поступающих на целевое обучение?',
#   'label': 0},
#  {'text': 'Добрый день, хотелось бы уточнить по всем ли специальностям занятия проходят в основном здании? Есть второе здание на Фрейзере, какие занятия там проходят?',
#   'label': 0},
#  {'text': 'здравствуйте, а баллы не будут указываться до ранжированных списков?',
#   'label': 0},
#  {'text': 'Как понять проходишь ты по баллам ЕГЭ или нет?Есть ли те,у кого баллы больше?',
#   'label': 0},
#  {'text': 'Если есть те у кого больше то ниже их', 'label': 0},
#  {'text': 'После 27 и увидите..', 'label': 0},
#  {'text': 'Добрый день)\nпосле подачи заявления на рассмотрение модератора на почту пришло письмо  "Вам необходимо: 1) перейти в заявление, нажав “Просмотреть”; 2) На указанную Вами почту будет выслано Заявление."\nно заявление не приходило, в течение какого периода оно может прийти?',
#   'label': 0},
#  {'text': 'Добрый день. Подскажите пожалуйста, можно ли подать документы не выбирая квоту(по целевой), а через время заключив договор с предприятием, внести изменения? Или изменения уже не будет возможности внести.',
#   'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'Подскажите ещё пожалуйста, какой датой должны быть датированы договора на целевое обучение? Есть какой-то крайний срок?',
#   'label': 0},
#  {'text': 'По вступительным испытаниям, т. к ЛНР', 'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'в понедельник', 'label': 0},
#  {'text': 'Здравствуйте,жму кнопку «Сохранить информацию о направлениях подготовки и перейти к следующему шагу»\nи ничего не происходит (хотя по идее должно перекинуть в пункт «вступительные испытания») или я неправильно понял?',
#   'label': 0},
#  {'text': 'Если  поступаем по ЕГЭ,какой датой должен быть договлр на целевое?',
#   'label': 0},
#  {'text': 'Доброе утро. Подскажите, пожалуйста, если мы принесём оригинал аттестата, нам нужно дать согласие на какую-то одну специальность или на все 5, то есть аттестат будет отправлен на ту специальность, на которую мы пройдём?',
#   'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'А это можно сделать и после 27 июля?', 'label': 0},
#  {'text': 'Добрый день, подскажите,  если подача документов произошла через личный кабинет , на сайте вуза, возможно ли , это сделать повторно через Гос услуги, или уже система не пропустит ?',
#   'label': 0},
#  {'text': 'Спасибо за ответ.', 'label': 0},
#  {'text': 'да,всё хорошо. Дело двинулось вперёд)\nно появилась другая проблема, а именно, каким образом я должен достать скан на обработку персональных данных?',
#   'label': 0},
#  {'text': 'Подскажите, пожалуйста, у вас все учебные корпуса находятся на Савеловской? Спасибо',
#   'label': 0},
#  {'text': 'Спасибо!! Собираемся подавать документы ногами. В какое время наименьшее количество народа?)))',
#   'label': 0},
#  {'text': 'спасибо огромное!!!', 'label': 0},
#  {'text': 'Здравствуйте,   мы через личный кабинет, подали все документы. Но в конкурсных списках , фамилия пока не появляется.  Как выяснить , подтвержден наш личный кабинет или нет?',
#   'label': 0},
#  {'text': 'А есть связь с техническим отделом или только по почте ? Уже сутки как все документы были отправлены.',
#   'label': 0},
#  {'text': 'Согласие на обработку данных для распространения и согласие на обработку персональных данных (если нет 18 лет) подписывают родители?',
#   'label': 0},
#  {'text': 'Сколько рассматривается заявление на поступление на гос услугах?',
#   'label': 0},
#  {'text': 'Уже 2 сутки идут', 'label': 0},
#  {'text': 'А статус тот же', 'label': 0},
#  {'text': 'Запрашивали аттестат,после этого тишина', 'label': 0},
#  {'text': 'это было вчера в 12 часов дня', 'label': 0},
#  {'text': 'Понял,спасибо', 'label': 0},
#  {'text': 'Добрый день, пытаюсь подать заявления, но в индивидуальных достижениях нет "интеллектуальный мегаполис потенциал". За него дают баллы или нужно его вводить в какое то другое место?',
#   'label': 0},
#  {'text': 'Как подписывается согласие на обработку данных, если подаешь заявление через ЕПГУ? Скачать бланк, распечатать, подписать, сфотографировать,  загрузить и отправить?',
#   'label': 0},
#  {'text': 'А где нужно выбрать пункт участие в олимпиадах? Нужно нажимать не на индивидуальные достижения?',
#   'label': 0},
#  {'text': 'Да на что?', 'label': 0},
#  {'text': 'Там нет просто пункта "участие в олимпиадах"', 'label': 0},
#  {'text': 'Ок, выбрал', 'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'Добрый день. Были поданы документы , через личный кабинет , прошло более двух суток , наше заявление , до сих пор , даже не рассмотрено. Вы писали, что рассматривается все, в течении дня.',
#   'label': 0},
#  {'text': 'Хорошо. Спасибо.', 'label': 0},
# ...
#   'label': 0},
#  {'text': 'ДД! Когда последний день подачи оригинала на бюджет по общей квоте?',
#   'label': 0},
#  {'text': 'здравствуйте, опять сайт не работает чтобы подать документы?',
#   'label': 0},
#  {'text': 'Здравствуйте, написано что не поставил все подписи, хотя подписи стоят, кому можно обратиться?',
#   'label': 0},
#  {'text': 'написал', 'label': 0},
#  {'text': 'здравствуйте, как я могу узнать дни экзаменов ?', 'label': 0},
#  {'text': 'Добрый день, если заявление подано, в пофамильных списках фио есть, а в ранжированных нет,  появится позже, после обработки данных?',
#   'label': 0},
#  {'text': 'Добрый день! Подскажите, пожалуйста, до какого числа принимаются документы в магистратуру на бюджетные места?',
#   'label': 0},
#  {'text': 'Спасибо!', 'label': 0},
#  {'text': 'Спасибо за ответ! \nНа очно-заочную форму обучения на бюджет тоже до 11.08?',
#   'label': 0},
#  {'text': 'А можно сдать экзамены следующей волной (в августе) на бюджетные места очно-заочной формы обучения?',
#   'label': 0},
#  {'text': 'Такой вопрос,не конкретно про ваш вуз. Если места, выделенные для особой квоты не будут заполнены,то они переходят в общий конкурс или нет?',
#   'label': 0},
#  {'text': 'Спасибо.\nА подскажите, пожалуйста, ещё в одном вопросе. \nКак оформлять библиотечный список статей, из индивидуальных достижений?',
#   'label': 0},
#  {'text': 'Просто у вас на сайте одно время был образец оформления, а сейчас его нет.',
#   'label': 0},
#  {'text': 'Спасибо большое за информацию!', 'label': 0},
#  {'text': 'Здравствуйте, что выбрать в направлениях подготовки, бюджет или платную основу, если я иду по целевой квоте?',
#   'label': 0},
#  {'text': 'Через личный кабинет', 'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'А что такое отдельная квота и особое право?', 'label': 0},
#  {'text': 'Я просто из ЛНР и поступаю по вступительным, что мне выбрать?',
#   'label': 0},
#  {'text': 'Добрый день. Вчера подали документы в ваш университет. Сказали, что военной кафедры нет, но вот-вот появится. Можно более подробную информацию, в каком году планируется?',
#   'label': 0},
#  {'text': 'здравствуйте,как изменить приоритеты в госуслугах?', 'label': 0},
#  {'text': 'спасибо', 'label': 0},
#  {'text': 'Здравствуйте, а на каких направлениях больше всего программирования?',
#   'label': 0},
#  {'text': 'ок', 'label': 0},
#  {'text': 'а есть какой-то чат студентов, где можно обсудить это?',
#   'label': 0},
#  {'text': 'Добрый день. А личные кабинеты так и не работают?', 'label': 0},
#  {'text': 'Здравствуйте, ссылки на консультации на вступительные испытания будут отображаться в личном кабинете или на сайте смотреть?',
#   'label': 0},
#  {'text': 'а что если в заявлении для печати не отображаются:\nснилс, номер паспорта\nприоритеты расставлены неправильно',
#   'label': 0},
#  {'text': 'снилс и номер самому заполнить, а приоритеты не меняются, сколько бы не меняй их на сайте',
#   'label': 0},
#  {'text': 'Здравствуйте! Подскажите, пожалуйста, как у вас оцениваются вступительные испытания? Как в ЕГЭ с такими же первичными и вторичными баллами?',
#   'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'Здравствуйте\nПодскажите, где посмотреть приказы о зачислении с баллами прошлых лет --  2020, 2019\nСпасибо',
#   'label': 0},
#  {'text': 'На сайте только 2021', 'label': 0},
#  {'text': 'Понятно. Спасибо.', 'label': 0},
#  {'text': 'Скажите, пожалуйста, как происходит распределение внутри 09.03.03 и 09.03.04?',
#   'label': 0},
#  {'text': 'Спасибо, отправляйте', 'label': 0},
#  {'text': 'Выдает ошибку', 'label': 0},
#  {'text': 'Да, теперь доступно', 'label': 0},
#  {'text': 'Если подавать через гос улсуги,то никаких заявлений же не надо заполнять?',
#   'label': 0},
#  {'text': 'Где можно поставить галочку, о том что необходимо общежитие? Просто в заявлении у меня сразу выставлен крестик.',
#   'label': 0},
#  {'text': 'Понятно, спасибо', 'label': 0},
#  {'text': 'А что писать в заявлении, в разделе "Сведения о наличии индивидуальных достижений"?',
#   'label': 0},
#  {'text': 'Да', 'label': 0},
#  {'text': 'А вот "заявление поступающего на бюджетной основе" не нужно получается заполнять?',
#   'label': 0},
#  {'text': 'Ну да', 'label': 0},
#  {'text': 'Понятно, спасибо', 'label': 0},
#  {'text': 'А вот в разделе "Результаты вступительных испытаний", так как я из ЛНР, но не сдавал ЕГЭ, мне отмечать "не сдавшие ЕГЭ"?',
#   'label': 0},
#  {'text': 'Ну вот я из ЛНР и в этом году получил аттестат о среднем общем образовании',
#   'label': 0},
#  {'text': 'Хорошо', 'label': 0},
#  {'text': 'Это выдаёт при загрузке индивидуального достижения', 'label': 0},
#  {'text': 'Здравствуйте, если я выпускник прошлых лет и подаю заявление через Госуслуги, но при этом не могу прикрепить там волонтерскую книжку. Могу ли я отправить ее отдельно по e-mail и получить доп.балл?',
#   'label': 0},
#  {'text': 'Здравствуйте, общежитие предоставляется всем нуждающимся или есть конкурс?',
#   'label': 0},
#  {'text': 'Всем привет, где можно посмотреть списки лиц, подавших документы',
#   'label': 0},
#  {'text': 'Никак не могу найти нужную ссылку', 'label': 0},
#  {'text': 'что значит зелёная зона?', 'label': 0},
#  {'text': 'Здравствуйте, почему у меня на против 1 приоритета нет галочки о высшем приоритете?',
#   'label': 0},
#  {'text': 'Спасибо !', 'label': 0},
#  {'text': 'Перепроверила, но ни на одном из 5 нет', 'label': 0},
#  {'text': 'Нет', 'label': 0},
#  {'text': 'Спасибо!', 'label': 0},
#  {'text': 'Спасибо большое 🙏', 'label': 0},
#  {'text': 'А когда начнут выходить приказы по основному этапу зачисления?',
#   'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'Здравствуйте, подскажите пожалуйста, даются ли у вас справочные материалы на вступительных экзаменах?',
#   'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'Но здесь нет информации о справочных материалах. Меня интересует экзамен по физике, будут ли выданы хотя бы константы?',
#   'label': 0},
#  {'text': 'Здравствуйте! Подскажите, пожалуйста, у сына  сейчас, зеленая волна на 4 приоритете.  Возможно же, что не все принесут оригинал, кто на 1, 2 , 3 приоритет и тогда ребята с 4 приоритетом поднимутся выше?',
#   'label': 0},
#  {'text': 'Здравствуйте!  Скажите пожалуйста,  на электронные письма приемная комиссия отвечает, или удобнее другой способ связи?',
#   'label': 0},
#  {'text': 'Хорошо, спасибо', 'label': 0},
#  {'text': 'здравствуйте, по поводу экзаменов, например русский язык 19 июля в 10:00 до скольки экзамен?',
#   'label': 0},
#  {'text': 'то есть я могу начать экзамен и в 11:00 и в 12:00', 'label': 0},
#  {'text': 'до 13:00 правильно ?', 'label': 0},
#  {'text': 'Добрый день! Подскажите, пож- та, где можно посмотреть кцп на менеджмент, управление персоналом, экономика с учетом всех квот?',
#   'label': 0},
#  {'text': 'Спасибо, но там не указано сколько целевых место, отдельной квоты и тд и тп. Хочется знать более точные цифры',
#   'label': 0},
#  {'text': 'Если есть в виде таблицы, буду очень благодарна', 'label': 0},
#  {'text': 'как думаете много людей уйдут со списков, когда начнут подавать аттестаты?',
#   'label': 0},
#  {'text': 'а можете скинуть ссылку где будут проводиться экзамены ?',
#   'label': 0},
#  {'text': 'Здравствуйте,я 9 дней назад подавала к вам заявление через Госуслуги,мне стоит дождаться ,когда заявление станет "участвую в конкурсе",или лучше через сайт подать(с учётом того,что подавать оригинал я буду через галочку в госуслугах)',
#   'label': 0},
#  {'text': 'Если уже продали на госуслугах, то можно или подождать рассмотрения заявки или убрать на госуслугах и отправить через сайт вуза',
#   'label': 0},
#  {'text': 'Здравствуйте! Скажите, пожалуйста, через какое время моё заявление будет рассмотрено модератором?',
#   'label': 0},
#  {'text': 'Завтра просто последний день, меня просили срочно отправить исправное заявление',
#   'label': 0},
#  {'text': 'Здравствуйте,  личные кабинеты начали работать?', 'label': 0},
#  {'text': 'А до какого числа нужно подать заявление?', 'label': 0},
#  {'text': 'Ну просто мне написали вот, что необходимо срочно', 'label': 0},
#  {'text': 'Хорошо, спасибо', 'label': 0},
#  {'text': 'Я просто сдаю вступительные экзамены и первый экзамен уже послезавтра',
#   'label': 0},
#  {'text': 'Здравствуйте!  Мы у вас есть в конкурсных списках. Сын внёс изменения  в одном  направлении15 июля (подавали через госуслуги) в одном направлении. сейчас  Программная инженерия стоит статус передано в вуз и все на этом (без изменений). Можно узнать Вы нас видите? или сбой в госуслугах?',
#   'label': 0},
#  {'text': 'спасибо!', 'label': 0},
#  {'text': 'Здравствуйте, в личном кабинете написано, что подан оригинал, а я не подавал, это ошибка?',
#   'label': 0},
#  {'text': 'Да', 'label': 0},
#  {'text': 'Есть информация', 'label': 0},
#  {'text': 'можете тут помочь ?', 'label': 0},
#  {'text': 'я прикрепил аттестат', 'label': 0},
#  {'text': 'я с другой страны немогу звонить на российский номер', 'label': 0},
#  {'text': 'Есть какая-то информация?', 'label': 0},
#  {'text': 'а в течение какого времени придет ответ на почту?', 'label': 0},
#  {'text': 'я пополнил анкету, заявление и закрепил все документы но при отправке заявление в приёмную комиссию говорится нужно закрепить аттестат об образовании но я уже закрепил',
#   'label': 0},
#  {'text': 'Понял, спасибо', 'label': 0},
#  {'text': 'да всё хорошо но я не могу отправить заявку в приёмную комиссию',
#   'label': 0},
#  {'text': 'А убрать эту галочку в личном кабинете можно, а то тревожно😅',
#   'label': 0},
#  {'text': 'да', 'label': 0},
#  {'text': 'нет это заявление моего друга', 'label': 0},
#  {'text': 'Умаров Бахриддинджон Бахромджонович', 'label': 0},
#  {'text': 'Здравствуйте!  Смотрим ранжирование списки и  возник вопрос, почему у одних  абитуриентов бал ниже, а приоритет выше? Например : бал 250 -  высший приоритет 5, а бал 247 - высший приоритет- 3.',
#   'label': 0},
#  {'text': 'все понятно, спасибо!', 'label': 0},
#  {'text': 'Подскажите, пожалуйста, что это значит?', 'label': 0},
#  {'text': 'Там две черты, где именно мне подписать?', 'label': 0},
#  {'text': 'Хорошо', 'label': 0},
#  {'text': 'Отправил с подписью', 'label': 0},
#  {'text': 'Через личный кабинет', 'label': 0},
#  {'text': 'Хорошо', 'label': 0},
#  {'text': 'Почему в личном кабинете указано, что я подал оригинал, хотя ничего такого я не делал',
#   'label': 0},
#  {'text': 'Хорошо, спасибо', 'label': 0},
#  {'text': 'А можно ли выходить в туалет во время экзамена?', 'label': 0},
#  {'text': 'Хорошо', 'label': 0},
#  {'text': 'но тут нет же загран паспорт иностранного гражданина', 'label': 0},
#  {'text': 'хорошо', 'label': 0},
#  {'text': 'Подскажите, пожалуйста, на экскурсию нужно регистрироваться и абитуриенту и родителю? Или достаточно только абитуриенту?',
#   'label': 0},
#  {'text': 'Ноутбук нужен будет на 1 курсе?', 'label': 0},
#  {'text': 'А если его нет, и купить нет возможности?', 'label': 0},
#  {'text': 'Здравствуйте, почему личный кабинет не грузит? Как тогда получить ссылку на консультацию на вступительный экзамен?',
#   'label': 0},
#  {'text': 'Здравствуйте, не подскажите до скольки я смогу привести документы?',
#   'label': 0},
#  {'text': 'А через сколько он заработает? Просто через час начинаются консультации уже',
#   'label': 0},
#  {'text': 'Добрый день,я подавал документы через госуслуги. Я могу как то посмотреть списки поступающих? На госуслугах написано что списки появятся только 27',
#   'label': 0},
#  {'text': 'Что означает зелёная зона в списках?', 'label': 0},
#  {'text': 'В шифр что надо написать?', 'label': 0},
#  {'text': 'Что значит высший приоритет? Это 1-й приоритет?', 'label': 0},
#  {'text': 'как подключиться на консультацию ?', 'label': 0},
#  {'text': 'у меня заявка уже одобрена', 'label': 0},
#  {'text': 'да всё правильно', 'label': 0},
#  {'text': 'но не входит', 'label': 0},
#  {'text': 'всё всё зашёл', 'label': 0},
#  {'text': 'а где будет ссылка  на экзамен ?', 'label': 0},
#  {'text': 'спасибо большое за информации', 'label': 0},
#  {'text': 'Подскажите, Пдф файл работы , который я загружаю после вступительного, надо в цветном формате или чб?',
#   'label': 0},
#  {'text': 'а экзамен тоже через zoom будет или на сайте ?', 'label': 0},
#  {'text': 'Скажите, пожалуйста, в корректно ли в ЛК отражаются кцп? Написано, например, что 090302 имеет 74 места',
#   'label': 0},
#  {'text': 'У вас опять сайт лег?', 'label': 0},
#  {'text': 'здесь будет ссылка на экзамен ?', 'label': 0},
#  {'text': 'прокторинг через zoom я нашёл ссылку, а вот задания где будут отображатся  и где я буду вводить ответы ?',
#   'label': 0},
#  {'text': 'всё понятно', 'label': 0},
#  {'text': 'А можно вопрос. Нужно ли включать камеру? Просто у меня она не работает',
#   'label': 0},
#  {'text': 'ответ с клавиатуры вводить невозможно да как я понял нужно преобразовать в pdf листок на которой я решил задания а потом прикрепить ?',
#   'label': 0},
#  {'text': 'да потом как нужно вводить ответы ?', 'label': 0},
#  {'text': 'с телефона можно фотографировать и отправить ?', 'label': 0},
#  {'text': 'во время экзамена?', 'label': 0},
#  {'text': 'хорошо', 'label': 0},
#  {'text': 'Здравствуйте, в личном кабинете появилась ссылка на ВИ, но их не надо писать тем, кто поступает по егэ?',
#   'label': 0},
#  {'text': 'То есть это не только у меня появилось?', 'label': 0},
#  {'text': 'Ок, спасибо 🥺', 'label': 0},
#  {'text': 'Здравствуйте, а военная кафедра есть?', 'label': 0},
#  {'text': 'спасибо за информацию', 'label': 0},
#  {'text': 'Шпагин Тимофей Павлович', 'label': 0},
#  {'text': 'А можно же по Егэ?', 'label': 0},
#  {'text': 'Все отлично, спасибо', 'label': 0},
#  {'text': 'Добрый день, можно здесь получить информацию о предоставлении общежития? Сегодня у вас в вк появилась инфа, что бюджетникам гарантируем общежитие. По практике прошлого года нашим друзьям предоставили общежитие другого вуза, но в договоре прописали срок 9/10мес (точно сейчас не помню), т.о в июне/июле сложилась ситуация «с вещами на вызод», какова дальнейшая судьба этих студентов, строим планы чего ожидать нам в такой ситуации?',
#   'label': 0},
#  {'text': 'Подскажите, где смотреть списки подавших документ?!', 'label': 0},
#  {'text': 'здравствуйте, сколько времени даётся на вступительные испытания по математике и физике?',
#   'label': 0},
#  {'text': 'здравствуйте, а куда подгружать заявление, которое нужно было распечатать?',
#   'label': 0},
#  {'text': 'и что там нужно заполнять?', 'label': 0},
#  {'text': 'нет, это второй раз\nуже все подписи проставил и прикрепил',
#   'label': 0},
#  {'text': 'да', 'label': 0},
#  {'text': 'Здравствуйте! Я не нашёл своего результата экзамена по русскому языку, хотя мне сказали, что приняли мою работу.',
#   'label': 0},
#  {'text': 'А где можно уникальный код найти, просто по СНИЛС не могу отыскать',
#   'label': 0},
#  {'text': 'Спасибо!', 'label': 0},
#  {'text': 'Подскажите как отозвать документы. На сайте не загружается заявление на отзыв документов на поступление. Выдает ошибку.',
#   'label': 0},
#  {'text': 'Мы не можем скачать образец бланка на отзыв', 'label': 0},
#  {'text': 'Здравствуйте, в приёмной комиссии и на сайте сказано, что вступительный экзамены в магистратуру проходят в дистанционном формате. В расписании указана также указаны консультации, как я понял тоже в дистанционном формате. Как ко всему этому будет предоставляться доступ ? Будут ли ссылки заранее доступны в личном кабинете на сайте приёмной комиссии ? И как всё это будет проводится ? В формате конференции в zoom или discord ?',
#   'label': 0},
#  {'text': 'Добрый день,  223 балла +6 ГТО,если поступлю на бюджет, каковы шансы на общежитие?',
#   'label': 0},
#  {'text': 'На 15.03.04', 'label': 0},
#  {'text': 'Из Иркутска) точно за красной зоны)))', 'label': 0},
#  {'text': 'Здравствуйте, здесь была галочка но недавно она исчезла, почему ?',
#   'label': 0},
#  {'text': 'куда мне нужно отправить ?', 'label': 0},
#  {'text': 'я иностранный гражданин', 'label': 0},
#  {'text': 'или после зачисления ?', 'label': 0},
#  {'text': 'Спасибо!если подано через ГУ то ещё может на них поменять  направления до 25го?',
#   'label': 0},
#  {'text': 'Спасибо', 'label': 0},
#  {'text': 'А подскажите где можно учебные планы по ним посмотреть,  пожалуйста',
#   'label': 0},
#  {'text': 'Большое спасибо!!!', 'label': 0},
#  ...]

# %% [markdown]
# ### Датасет с обработкой

# %%
only_text_p = deepcopy(df[['text_preprocessed', 'label']])

# %%
dataset_p = only_text_p.to_dict('records')

# %%
ru_dataset_p = []

# %%
for d in dataset_p:
    if not(1072 <= ord(d['text_preprocessed'][0].lower()) <= 1103):
        continue
    ru_dataset_p.append({"text": d['text_preprocessed'], "label": d['label']})

# %%
len(dataset), len(ru_dataset), len(ru_dataset_p)
# Out:
# (25013, 24221, 24375)

# %% [markdown]
# ## Дообучение RuBert

# %% [markdown]
# ### Загрузка модели и токенайзера

# %%
MODEL_NAME = "cointegrated/rubert-tiny2"
# MODEL_NAME = "DeepPavlov/rubert-base-cased"

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
rb_model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=2)  # num_labels=2 для бинарной классификации
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cointegrated/rubert-tiny2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Подготовка выборок

# %%
def tokenize_function(examples):  # Почти лямбда функция для токенизации данных
    return tokenizer(examples["text"], padding="max_length", truncation=True, max_length=512)

# %% [markdown]
# #### Без предобработки

# %% [markdown]
# Загрузка датасета без предобработки

# %%
ru_df = pd.json_normalize(ru_dataset)

# %% [markdown]
# Преобразование в формат Hugging Face

# %%
dataset_hf = Dataset.from_pandas(ru_df)

# %% [markdown]
# Разделение на обучающую и тестовую выборки

# %%
rb_train_test_split = dataset_hf.train_test_split(test_size=0.2, seed=42)
rb_train_dataset = rb_train_test_split['train']
rb_test_dataset = rb_train_test_split['test']

# %%
ru_df_spam = ru_df.loc[ru_df['label'] == 1]

# %%
ru_df_spam
# Out:
#                                                     text  label
# 24070  Только что выиграл 26000 рублей в новом телегр...      1
# 24071  ЗАПУСТИЛИ ОФИЦИАЛЬНОЕ КАЗИНО С ОГРОМНЫМ ШАНСОМ...      1
# 24072  Заработал 800$ в новом телеграм казино, кому и...      1
# 24073  Выиграл 23000 рублей, играю в этом казике @Big...      1
# 24074  Выиграл 4500$ в олимпусе, играю тут @BigCasino...      1
# ...                                                  ...    ...
# 24216  в стиме началась раздача 10$ в честь дня рожде...      1
# 24217        Пиздец чекай https://t.me/SupeRRC0ntent_bot      1
# 24218  Прикинь чё нашёл, заходи быстрее discord.gg/cV...      1
# 24219  Привет, ты уже забрал подарок 20$ от стима? [s...      1
# 24220  Заходи сюда срочно !!! Мы тебя ждём !! discord...      1
#
# [147 rows x 2 columns]

# %% [markdown]
# Токенизация данных

# %%
rb_tokenized_train = rb_train_dataset.map(tokenize_function, batched=True)
rb_tokenized_test = rb_test_dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/19376 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4845 [00:00<?, ? examples/s]

# %% [markdown]
# #### С предобработкой

# %% [markdown]
# Загрузка датасета c предобработкой

# %%
ru_df_p = pd.json_normalize(ru_dataset_p)

# %% [markdown]
# Преобразование в формат Hugging Face

# %%
dataset_hf_p = Dataset.from_pandas(ru_df_p)

# %% [markdown]
# Разделение на обучающую и тестовую выборки

# %%
rb_train_test_split_p = dataset_hf_p.train_test_split(test_size=0.2, seed=42)
rb_train_dataset_p = rb_train_test_split_p['train']
rb_test_dataset_p = rb_train_test_split_p['test']

# %%
ru_df_spam_p = ru_df_p.loc[ru_df_p['label'] == 1]

# %%
ru_df_spam_p
# Out:
#                                                     text  label
# 24172     официальное телеграм казино играй прямо в боте      1
# 24173  топ 4 казино с самыми высокими шансами выигрыш...      1
# 24174  только что выиграл 26000 рублей в новом телегр...      1
# 24175  запустили официальное казино с огромным шансом...      1
# 24176  заработал 800 в новом телеграм казино кому инт...      1
# ...                                                  ...    ...
# 24370  в стиме началась раздача 10 в честь дня рожден...      1
# 24371                                пиздец чекай [LINK]      1
# 24372             прикинь чё нашёл заходи быстрее [LINK]      1
# 24373    привет ты уже забрал подарок 20 от стима [LINK]      1
# 24374             заходи сюда срочно мы тебя ждём [LINK]      1
#
# [199 rows x 2 columns]

# %% [markdown]
# Токенизация данных

# %%
rb_tokenized_train_p = rb_train_dataset_p.map(tokenize_function, batched=True)
rb_tokenized_test_p = rb_test_dataset_p.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/19500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4875 [00:00<?, ? examples/s]

# %% [markdown]
# ### Подготовка trainer'а

# %%
train_loader = DataLoader(rb_tokenized_train, batch_size=16, shuffle=True)
test_loader = DataLoader(rb_tokenized_test, batch_size=16)

# %%
train_loader_p = DataLoader(rb_tokenized_train_p, batch_size=16, shuffle=True)
test_loader_p = DataLoader(rb_tokenized_test_p, batch_size=16)

# %%
rb_training_args = TrainingArguments(
    output_dir="rb_results",  # Папка для сохранения модели
    eval_strategy="epoch",  # Оценка модели на каждом эпохе
    save_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,  # Количество эпох
    weight_decay=0.01,
    logging_dir="rb_logs",  # Логи обучения
    logging_steps=10,
    save_total_limit=2,  # Сохранение только последних двух моделей
)

# %%
rb_trainer = Trainer(
    model=rb_model,
    args=rb_training_args,
    train_dataset=rb_tokenized_train,
    eval_dataset=rb_tokenized_test,
    processing_class=tokenizer
)

# %%
rb_trainer_p = Trainer(
    model=rb_model,
    args=rb_training_args,
    train_dataset=rb_tokenized_train_p,
    eval_dataset=rb_tokenized_test_p,
    processing_class=tokenizer
)

# %% [markdown]
# ### Запуск дообучения

# %% [markdown]
# #### Перемещение модели на GPU

# %%
# Проверка доступности GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Используемое устройство: {device}")

# Переместите модель на GPU
rb_model.to(device)
# Out:
# Используемое устройство: cuda
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(83828, 312, padding_idx=0)
#       (position_embeddings): Embedding(2048, 312)
#       (token_type_embeddings): Embedding(2, 312)
#       (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-2): 3 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=312, out_features=312, bias=True)
#               (key): Linear(in_features=312, out_features=312, bias=True)
#               (value): Linear(in_features=312, out_features=312, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=312, out_features=312, bias=True)
#               (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=312, out_features=600, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=600, out_features=312, bias=True)
#             (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=312, out_features=312, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=312, out_features=2, bias=True)
# )

# %% [markdown]
# #### Тренировка

# %% [markdown]
# ##### Без предобработки данных

# %%
rb_trainer.train()
# Out:
#     <div>
#
#       <progress value='3633' max='3633' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3633/3633 06:08, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000200</td>
#       <td>0.002033</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000600</td>
#       <td>0.000699</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000100</td>
#       <td>0.000615</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=3633, training_loss=0.007789298103766402, metrics={'train_runtime': 369.5209, 'train_samples_per_second': 157.306, 'train_steps_per_second': 9.832, 'total_flos': 428647903100928.0, 'train_loss': 0.007789298103766402, 'epoch': 3.0})

# %%
rb_trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='303' max='303' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [303/303 00:14]
#     </div>
# {'eval_loss': 0.0006148326792754233,
#  'eval_runtime': 14.8641,
#  'eval_samples_per_second': 325.953,
#  'eval_steps_per_second': 20.385,
#  'epoch': 3.0}

# %% [markdown]
# Сохранение модели

# %%
rb_model.save_pretrained("../models/finetuned_rubert_tiny2")
tokenizer.save_pretrained("../models/finetuned_rubert_tiny2")
# Out:
# ('../models/finetuned_rubert_tiny2\\tokenizer_config.json',
#  '../models/finetuned_rubert_tiny2\\special_tokens_map.json',
#  '../models/finetuned_rubert_tiny2\\vocab.txt',
#  '../models/finetuned_rubert_tiny2\\added_tokens.json',
#  '../models/finetuned_rubert_tiny2\\tokenizer.json')

# %% [markdown]
# ##### С предобработкой данных

# %%
rb_trainer_p.train()
# Out:
#     <div>
#
#       <progress value='3657' max='3657' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3657/3657 06:15, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.003600</td>
#       <td>0.007194</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.005298</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.005155</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=3657, training_loss=0.0018951208413552619, metrics={'train_runtime': 375.2746, 'train_samples_per_second': 155.886, 'train_steps_per_second': 9.745, 'total_flos': 431391108096000.0, 'train_loss': 0.0018951208413552619, 'epoch': 3.0})

# %%
rb_trainer_p.evaluate()
# Out:
#     <div>
#
#       <progress value='305' max='305' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [305/305 00:15]
#     </div>
# {'eval_loss': 0.005155482329428196,
#  'eval_runtime': 15.0809,
#  'eval_samples_per_second': 323.257,
#  'eval_steps_per_second': 20.224,
#  'epoch': 3.0}

# %% [markdown]
# Сохранение модели

# %%
rb_model.save_pretrained("../models/finetuned_rubert_tiny2_p")
tokenizer.save_pretrained("../models/finetuned_rubert_tiny2_p")
# Out:
# ('../models/finetuned_rubert_tiny2_p\\tokenizer_config.json',
#  '../models/finetuned_rubert_tiny2_p\\special_tokens_map.json',
#  '../models/finetuned_rubert_tiny2_p\\vocab.txt',
#  '../models/finetuned_rubert_tiny2_p\\added_tokens.json',
#  '../models/finetuned_rubert_tiny2_p\\tokenizer.json')

# %% [markdown]
# ## Оценка качества моделей

# %%
# Тестовые сообщения
test_messages = [
    "Это честное сообщение от пользователя.",
    "🔥 Казино онлайн! Зарабатывай миллионы прямо сейчас! 💰💎",
    "Зарабатывай миллионы **онлайн** прямо сейчас!",
    "Работа на дому, легкий доход. Пиши в личку!",
    "Привет! Как дела? У меня всё отлично.",
    "Discover the hidden secrets of the digital market that top traders don’t want you to know! I’m seeking five motivated individuals who are committed to earning over $100K weekly in the digital market. Once you start seeing profits, I’ll require just 15% of your earnings as my fee. Please note: I’m only interested in working with five serious and dedicated people should send me a direct message or ask me (HOW) via TELEGRAM\n\nhttps://t.me/ancleroyofficial",
    "Discover the hidden secrets of the digital market that top traders don’t want you to know! I’m seeking five motivated individuals who are committed to earning over $100K weekly in the digital market. Once you start seeing profits, I’ll require just 15% of your earnings as my fee. Please note: I’m only interested in working with five serious and dedicated people should send me a direct message or click the link on my bio",
    "steam gift 50$ - steamcommunity.com/gift-card/pay/50\n@everyone",
    "Давайте **вместе** будем писать про казино в чатах!!! Присоединяйтесь!",
    "Как же надоели эти сообщения про казино",
    "Добрый день. Для подачи документов необходимо пройти регистрацию здесь: stankin.ru",
    "Добрый день. Для подачи документов необходимо пройти регистрацию здесь: https://stankin.ru",
    "Поступление – это почти что казино! Лотерея!"
]

# %%
classifier = pipeline("text-classification", model="../models/finetuned_rubert_tiny2", tokenizer="../models/finetuned_rubert_tiny2")
# Out:
# Device set to use cuda:0

# %%
classifier_p = pipeline("text-classification", model="../models/finetuned_rubert_tiny2_p", tokenizer="../models/finetuned_rubert_tiny2_p")
# Out:
# Device set to use cuda:0

# %%
for message in test_messages:
    result = classifier(message)
    print(message)
    print(result)
    print()
# Out:
# Это честное сообщение от пользователя.
# [{'label': 'LABEL_0', 'score': 0.9999589920043945}]
#
# 🔥 Казино онлайн! Зарабатывай миллионы прямо сейчас! 💰💎
# [{'label': 'LABEL_1', 'score': 0.999045193195343}]
#
# Зарабатывай миллионы **онлайн** прямо сейчас!
# [{'label': 'LABEL_1', 'score': 0.9961320161819458}]
#
# Работа на дому, легкий доход. Пиши в личку!
# [{'label': 'LABEL_0', 'score': 0.9998481273651123}]
#
# Привет! Как дела? У меня всё отлично.
# [{'label': 'LABEL_0', 'score': 0.9999611377716064}]
#
# Discover the hidden secrets of the digital market that top traders don’t want you to know! I’m seeking five motivated individuals who are committed to earning over $100K weekly in the digital market. Once you start seeing profits, I’ll require just 15% of your earnings as my fee. Please note: I’m only interested in working with five serious and dedicated people should send me a direct message or ask me (HOW) via TELEGRAM
#
# https://t.me/ancleroyofficial
# [{'label': 'LABEL_1', 'score': 0.9952722191810608}]
#
# Discover the hidden secrets of the digital market that top traders don’t want you to know! I’m seeking five motivated individuals who are committed to earning over $100K weekly in the digital market. Once you start seeing profits, I’ll require just 15% of your earnings as my fee. Please note: I’m only interested in working with five serious and dedicated people should send me a direct message or click the link on my bio
# [{'label': 'LABEL_1', 'score': 0.9962855577468872}]
#
# steam gift 50$ - steamcommunity.com/gift-card/pay/50
# @everyone
# [{'label': 'LABEL_1', 'score': 0.998494029045105}]
#
# Давайте **вместе** будем писать про казино в чатах!!! Присоединяйтесь!
# [{'label': 'LABEL_1', 'score': 0.9770578145980835}]
#
# Как же надоели эти сообщения про казино
# [{'label': 'LABEL_0', 'score': 0.999896764755249}]
#
# Добрый день. Для подачи документов необходимо пройти регистрацию здесь: stankin.ru
# [{'label': 'LABEL_0', 'score': 0.9999555349349976}]
#
# Добрый день. Для подачи документов необходимо пройти регистрацию здесь: https://stankin.ru
# [{'label': 'LABEL_0', 'score': 0.9999465942382812}]
#
# Поступление – это почти что казино! Лотерея!
# [{'label': 'LABEL_1', 'score': 0.6101247072219849}]

# %%
for message in test_messages:
    # message = preprocess_text(message)
    result = classifier_p(message)
    print(message)
    print(result)
    print()
# Out:
# Это честное сообщение от пользователя.
# [{'label': 'LABEL_0', 'score': 0.999996542930603}]
#
# 🔥 Казино онлайн! Зарабатывай миллионы прямо сейчас! 💰💎
# [{'label': 'LABEL_1', 'score': 0.9999890327453613}]
#
# Зарабатывай миллионы **онлайн** прямо сейчас!
# [{'label': 'LABEL_1', 'score': 0.9999821186065674}]
#
# Работа на дому, легкий доход. Пиши в личку!
# [{'label': 'LABEL_1', 'score': 0.9511370062828064}]
#
# Привет! Как дела? У меня всё отлично.
# [{'label': 'LABEL_0', 'score': 0.9999966621398926}]
#
# Discover the hidden secrets of the digital market that top traders don’t want you to know! I’m seeking five motivated individuals who are committed to earning over $100K weekly in the digital market. Once you start seeing profits, I’ll require just 15% of your earnings as my fee. Please note: I’m only interested in working with five serious and dedicated people should send me a direct message or ask me (HOW) via TELEGRAM
#
# https://t.me/ancleroyofficial
# [{'label': 'LABEL_1', 'score': 0.9999837875366211}]
#
# Discover the hidden secrets of the digital market that top traders don’t want you to know! I’m seeking five motivated individuals who are committed to earning over $100K weekly in the digital market. Once you start seeing profits, I’ll require just 15% of your earnings as my fee. Please note: I’m only interested in working with five serious and dedicated people should send me a direct message or click the link on my bio
# [{'label': 'LABEL_1', 'score': 0.9999841451644897}]
#
# steam gift 50$ - steamcommunity.com/gift-card/pay/50
# @everyone
# [{'label': 'LABEL_1', 'score': 0.9999847412109375}]
#
# Давайте **вместе** будем писать про казино в чатах!!! Присоединяйтесь!
# [{'label': 'LABEL_1', 'score': 0.9999570846557617}]
#
# Как же надоели эти сообщения про казино
# [{'label': 'LABEL_0', 'score': 0.9999804496765137}]
#
# Добрый день. Для подачи документов необходимо пройти регистрацию здесь: stankin.ru
# [{'label': 'LABEL_0', 'score': 0.9999963045120239}]
#
# Добрый день. Для подачи документов необходимо пройти регистрацию здесь: https://stankin.ru
# [{'label': 'LABEL_0', 'score': 0.9999955892562866}]
#
# Поступление – это почти что казино! Лотерея!
# [{'label': 'LABEL_1', 'score': 0.9999589920043945}]
