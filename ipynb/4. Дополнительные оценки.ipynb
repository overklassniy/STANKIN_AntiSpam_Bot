# %% [markdown]
# # Дополнительные оценки качества моделей

# %% [markdown]
# ## Импорт необходимых библиотек

# %%
import os
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix
from transformers import pipeline
from scipy.sparse import hstack
from datasets import Dataset
from copy import deepcopy
import regex
import re
import emoji

# %% [markdown]
# ## Чтение тестовых данных

# %% [markdown]
# ### Данные с чистыми сообщениями

# %% [markdown]
# `data/test_clear.json` – `.json` файл структуры `[{"text": "blablabla", "label": 0}]`, где ключ `text` представляет текстовое значение сообщения, а ключ `label` – класс сообщения (0: безопасное, 1: опасное).
# Сообщения были собраны из чата "СТАНКИН" смежного Telegram канала.

# %%
df_clear = pd.read_json('../data/test_clear.json')

# %%
df_clear_short = df_clear.head(1000)

# %%
df_clear_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    1000 non-null   object
#  1   label   1000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 15.8+ KB

# %%
df_clear_short.head()
# Out:
#                                                 text  label
# 0                                    Очень похоже)❤️      0
# 1                                 Грозный СТАНКИН)))      0
# 2                                                         0
# 3  Здравствуйте, а куда можно написать по вопроса...      0
# 4  Здравствуйте, напишите свой вопрос в данный ча...      0

# %% [markdown]
# ### Данные со спам сообщениями

# %% [markdown]
# `data/parsed_lols_2023.txt` – `.txt` файл с набором спам-сообщений.
# Файл был получен с [lols.bot](https://lols.bot/2023/)

# %%
parsed_lols_2023 = open('../data/parsed_lols_2023.txt', 'r', encoding='utf-8').readlines()

# %%
for i in range(len(parsed_lols_2023)):
    parsed_lols_2023[i] = parsed_lols_2023[i].replace('<br/>', '', 1).strip().replace('<br/>', '\n')

# %%
len(parsed_lols_2023)
# Out:
# 32437

# %%
parsed_lols_2023_short = parsed_lols_2023[:999]

# %%
df_spam = pd.DataFrame()
df_spam['text'] = parsed_lols_2023_short
df_spam['label'] = [1] * len(parsed_lols_2023_short)

# %%
df_spam.head()
# Out:
#                                                 text  label
# 0  🤝ƃАЗA ЧAT𝖮B ᎩCЛᎩГ🤝 + Б𝖮Т AВTОРАСCЫЛKИ🚀<br>\n❗️...      1
# 1                                          دانیالللل      1
# 2  🤙🏻🤘🏻Caмo𝚎 cлoжное нa сеpoм рынке — это найти н...      1
# 3                                          𝙇 𝘼 𝙈 𝙄 𝘼      1
# 4  🔲DROP SERVICE🔲<br><br>☕️ 𝔸ℝ𝔸𝔹𝕀ℂ𝔸×ℝ𝕆𝔹𝕌𝕊𝕋𝔸 ☕️ \n...      1

# %% [markdown]
# ### Объединение данных

# %%
df_test = pd.concat([df_clear_short, df_spam])

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1999 entries, 0 to 998
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    1999 non-null   object
#  1   label   1999 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 46.9+ KB

# %%
df_test.head()
# Out:
#                                                 text  label
# 0                                    Очень похоже)❤️      0
# 1                                 Грозный СТАНКИН)))      0
# 2                                                         0
# 3  Здравствуйте, а куда можно написать по вопроса...      0
# 4  Здравствуйте, напишите свой вопрос в данный ча...      0

# %% [markdown]
# ## Обработка данных

# %% [markdown]
# ### Создание новых столбцов с числовыми данными

# %% [markdown]
# В спам сообщениях очень часто используются эмодзи, ссылки, теги (`@`), много новых строк (`\n`) и лишних пробелов, так что их количество в сообщении может играть большую роль в классификации сообщений

# %% [markdown]
# #### Функции для подготовки текста и дополнительных числовых данных

# %% [markdown]
# > Эти же функции находятся в `../utils/preprocessing.py`.

# %%
def count_emojis(text: str) -> int:
    """
    Считает количество эмодзи в тексте.

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        int: Количество найденных эмодзи.
    """
    # Разбиваем текст на "графемные кластеры" (учитывая составные эмодзи)
    data = regex.findall(r'\X', text)
    # Считаем эмодзи
    emoji_counter = sum(emoji.is_emoji(word) for word in data)
    return emoji_counter

# %%
def count_newlines(text: str) -> int:
    """
    Считает количество символов новой строки (\n) в тексте.

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        int: Количество символов новой строки.
    """
    # Подсчёт символов новой строки
    newline_count = text.count('\n')
    return newline_count

# %%
def count_whitespaces(text: str) -> int:
    """
    Считает количество последовательных пробелов (два или более) в тексте.

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        int: Количество найденных последовательных пробелов.
    """
    # Считаем последовательности из двух и более пробелов
    extra_spaces_count = len(re.findall(r'\s{2,}', text))
    return extra_spaces_count

# %%
# Регулярное выражение для ссылок
url_pattern = r'(https?://[^\s]+|www\.[^\s]+|[a-zA-Z0-9.-]+\.[a-zA-Z]{2,}(?:/[^\s]*)?)'

# %%
def count_links(text: str) -> int:
    """
    Считает количество ссылок в тексте.

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        int: Количество найденных ссылок.
    """
    # Найти все ссылки в тексте
    links = re.findall(url_pattern, text)
    return len(links)

# %%
def count_tags(text: str) -> int:
    """
    Считает количество упоминаний (тегов) в тексте.

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        int: Количество найденных тегов.
    """
    # Подсчёт символов "@" как маркеров тегов
    tag_count = text.count('@')
    return tag_count

# %% [markdown]
# Удаление пунктуации и эмодзи, приведение к нижнему регистру может снизить шум и сложность модели

# %%
def remove_emojis(text: str) -> str:
    """
    Удаляет все эмодзи из текста.

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        str: Текст без эмодзи.
    """
    # Разбиваем текст на "графемные кластеры"
    data = regex.findall(r'\X', text)
    # Удаляем все эмодзи
    text_without_emojis = ''.join(word for word in data if not emoji.is_emoji(word))
    return text_without_emojis

# %% [markdown]
# Ссылки и тэги без пунктуации превращаются в набор латинских символов, что будет мешать работе модели, но при этом их нельзя удалять из текстов, так как это важные маркеры. Поэтому их необходимо заменить на что-то вроде `[LINK]` и `[TAG]`

# %%
def replace_links(text: str) -> str:
    """
    Заменяет все ссылки в тексте на "[LINK]".

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        str: Текст с заменёнными ссылками.
    """
    # Заменить ссылки на [LINK]
    text = re.sub(url_pattern, '[LINK]', text)
    return text

# %%
def replace_tags(text: str) -> str:
    """
    Заменяет все упоминания (теги) в тексте на "[TAG]".

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        str: Текст с заменёнными тегами.
    """
    # Регулярное выражение для тегов
    tag_pattern = r'@[a-zA-Z0-9_]+'
    # Замена тегов на [TAG]
    text = re.sub(tag_pattern, '[TAG]', text)
    return text

# %%
def preprocess_text(
        text: str,
        lower: bool = True,
        remove_punctuation: bool = True,
        remove_emoji: bool = True,
        remove_whitespaces: bool = True,
        remove_links: bool = True,
        remove_tags: bool = True
) -> str:
    """
    Предобрабатывает текст, включая нормализацию регистра, удаление пунктуации, эмодзи, ссылок, тегов и пробелов.

    Параметры:
        text (str): Исходный текст.
        lower (bool): Приводить ли текст к нижнему регистру (по умолчанию True).
        remove_punctuation (bool): Удалять ли пунктуацию (по умолчанию True).
        remove_emoji (bool): Удалять ли эмодзи (по умолчанию True).
        remove_whitespaces (bool): Удалять ли лишние пробелы (по умолчанию True).
        remove_links (bool): Удалять ли ссылки (по умолчанию True).
        remove_tags (bool): Удалять ли теги (по умолчанию True).

    Возвращает:
        str: Обработанный текст.
    """
    # Приведение текста к нижнему регистру
    if lower:
        text = text.lower()
    # Замена ссылок на [LINK]
    if remove_links:
        text = replace_links(text)
    # Замена тегов на [TAG]
    if remove_tags:
        text = replace_tags(text)
    # Удаление пунктуации
    if remove_punctuation:
        text = re.sub(r'[^\w\s]', '', text)  # Удаляет пунктуацию
        # Восстановление [LINK] после очистки пунктуации
        if remove_links:
            text = text.replace('LINK', '[LINK]')
        # Восстановление [TAG] после очистки пунктуации
        if remove_tags:
            text = text.replace('TAG', '[TAG]')
    # Удаление эмодзи
    if remove_emoji:
        text = remove_emojis(text)
    # Удаление лишних пробелов и символов новой строки
    if remove_whitespaces:
        text = re.sub(r'\s+', ' ', text).strip()
    return text

# %% [markdown]
# #### Подготовка текста и дополнительных числовых данных

# %%
emojis_count = []
newlines_count = []
whitespaces_count = []
links_count = []
tags_count = []
for text in df_test['text']:
    emojis_count.append(count_emojis(text))
    newlines_count.append(count_newlines(text))
    whitespaces_count.append(count_whitespaces(text))
    links_count.append(count_links(text))
    tags_count.append(count_tags(text))

# %%
df_test['emojis'] = emojis_count
df_test['newlines'] = newlines_count
df_test['whitespaces'] = whitespaces_count
df_test['links'] = links_count
df_test['tags'] = tags_count

# %%
df_test.head()
# Out:
#                                                 text  label  emojis  newlines  \
# 0                                    Очень похоже)❤️      0       1         0
# 1                                 Грозный СТАНКИН)))      0       0         0
# 2                                                         0       0         0
# 3  Здравствуйте, а куда можно написать по вопроса...      0       1         0
# 4  Здравствуйте, напишите свой вопрос в данный ча...      0       0         2
#
#    whitespaces  links  tags
# 0            0      0     0
# 1            0      0     0
# 2            0      0     0
# 3            0      0     0
# 4            1      1     0

# %%
texts = list(deepcopy(df_test['text']))
for text_i in range(len(texts)):
    temp = preprocess_text(texts[text_i])
    if not temp:
        temp = np.NaN
    texts[text_i] = temp

# %%
texts
# Out:
# ['очень похоже',
#  'грозный станкин',
#  nan,
#  'здравствуйте а куда можно написать по вопросам общежития туда попадают на конкурсной основе какие примерно шансы',
#  'здравствуйте напишите свой вопрос в данный чат [LINK]',
#  'день рождения станкина',
#  nan,
#  nan,
#  'подскажите всем ли дают общежитие',
#  'а что делать тем кто был не допущен ждать 07072023 или сразу идти в военкомат ребёнок из многодетной семьи',
#  'сегодня был сказали ждать до 07072023 а чего ждать если отчисляют или ещё чтото то пусть сразу говорят ребёнку тогда нужно подавать заявку в другой или в армию идти почему преподаватели молчали ни кто с родителями не связывался даже в колледже такого безобразия нет',
#  'это очень круто предлагаем пообщаться по теме проекта более плотно как найти юлию и елизавету девочки поставьте на это сообщение если вы готовы обсудить возможности приземления вашего проекта в станкине или напишите на почту prostankin[LINK] пожалуйста',
#  'как закалялся станкиновец написал бы николай островский',
#  'альберт хофманн мой трудный станкиновец',
#  'станкиновец и его команда',
#  'невероятные приключения станкиновца',
#  'станкиновец нашего времени',
#  'история одного станкиновца',
#  'станкиновцу на руси жить хорошо',
#  'молодцы',
#  'круто',
#  'классно',
#  'достойно но стремимся к большему коллеги',
#  'я бы первое слово поменял бы на самые',
#  'отличные варианты',
#  'возьмём на заметку эти варианты',
#  'командные или индивидуальные соревнования на основе компьютерных игр и есть киберспорт достаточно доходный и интересный вид спорта',
#  'с праздником желаем чтобы в семьях царили только мир гармония и взаимопонимание',
#  'практика',
#  nan,
#  'я когда заканчивал новый корпус только закладывали',
#  'подскажите как узнать минимальный проходной балл в магистратуру на программную инженерию за 2022 год чтобы примерно понимать что будет в этой приёмной кампании',
#  'да но им поведение сложно учитывать а вот с помощью математической выборки и анализа может сделать вероятный ответ',
#  'гто золотое учитывается',
#  'в магу',
#  'да это все понятно не информативные сайты потому и спросил кстати ответ так и не получил',
#  'открытка супер',
#  'с днем рождения в этот прекрасный день много лет назад был основан наш университет чтобы превратиться в альмаматер для многих талантливых людей настоящих профессионалов своего дела с праздником и пусть будущие поколения студентов будут достойны своих предшественников',
#  'горжусь тем что закончил наш любимый станкин',
#  'с днём рождения долгих лет процветания университету',
#  nan,
#  'а где найти расписание программной инженерии',
#  'умничка',
#  'картинки просто великолепные идеально передали атмосферу москвы молодцы',
#  'классные фотографии',
#  nan,
#  nan,
#  'молодцы всех выпускников поздравляем',
#  'молодцы егорьевский филиал на втором месте 12 красных дипломов',
#  'бравотолько так и только вперед наш университет надежная опора нашей страны',
#  'поздравляю всех ребят молодцы',
#  nan,
#  'что за мужчина',
#  'здравствуйте у вас срок приёма документов до 18 включительно',
#  'да это 18 включительно да например до 1809 вечера',
#  'просто я вчера подал заявление её ещё не приняли',
#  'спасибо',
#  'меня зовут юлдошев давлатджон шухратович',
#  'уточнили',
#  'спасибо',
#  'там на согласие обработки персональных данных написано чтобы я вставил актуальную дату я вот с этим не понял что делать',
#  'тут сегодняшнее число написать',
#  'у меня попросили согласие родителей на распространение данных так как я несовершеннолетний но я не понял куда её прикреплять можете помочь пожалуйста',
#  'спасибо я им в почту отправил',
#  'когда начнутся вступительные испытания',
#  'у вас нету группы либо чата в телеграме или ватсапе для общения и знакомства с будущими студентами',
#  'спасибо за предупреждение',
#  'спасибо действительно мошенники во всех сферах активизировались сейчас',
#  'здравствуйте экзамены когда начнутся',
#  'но мне на почту не пришла ссылка на экзамен по русскому языку что делать и экзамен будет доступен до вечера',
#  'ало',
#  nan,
#  'ало',
#  'здравствуйте',
#  'мне не пришла ссылка на сегодняшний экзамен по русскому',
#  'что делать',
#  'добрый день а когда это было абитуриентам этого года очень бы хотелось сейчас такое мероприятие посетить день открытых дверей в ближайшее время не планируется',
#  'почему мне не прислали мне ссылку на сегодняшний экзамен по русскому языку',
#  'мне не прислали ссылку на сегодняшний экзамен',
#  'информацию вы сможете уточнить у сотрудников приёмной комиссии по номеру 74999733849',
#  'я иностранный гражданин не могу позвонить в этот номер',
#  'можете написать пройдя по этой ссылке [LINK]',
#  'скиньте мне пожалуйста заявление на сдачу в резервный день',
#  'ало',
#  'обратитесь с этим вопросом в приёмную комиссию по электронной почте abitur[LINK] или по ссылке [LINK]',
#  'закат на волге',
#  'хелп пропала вкладка с ссылкой в эос и на экзамены',
#  'спасибо',
#  'так же оценки не появились за два экзамена ну эт ладно но по информатики завтра экзамен просто c',
#  'а ссылки нет',
#  'подскажите получится решить проблему перед экзаменом',
#  'неплохо',
#  'народ вы не знаете что надо вписать в бланке согласие на обработку персональных данных разрешенных субъектом персональных данных для распространения где надо написать наименование или фио оператора',
#  nan,
#  'спасибо',
#  'извиняюсь как сириякубавьетнамкитайсудан и монголия относятся к европе',
#  'как здорово что школьники приехали из разных регионов страны чтобы узнать больше о флагманских инженерных вузах включая станкин надеюсь им понравится их ознакомительная лекция и они найдут для себя интересные перспективы',
#  'как здорово что город приозерск собрал команды со всего мира для чемпионата европы по городошному спорту зрелищные игры и эмоции этого мероприятия действительно захватывают признаться мне тоже было бы интересно попробовать себя в этой игре',
#  'замечательная программа обучения для молодых инженеров реальная практика в крупных компаниях и высокая трудоустройство выпускников это то что меня впечатляет надо подавать документы сейчас и не откладывать на август',
#  'новая версия хита парк горького звучит потрясающе сергей арутюнов продемонстрировал свои таланты не только как учёный но и как музыкант очень интересно услышать классическую песню на русском языке отличный выбор продюсера',
#  'классно видеть молодых талантливых ребят которые не боятся новых вызовов и активно развиваются в технологической сфере их энтузиазм и интерес к различным специальностям вдохновляют не перестаю удивляться и восхищаться их достижениями',
#  'очень интересно узнать о дне крещения руси эта дата напоминает о важной исторической вехе когда христианство пришло на нашу землю благодарен за информацию и обязательно узнаю больше об этом празднике',
#  'отличная и примерная история восхищаюсь решимостью и трудолюбием бенсона уверен что его амбиции и знания приведут его к успеху где бы он ни продолжал свое образование желаю ему удачи в будущем и осуществления его мечты',
#  'здравствуйте подскажите пожалуйста мне обращать внимание на какой из пунктов высшего приоритета написано нет',
#  'привет я тоже абитуриентка сегодня звонила узнавала куда смотреть так поняла на место с учётом приоритета и оригинала но оно очень сильно зависит от твоего места с учётом оригинала тк 3 числа те кто подали оригинал баллы выше твоих но видимо их нет в списке с учётом и приоритета и оригинала потому что их приоритет на это направление меньше твоего в случае если при зачислении они откажутся от их приоритетов один и не поступят на свои приоритеты 1 то твоё место сместится',
#  'ну то есть если эти 58 человек до тебя не поступят на другие направления то они тебя сместят',
#  'спасибо',
#  'приветствую что касается станкиновских часов скорее всего они работают как обычно ведь время не знает отдыха',
#  'где ранжированные списки',
#  'на официальном сайте в верхнем левом углу три точки раздел бакалавриат и специалитет списки и приказы ранжированные списки',
#  'андрей делает правильный выбор следуя традициям семьи учеба оказалась не такой уж и трудоемкой благодаря отзывчивым преподавателям интересно с какими еще неожиданностями андрей столкнется',
#  nan,
#  'добрый день подскажите поступили на целевое через госуслуги когда подавать оригиналы документов',
#  'до какой даты необходимо предоставить оригиналы в приёмную комиссию можно ли это сделать по приезду к заселению в общежитие когда будет заселение в общежитие',
#  'что да',
#  'вопрос был 1 до какой даты необходимо предоставить оригинал 2 когда заселение в общежитие',
#  'какое прекрасное время чтобы отметить дружбу давайте поделимся своими любимыми песнями о друзьях и вспомним о всех замечательных моментах которые мы провели вместе всем желаю радостного воскресенья',
#  'если с другом вышел в путь веселей дорога',
#  'молодежь получает реальный опыт работы в индустрии благодаря практике в группе компаний изолятор такие возможности помогут студентам развить свои навыки и стать востребованными специалистами в будущем',
#  'очень рады за этого день',
#  'отличные новости университет мгту станкин продолжает активно развиваться и сотрудничать с ведущими компаниями поздравляю выпускника со встречей с родителями это наверняка было незабываемо а студентка станкина молодец 13е место в гонках большой успех удачи всем в дальнейших достижениях дайджестнедели',
#  'здравствуйте а 3 числа в какой промежуток времени принимают оригиналы',
#  'очень интересно узнать больше о сотрудниках станкина и их участии в учебном процессе и обеспечении безопасности прекрасно что они также проявляют творческие навыки домашний музей с русской старинной утварью и бытовыми приспособлениями звучит увлекательно наверняка каждый экспонат имеет свою уникальную историю хочется узнать как использовался предмет с галочкой',
#  'отделение зёрен от травяной составляющей',
#  'тогда не знаю',
#  'это гребец',
#  'для стирки',
#  'ну блин',
#  'для засыпания зёрен в мешки',
#  'ну как так',
#  'для вязания',
#  'для изготовки сетей',
#  'спасибо',
#  'нет это рубель',
#  'наверное',
#  'дед плохому не научит',
#  'спасибо',
#  'именно так и поступлб',
#  'деревянная доска с вырубленными поперечными желобками для катания белья накатки кож предмет домашнего обихода использовался для выколачивания и глажения белья отжатое вручную бельё наматывали на валик или скалку и раскатывали рубелем',
#  'красивые фото утро в станке всегда принимается с особой радостью надеюсь у вас будет активный и полезный день',
#  'поздравляю всех первокурсников с зачислением это начало важного этапа в вашей жизни желаю успешной учебы и интересных знакомств в станкине',
#  'молодежь станкина прекрасно представила россию на форуме россияафрика горжусь нашими учеными лилией туктамышевой и романом хмыровым которые получили гранты и стипендии президента рф продолжайте вести нашу страну к новым научным высотам',
#  'спасибо какие наши дальнейшие действия',
#  'вспоминать заново после егэ все программу школьную',
#  'хорошая идея но всё же',
#  'подписывать ни чего не надо',
#  'здравствуйте на ивт учат на программистов',
#  'отличный пост лето было невероятное а август обещает быть еще более запоминающимся надеюсь каждый найдет свои приключения и радость в этом месяце удачи всем',
#  'важно помнить о героях первой мировой войны и их подвигах которые сделали эту войну значимой для истории россии и всего мира создание такого портала является важным шагом для сохранения памяти о событиях тех лет',
#  'круто участие в таком масштабном мероприятии это большая честь желаю удачи семену королеву и виктору ипатову в презентации своего проекта и в соревнованиях вперед станкиновцы',
#  'юлия ершова определись уже',
#  'здорово отличная возможность для молодых предпринимателей реализовать свои мечты и найти партнеров соревнование в двух лигах так что каждый найдет свое место не упусти шанс и отправляй заявку прямо сейчас',
#  'поздравляю владислава египко и владимира клачкова с получением грантов очень интересные проекты обладающие большим потенциалом уверен что эти ребята смогут успешно развивать свои идеи и внести вклад в инновационную сферу удачи',
#  'отличная возможность отдохнуть на черноморском побережье пожелаем ребятам высоких результатов в соревнованиях и море положительных эмоций на отдыхе',
#  'молодец абитуриент не стоит унывать изза егэ ведь у тебя есть еще шанс поступить в станкин спешу напомнить что 3 августа последний день для сдачи оригиналов так что не теряй времени и срочно отправляйся в приемную комиссию',
#  'юлия ершовавы разбиваете мне сердце',
#  'поздравляю станкин с вхождением в экспертное сообщество союза дпо это отличная возможность для университета развивать дополнительное профессиональное образование и укреплять связи с зарубежными партнерами желаю успехов в реализации мероприятий и новых сотрудничеств',
#  'сегодня приёмная комиссия до скольки работает',
#  'до 2100',
#  'это так здорово видеть что университет не просто отдыхает летом а активно обновляется и готовится к новому учебному году спасибо сотрудникам станкина за их труд и старания чтобы студенты имели лучшие условия для обучения очень интересно попасть в закулисье и увидеть как все происходит',
#  'отличные работы молодые фотографы действительно поразили своим талантом и профессионализмом поздравляю победителей и всех участников конкурса',
#  'интересно узнать о таких исторических фактах уникальная кафедра которая не только обучает но и проводит серьезные научные исследования продолжать традиции и стремиться к новым вершинам это замечательно',
#  'здравствуйте а для подачи оригиналов нужен только аттестат и паспорт',
#  'да',
#  'дорогие абитуриенты не упускайте возможность поступить в желаемый вуз спешите предоставить оригиналы документов до 1200 в станкине вадковский переулок д1 удачи вам',
#  'если я отправлю заявление с госуслуг успеют отработать',
#  'а что означает зеленая зона в конкурсных списках',
#  'а какого числа можно будет понимать попал или не попал на факультет',
#  'завтра',
#  'в течении дня',
#  'понятно спасибо',
#  'а в госуслугах должен быть статус что то вроде подал оригинал',
#  'галочка должна стоять',
#  'после обновления данных приемной комиссии',
#  'уже полтора часа назад подал что то нет галочки походу пролёт хотя подавал очно',
#  'а можно фио полностью ваше',
#  'имаев ян дмитриевич',
#  'у нас в системе всё хорошо оригинал проставлен это главное в госуслугах чуть позже добавится',
#  'хорошо спасибо',
#  'всётаки волнительно было самостоятельно подавать документы в приёмную комиссию станкина жду с нетерпением результата и надеюсь услышать заветные слова вы поступили а какими красками абитуриенты видят студенческую жизнь в станкине очень интересно узнать',
#  'а когда скажут приняли не приняли',
#  'увидишь в списках себя по снилсу или в личном кабинете будет указаночто ты зачислен в такомто приказе',
#  'а это до приказа будет видно',
#  'некак только приказы будутто появится',
#  'спасибо',
#  'а так тебе ещё стрессовать до выхода приказахахаха',
#  nan,
#  'удачи',
#  'а когда он будет',
#  '9 августа',
#  'спасибо',
#  'ну ребятинфа же вся на сайте есть',
#  'тут могут ответить',
#  'и заходить никуда не надо',
#  'нужно ли мне привозить аттестат если я подавал через госуслуги',
#  'впечатляющее количество участников и номинаций в конкурсе поздравляю всех победителей и призёров участие в таких мероприятиях развивает творческие способности и увлечение техникой отличная инициатива',
#  'это отличная возможность вернуться к хакатонам и открыться новым приключениям с командой единомышленников не теряйте времени и подавайте заявку на участие прямо сейчас удачи в создании компьютерной игры и получении ценных призов',
#  'вот в теории если я попал в вуз то когда нужно будет фотки 3х4 нести и в каком количестве и справку 086',
#  'привозить аттестат на данный момент для зачисления не надо если есть отметка в госуслугах оригинал необходимо принести на собрания первркурсников в конце августа расписание будет вывешено позже',
#  'ближе к концу августа на первые собрания первокурсников расписание будет позже',
#  'а как относить оригинал на собрание первокурсников если его отдал',
#  'сказали просто что он в пк лежит и дали бумажку',
#  'если отдали уже не надо он в университете оригинал привозят только те кто подавал документы через госулуги',
#  'аа понятно',
#  'понял спасибо',
#  'ok',
#  'классная идея очень интересно будет услышать мнение преподавателей в роли студентов жду с нетерпением рассказов дмитрия кулизаде и других гостей этой рубрики',
#  'где сообщение про зачисление',
#  'по идее да',
#  'а если я в зелёной зоне то я попал 100 или только на данный момент',
#  'на данный',
#  'а в теории к спискам к приказам может кто то добавиться',
#  'это же окончательные списки нет разве',
#  'именно не ранжированные а к приказам',
#  'если к приказам то 999 сегодня вечером уже будут приказы',
#  'а ниче себе а говорили 9 числа',
#  'с 49 на оф странице но уже был пост о списках на зачисление но его снесли ждем новый пост',
#  'очень ожидаем результаты удачи всем абитуриентам',
#  'последний заезд',
#  'когда',
#  nan,
#  'тёплого дня подскажите пожалуйста в списках к приказу в личном кабинете которые обновлены сегодня в 1103 учтены уже все поданные оригиналы или чтото с госуслуг ещё дойдёт в течение дня',
#  'кто на какое направление метит',
#  'стандартизация и метрология',
#  'понял принял пока мимо',
#  'на данный момент большая часть всех поданных оригиналов обработана значительных изменений скорее всего не будет',
#  'а ты на какое',
#  'на программную инженерию',
#  'жёсткий',
#  'ахахах',
#  'хотел бы я таким быть',
#  'ну ждёмс приказов тогда',
#  'благодарю',
#  'ну если ты уже в списке к приказам то вроде как 99 попал ну так говорят',
#  'понял',
#  'ну буду надеяться на это',
#  'а будет вторая волна на бюджет',
#  'на бюджет всех добрали в приёмке говорят что нет',
#  'спасибо',
#  'все возможно обратитесь пожалуйста завтра в приёмную комиссию любым удобным для вас способом по этому вопросу для получения более подробной информации и следите за новостями в наших соц сетях',
#  nan,
#  'подскажите приблизительно к какому времени смотреть списки',
#  'добрый день а при подаче заявления через госуслуги нужно какието документы готовить или госуслуги предоставляют всё сами не нашел информации об этом',
#  '[LINK] подскажите приказы по этой ссылке будут или нет',
#  'госуслуги предоставляют все сами',
#  'да все верно',
#  'подскажитепожалуйста что есть зеленая зона',
#  'я правильно понимаю что их еще не опубликовали',
#  'пока нет ещё немного и все будет сразу сообщим об опубликовании',
#  'приказы нужныы',
#  'что же такое зеленая зона',
#  nan,
#  'ещё нету приказов и стоит ли их ожидать сегодня',
#  'мы очень стараемся все выверяем приказы будут ближе к позднему вечеру',
#  'ждем с нетерпением',
#  'есть у кого то чат абитуриентов',
#  'у меня вопрос возник просто чтобы оценивать свои шансы нужно смотреть в ранжированные списки или в списки приказов',
#  'списки приказов наверное они самые актуальные',
#  'ну типо если ты там в зеленой зоне да и ещё не на последних местах то попал туда скорее всего',
#  nan,
#  'понял',
#  'дайте чатик абитуриентов пожалуйста',
#  'возможно вот то что вы искали чат приемной комиссии абитуриентов [LINK]',
#  'пасиба',
#  'ура поступил',
#  'ура ура жизнь кайф',
#  'урааава',
#  'поступил',
#  'есть такое',
#  'мы поступили',
#  'поступил',
#  'ура ура',
#  'ура поступил',
#  'ура',
#  nan,
#  'поступила',
#  'как хорошо что в первый же день приказы опубликовали поступил сегодня приёмная комиссия уже не работает что дальше делать',
#  'есть тут кто поступил на информатику и вычислительную технику',
#  '090301 вроде',
#  'есть',
#  'ты',
#  'да',
#  'кайф будем учиться на одном направлении',
#  'есть кто на 380302',
#  'ага удачи всем',
#  'хорошо отлично',
#  'кто на 090302',
#  'я',
#  '150306',
#  'а вот ссылка на станкин вк кто ещё не подписался ждём [LINK]',
#  'я',
#  '090303',
#  'поступила вот и лето прошло балдежный отдых был',
#  'огромное спасибо приемной комиссии и вообще всем причастным к оперативному выпуску приказа вы лучшие',
#  'фактишь',
#  '150304',
#  'кто на 270304',
#  'да есть',
#  'ребят вы все такие умнички всех поздравляю',
#  'огромное спасибо приемной комиссии вы суперлюди',
#  'есть правда я мама',
#  'интересен возраст поступивших мне 24 думал буду молодым в группе',
#  'на месте',
#  '17 лет мальчику',
#  'мне 18 годиков',
#  'молодые все',
#  'взрослый дядя',
#  'походу старым буду',
#  'будешь мудрым дедом своей группы',
#  'ахаха',
#  'оооо куда поступила точнее на что',
#  'у меня история более смешная армия есть работаю сис админом и только после решил учиться ахахах',
#  'походу реально мудрым дедом буду',
#  'какая нестандартная история даже работаешьа я вот только собираюсь искать работу',
#  'ищу кто на 380302 пишите в личку будем общаться знакомится',
#  'а ты на какое направлние поступила',
#  'я самоучка был так по образованию логист но после армии три года работал логистом понял что не моё',
#  'и решил пойти в it то чем я занимался изначально',
#  'так уже два года и работаю',
#  'обалдеть очень крут',
#  'с 13 лет в комп играл постоянно от сюда и знания всего ахахах',
#  'будешь с преподами по душам общаться',
#  'так что не зря играл все детство',
#  'видимо хорошо все складывается пока',
#  'вот на это надеюсь ахахха',
#  nan,
#  '120301',
#  'я',
#  'ура',
#  'я',
#  'ура',
#  'я',
#  'ура поступил спасибо приёмной комиссии отличная работа',
#  '090301',
#  '150305',
#  'поддерживаю',
#  'я',
#  '09 03 02 мы подружимся',
#  'урааа',
#  'урааааааа',
#  'ура конечно но что делать дальше',
#  'всем привет я с вами',
#  'клааасс',
#  'привки',
#  'а насчет общаги надо звонить куданить',
#  nan,
#  'думаю да',
#  'эххээээ опять звонить',
#  'привет',
#  'ты поставила галку что оно тебе нужно',
#  'да поставила',
#  'если да жди скоро даты заселения скажут в понедельник',
#  'хорошо спасибо',
#  'на управление персоналом к сожалению я не прошла на бюджет',
#  'приветсвую',
#  'пожалуйста',
#  'вопрос возник',
#  'ой не огорчайся пожалуйста солнышко а сколько у тебя баллов',
#  'где общага находится d',
#  'ну вот есть напротив вуза но туда вроде редко заселяют',
#  'а есть ещё какаято',
#  'расписание заселения уже есть на сайте',
#  '244 спасибо большое надеюсь что получится перевестись',
#  'вроде магистров и иностранных',
#  'метро студенческая два корпуса',
#  'далековато',
#  'но в прошлом году 38ые направления селили туда',
#  'я уверена что получится',
#  'нет недалеко скажем так до технологического факультета дальше',
#  'чем до вадковского',
#  nan,
#  'не понимаю c',
#  'интересно заранее знать где будут мои одногруппники жить d',
#  'мне больше интересно состояние общежития',
#  nan,
#  'думаю в инете можно найти фотки или видео',
#  'чтоб оценить',
#  'мы посмотрели снаружи состояние хорошее на каждом этажн душ кухни постирать есть где',
#  'внутрь нас не пустили заселять скорее всего будут точечно первокурсников к старшим курсам',
#  'общежития коридорного типа',
#  'опа я',
#  'спасибо',
#  'урааа поступила в любимую 38 группу',
#  'менеджмент',
#  'экономика',
#  'я',
#  'ура ура я тоже',
#  'я',
#  'ооо',
#  'поздравляю всех поступивших',
#  'с 270301 есть кто нибудь',
#  'я на менеджмент',
#  'я тоже',
#  'опа думал один буду',
#  'хах там минимум еще 80 человек таких же',
#  'кстати интересно нас же наверное будут делить на группы',
#  'если бюджетных мест 80 с чем то мы же не будем учиться потоком около ста человек или будем',
#  'вродена одном направлении обычно несколько специализаций',
#  'нет',
#  'после 1 курса',
#  'на лекциях будете потоком а на семинарахлабах по группам',
#  'экзамены на сессии тоже по группам',
#  'онадо побольше гайдов по обучению глянуть',
#  nan,
#  'ураааа',
#  'главное это не разочароваться',
#  'побеееееда',
#  'когда можно получить ордер в любой день с 7 августа',
#  'ждем вас на кузьминках ребят',
#  'хорошо спасибо',
#  'на самом деле так волнительно это все все новое будет это пугает немного',
#  'да ладно в вузе наоборот жизнь только начинается',
#  'полностью согласна',
#  'надеюсь а вообще я сделала вывод что первакам ни в коем случае нельзя чекать подслушку хахаха',
#  'аххахахахаххаха',
#  'да там веселые вещи пишут',
#  'я даже когда в приемную комиссию пришла девчонки сказали мол лучше вообще не читай эту группу там бедных абитуриентов напугать пытаются',
#  'ахахаха',
#  'аххахахахахах',
#  'подскажите а как узнать дают общежитие или нет а то приедем 28го а нам ге дали',
#  'рыжего кота в 8ой общаге зовут алекс',
#  'добрый день когда будет известно в какое общежитие посетят',
#  'всем иногородним дают если в заявлении указалипо опыту предыдущего года',
#  'кузьминкивыхино скорее всего',
#  'что такое кузьминкивыхино',
#  'это метро студенческая',
#  'нет это метро кузьминки или выхино',
#  'а почему туда а не на студенческую',
#  'эээээ я думала только три общежития',
#  'два на студенческой и одно около института',
#  'на студенческой всем места не хватает мы думали туда на втором курсе переселят так там одну общагу на ремонт закрыли',
#  'ташкентская 34к1 и 34к2 кузьминки парни',
#  'это же достаточно далеко',
#  'улица академика скрябина 251к4 кузьминки девочки',
#  'а выхино',
#  'на выхино точно не знаю известно мне только то что это общаги мосгу смею предположить что это улица юности 5с36',
#  'у нас ребят с направления 090301 на выхино весной переселяли',
#  'это какую общагу на студенческой закрыли 2 или 8',
#  'и куда обычно менеджмент селят мне в приемной комиссии сказали что обычно или в 2 или в 8',
#  'может быть такое программисты по большей части в кузьмах сидят',
#  'не знаю мне вадим борисович не уточнял',
#  'ну ладно прорвемся спасибо за информацию',
#  'конечно сейчас уже незачем стрессовать самое страшное позади расслабляемся и вливаемся в увлекательную студенческую жизнь в мегаполисе',
#  'студактив жди меня',
#  'если вопросы какиенибудь есть пишите по возможности постараюсь ответить',
#  'спасибо',
#  'в прошлом году экономистыменеджмент селили в 3ю общагу',
#  'это та которая ближе всех в универу',
#  'да',
#  'надеемся на лучшее',
#  'ага',
#  'если зачислена на 090301 значит общагу на выхиноно дают',
#  'не обязательно',
#  'спасибо а вадим борисович заселением занимается',
#  'меня к нему по этим вопросам отправляли',
#  'здесь что весь менеджмент и экономика собрались',
#  'а какая у него фамилия и где он принимает',
#  'подскажите пожалуйста если собрание 090301 29 августа тогда когда заселят в общежитие',
#  'уважаемые студенты 1 курса бакалавриата и специалитета начинаем вливаться в станкиновскую жизнь читаем внимательно внимательно репостим к себе и ждем свою дату для получения ордера на вселение в общежитие заселение в общежитие студентов имеющих паспорта рф производится по ордеру и по графику',
#  'спасибо',
#  '28',
#  'подскажите если ребёнку нет 18 ему все равно оформят карту',
#  'что за карта',
#  '270304 тут',
#  'банковская карта для стипендии',
#  'оформят',
#  'я в 17 её получил',
#  'до начала учебного года за ней приехать или как',
#  'нет вам все скажут в первый день',
#  'а чаты для абитуриентов будут',
#  '[LINK]',
#  'спасибо',
#  'а оплачивать общежитие как помесячно раз в полгода',
#  'здравствуйте к кому можно обратиться по вопросу о приписном свидетельстве которая необходима для собрания абитуриентов',
#  'и какая оплата',
#  'ивтшников и прикинф куда скорее всего заселят',
#  'в кузьминках и выхино бесплатно универ платит за нас',
#  'а в кузьминках и выхино какие общаги',
#  'а цена',
#  'спасибо',
#  nan,
#  'мне не пришло',
#  nan,
#  'дают',
#  'скажите пожалуйста где можно увидеть конкурсные списки на платное',
#  'спасибо',
#  'было бы неплохо общежитие для ребят привести в достойный вид',
#  'есть фото оттуда',
#  'по поводу подготовки меня по какойто причине забанили в чате для абитуриентов хотя я выразился вполне корректно что по моему опыту не всегда учитывают ответив на сообщение о том что учитывается количество нуждающихся в общежитии и количество свободных мест имея ввиду то что с общежитием бывают проблемы такого рода потому что со мной такое случалось поэтому причины для бана не вижу этот чат был в некоторых моментах достаточно полезен пусть периодически есть флуд а сразу после моего сообщения меня забанили',
#  'ура',
#  'это здорово что независимые блогеры посетили мгту станкин и поделились честными впечатлениями о вузе они побывали в учебных аудиториях лабораториях общежитии даже попробовали еду в столовой молодежный проект обрнадзоро предлагает посмотреть выпуск чтобы узнать больше напоминаем абитуриентам о возможности поступить в этот ведущий технологический вуз удачи всем',
#  'доброе утро станкиновцы летнее время пролетает стремительно и осталось всего месяц чтобы насладиться его прекрасными деньками давайте вспомним что мы успели сделать за прошлые месяцы и составим список дел на август важно не упускать ни одного летнего дня делитесь в комментариях своими результатами и идеями о том как провести остаток лета насыщенно и запоминающеся пусть ваше лето будет наполнено яркими моментами и приятными впечатлениями',
#  'здравствуйте мы зачислены а в личном кабинете почемуто до сих пор ничего нет или лк абитуриента уже не работает и нужен лк студента',
#  'я правильно понимаю если указано что заселение с 29 августа то за ордером нужно приходить в эту дату или можно раньше ордер получить',
#  'интересует можно ли раньше',
#  'это я все видела и знаю я задала вопрос про личный кабинет говорили что информация будет там или про него можно уже забыть',
#  'прекрасная новость ребята у нас в университете открыты дополнительные бюджетные места если у ваших друзей не хватило баллов для поступления срочно поделитесь этой информацией с ними в нашем университете открыт набор по различным направлениям подготовки включая приборостроение машиностроение технологические машины и многое другое минимальные пороговые баллы доступны для тех кто хочет подать документы если вы заинтересованы обращайтесь к приемной комиссии по указанным контактам удачи всем абитуриентам',
#  'очень интересно узнать о развитии беспилотных авиационных систем на архипелаге2023 надеюсь что это приведет к новым возможностям в инженерии и технологиях буду следить за новостями',
#  'ребята все большие молодцы они заложили хороший фундамент для дальнейшего обучения и получили обширные знания о нашей стране языке культуре экономике политике и многом другом',
#  'поздравляю всех иностранных слушателей с успешным прохождением курсов русского языка пожелаю вам удачи в будущем обучении в вузах россии и других университетах',
#  'congratulations',
#  'отличный отдых полный активного времяпрепровождения и спортивных достижений каждый момент был наполнен весельем и зарядил энергией на весь учебный год классно что такие поездки позволяют завязывать новые дружеские связи и обмениваться опытом с другими студентами желаю всем хорошо отдохнуть и с новыми силами приступить к занятиям',
#  'спасибо за информацию буду иметь в виду о возможном дожде и возьму с собой дождевик удачного дня всем',
#  'очень интересно узнать что молодежь становится все более читающей аудиторией поделитесь пожалуйста своими текущими чтениями и опытом посещения научнотехнической библиотеки станкина какие книги там нашли',
#  'недавно дочитала дочь священника оруэлла',
#  'борис акунин медвежатница и рейчел гриффин высшая ведьма',
#  'дочитала цивилизация запахов 1619 в и читаю умберто эко имя розы',
#  'очень впечатляющие достижения участников всероссийского конкурса удивительно что школьники смогли создать такие разнообразные и полезные проекты желаю им дальнейших успехов и вдохновения',
#  'я вдохновлен данными опроса проекта твой ход и движения волонтеровэкологов делай очень рад что 82 студентов заботятся об окружающей среде мы все должны принимать участие в сохранении нашей планеты я лично отказался от использования пластиковых пакетов и активно сортирую мусор уверен что каждый шаг в направлении экологии имеет значение',
#  'какие документы нужны для заселения в общежитие',
#  'для иностранных абитуриентов поступивщих на квотную основу обучения',
#  'медицинские справки не нужны',
#  'круто что наш университет стал площадкой для такого интересного проекта разработка приложений виртуального прототипирования это будущее и классно что такая компания как vr concept была отмечена на конкурсе новых брендов россии поздравляю дениса захаркина и его команду с успехом',
#  'отличный выбор направлений возможность получить бесплатное высшее образование в топовом технологическом университете россии это реальная перспектива для будущей успешной карьеры не упустите свой шанс и подавайте документы в мгту станкин контактная информация для связи с приемной комиссией указана выше',
#  'добрый день подскажите пожалуста сколько свободных мест на техносферную безопасность интересует бюджет',
#  'обратитесь пожалуйста в приемную комиссию станкина телефон 74999733849',
#  'спасибо',
#  'как интересно было бы оказаться в шкуре студента наверное все мы могли бы узнать много нового и познакомиться с уникальными моментами из жизни студентов буду ждать новых рубрик',
#  'приветствую неплохая погода сегодня поднимает настроение как дела у вас ребята',
#  'гнетущаякак в произведениях достоевского',
#  'дайте дождику в краснодар а я вам 40 и мокрую кровать по утрам',
#  nan,
#  'можноахзаза',
#  'так до станкина ещё три недели',
#  'здравствуйте скажите пожалуйста стоимость за общежитие поступили на бюджет 090301',
#  'пока никто не скажет но в районе 56к в семестр в зависимости от общаги в которую вас поселят',
#  'я семестр я думала в месяц',
#  'спасибо успокоили',
#  'а вот',
#  'образование увлечения знакомства и любовь вот что важно в станкине поздравляю артемия и юлию с семейным счастьем молодцы',
#  'интересный проект который объединяет спорт киберспорт и технологии будет интересно посмотреть как новые дисциплины проработают участники отличная возможность для тех кто увлекается наукой и спортом жду с нетерпением первых игр в казани',
#  'уважаемая администрация если есть информация такая в какие общежития будут заселять 090301 информатика и вычислительная техника',
#  'такой информации нет всё узнаете на заселении',
#  'даже деканат такого не знает',
#  'то есть расселяют рандомно',
#  'по потокам и группам',
#  'а что такое поток',
#  'специальность',
#  '090301',
#  '150305',
#  'и так далее',
#  'это я поняла поэтому и уточняю то есть одна группа может быть в одном общежитии другая в другом',
#  'да такое может случиться но это маловероятно',
#  'но почти всегда весь поток живёт в одной общаге',
#  'я хочу разместиться в общежитии n3',
#  'а ты иностранец',
#  'да',
#  'а ну тогда вероятно в третью поедешь',
#  'туда обычно иностранцев селят',
#  'даа',
#  'это я понимаю поэтому и спрашиваю на студенческой или в другом месте информатику поселят',
#  'каковы условия общежития',
#  'да никто не знает женщина этого даже университет не знает как мы можем знать',
#  'на сайте инфа есть',
#  'ну в общем комнаты в хорошем состоянии да',
#  '[TAG] вы из таджикистана',
#  'узбекистан',
#  'вряд ли он иностранец вообще',
#  'а много ли студентов из центральной азии',
#  nan,
#  'подскажите где узнать статистику в магистратуру на программную инженерию',
#  'а волейбол',
#  'жиз',
#  'волейбола не будет',
#  'тоже есть',
#  'классный шанс для абитуриентов если не хватило баллов для первой волны то сейчас можно попробовать пройти на бюджетное обучение интересные направления подготовки респект ведущим вузам желаю успеха и пусть все документы будут в порядке',
#  'отлично проведенное мероприятие полное веселья и культурного обмена рад видеть как молодежь со всего мира объединяется в одно целое желаю всем отлично отдохнуть и зарядиться позитивной энергией',
#  'отличное исполнение песни радует что она стала международной молодежь всегда создает атмосферу праздника',
#  'мои зажигалочки',
#  'отдельно расскажите как найти кафедру математики',
#  'скорей кафедру физики и все кабинеты которые находятся в том крыле',
#  'да кафедру физикито искать нечего',
#  'а вот кафедру математики найти в первый раз вот это квест',
#  'я в общем сказал про кабинеты в том крыле так как когда мне в первый раз надо было в 309 я без помощи одногруппника разобраться не смог',
#  'там нумерация идёт 408410 а 409 нету он в другом крыле или что то такое я помню ахахахах изза этого я тогда на пару опоздал',
#  'приложениекартауниверситета',
#  'да я об этом',
#  'в станкине нет посвящение в студенты как в мэи например где три дня знакомят с вузом очень здорово на мой взгляд',
#  'студпосвят есть',
#  'но не три дня',
#  'в этом году с 28 по 30 3 дня адаптации',
#  'ок',
#  'это я про мэи',
#  'я понял',
#  'а чего же ты в мэи не пошёлто',
#  'вот 28 и пойду',
#  'расскажи потом обязательно',
#  'ок',
#  'ноутбукто зачем его надо каждый день таскать с собой',
#  'не подскажите когда появиться расписание занятий',
#  'в конце августа',
#  'здравствуйте какого типа общежития есть ли душ в блоках',
#  'здравствуйте в этой группе почти все иностранные абитуриенты',
#  'спасибо',
#  'сколько студентов может разместиться в одной комнате студенческого общежития',
#  'три',
#  'сколько студентов станкина потребуется чтобы поменять лампочку три первый ставит стул второй выключает свет а третий меняет лампочку',
#  '[TAG] иностранных студентов размещают только с иностранцами',
#  'не знаю как их там селят но все иностранные студенты живут напротив уника в третьей общаге',
#  'тогда уже больше людей',
#  'один составляет заявку второй её принимает и отправляет коменданту коменданттретий отправляет её менеджеру по уходу за общагой этот менеджерчетвёртый человек уже приходит менять лампочку',
#  'ждите рейтинг 40 он мне нужен как никогда',
#  'значит в общаге точно будут светить лампочки',
#  'а ноут зачем',
#  'для рефератов учёбы конспектов отдыха от учёбы',
#  'а если ты поступила на айтишника то это как голову дома забыть',
#  'дома компьютер а ноута нет',
#  'можешь комп в общагу пртвезти',
#  'а на парах где нужен комп они есть уже',
#  'добрый день где посмотреть крнкурсный список на платное как оценить свои шансы',
#  'на платное вы точно пройдёте',
#  'круто цифровой рубль новинка с потенциалом',
#  'и где потенциал чёт о нём ни слова',
#  'зачем нужен цифровой рубль цр 1 платить цр дешевле чем печатными деньгами 2 следить за передвижение цр проще так как наличных уже не будет в последствии 3 ограничить человека и лишить его всех благ проще с цр',
#  'наличные еще лет 100 будут',
#  'не выгодно прекращать оплату наличными',
#  'платить дешевле это как ценники для цр другие будут рибейтов нет и где тут выгода',
#  'это банкам лучше для нас выгоды никакой',
#  'именно дешевле для банка циферки нарисовать чем бумажные деньги печатать',
#  'лето пролетело быстро но оставило много ярких воспоминаний',
#  'великолепная встреча развитие сотрудничества с китаем шаг вперед для нас и для дружбы двух стран',
#  'классные приключения в общежитии с новыми друзьями и смешными историями удачи в поиске артефактов',
#  'hello every one i am student of phd program i am coming to university next month please some one tell me that how many rupees per month for a phd student is given by the russian government please please answer my question thanks',
#  'do you mean a scholarship',
#  'i dunno how many rubles russian government will give u but i know that u need at least 2025 thousand rubles per month',
#  'очень полезная информация спасибо',
#  'здравствуйте как часто приходится ездить в корпус на фрезере',
#  'смотря какое направление',
#  'но на 1 курсе все ездят 1 максимум 2 раза в неделю не чаще',
#  'фрезер это где',
#  'на шоссе фрезер',
#  'станции метро нижегородская',
#  'а далеко это от метро',
#  'нет десять минут с метро идти максимум',
#  'там просто выход запутанный через станцию электрички',
#  'слушайте а в чем на физкультуре занимаются в станкин',
#  'вроде как типа обычной физры в школе бегаем в волейбол играем',
#  'вообще много разных тем благодаря которым вам поставят зачёт по физре вроде участие в спортивных командах шахматышашки и прочие классические настолки',
#  'зимой можно кататься на лыжах было',
#  'yes in scholarship',
#  'please give my answers',
#  'sorry for my englishthey they will definitely answer you if you call him on their phone numberthat placed on their website',
#  'please call this number 84999729411 and ask this question at the center for international cooperation',
#  'руслан рады приветствовать удачи',
#  'руслан добро пожаловать ждём тебя в качестве наставника проектов для школьников',
#  'иностранных студентов поступивших по направлению 090302 информационные системы и технологии тоже 28 августа заселят на общежитие',
#  'их поселят в соответствии с графиком заселения',
#  'а откуда взять такой график',
#  'вот',
#  'совет вам да любовьмногие нашли свою половинку именно в наших стенахждем продолжения добрых традиций в нашей большой и дружной станкоинструментальнотехнологическоинформационноуправленческой семье',
#  'добрый день когда в станкине планируют открыть вуц',
#  'вуц',
#  'военно учебный центр',
#  'хз главное что сейчас его нет',
#  '[LINK]',
#  'а мы чтото свою фамилию не найдем 150306 смотрим расписание на сайте и пофамильные списки нас нет нигде хотя в приказе на зачисление есть',
#  'так списки уже для новой волны',
#  'если вы есть в приказе то всё вы студент',
#  nan,
#  'студент только после 1 сессии',
#  'не пугай мамочку',
#  'подскажите пожалуйста а где можно пофамильные списки посмотреть видели приказы о зачислении только с номером инн',
#  'нет таких',
#  'вам не нужны пофамильные списки если вы в приказе',
#  '[LINK]',
#  'это эос вы как туда доступ получили',
#  'что такое эос',
#  'студентамрасписание дальше папочки и войти как гость',
#  'это ведь группы людей зачисленных в прошлом году',
#  'электронная образовательная среда',
#  'вам доступ дадут в середине сентября',
#  'логины и пароли',
#  'я нашла первый курс вот и подумала там уже списки зачисленных на 1 курс',
#  'да там логины паролито хахаха номер студенческого',
#  'списки зачисленных находятся в приказах',
#  'понятно всем спасибо',
#  'ну типа доступ ещё не сделал деканат',
#  'потом староста всё всем разошлёь',
#  'а для чего вуц нужен',
#  'чтобы мальчики после вуза в армейку не пошли',
#  'военная кафедра',
#  'а',
#  'другими словами',
#  'ну если сделают то это оч прикольно',
#  'а во многих вузах вообще военная кафедра есть',
#  'нет',
#  'единицы',
#  'а это не прикольно',
#  'владимир валерьевич сказал что будет так что ждём',
#  'сказал что это займет несколько лет',
#  'поэтому особо планов не стройте',
#  'кстати а ктото в курсе основы военной подготовки сколько будет идти по семестрам',
#  'что это',
#  'в учебном плане надо смотреть',
#  'новый предмет с 1 сентября 2023',
#  nan,
#  nan,
#  'а у вас вообще не было такого',
#  'нет и честно говоря хорошо',
#  'раньше не было',
#  'теперь будет',
#  'сплюнь',
#  'и постучи',
#  'чё сплёвывать',
#  'это же как нововведение',
#  'открываем учебный план',
#  'так военка же не обязательная',
#  'и так много бредовых предметов',
#  'и видим',
#  'типа гимна с прошлого года и разговоров о важном',
#  'спасибо вова',
#  'во во',
#  'за бесплатное образование пожалуйста',
#  'будем учить воинские звания и разбирать калаш',
#  'оно всегда бесплатное было поэтому то что сейчас происходит это спад людям голову забивают всякой бредятиной',
#  'чтото в иностранных вузах я не вижу предметов бред про то как империалисты и запад нашу великую страну собираются разваливать',
#  'ну энивей нечего тут спорить',
#  'я помолчу посижу',
#  'ну во многих и образование платное',
#  nan,
#  'нуну историю учить надо ведь никто не работал раньше в маках после уника работали по профессии',
#  'а то ещё бан получим',
#  'выговор от деканата пострашнее',
#  'тучка у тебя легендарная фиолетовая кофта',
#  nan,
#  'да',
#  'но самое крутое это мерч приёмки',
#  'ради этого можно после первого курса в приемку',
#  'а ты на какой перешёл',
#  'второй',
#  'я думала ты олдфаг который на 4ый переходит',
#  'я прошареный',
#  'поэтому и думала так',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'это значит что будет пятидневка я правильно понимаю',
#  'хахахаха',
#  'нет',
#  'скорее всего нет',
#  'жаль',
#  nan,
#  'скажите пожалуйста вместо справки 086у могу ли принести медкнижку',
#  'здравствуйте',
#  'здесь студенты 2 курса присутствуют',
#  'имеются такие',
#  nan,
#  'у меня',
#  'рассматриваю поступление на следующий годсобираю информацию',
#  'стандартизация и метрологии интересует',
#  'есть студенты',
#  'хотелось бы пообщаться',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'да',
#  'а где послушать трек молодого музыканта который не выходит у вас из головы',
#  'в вконтакте',
#  'да',
#  'а вы в след году',
#  'я думал на первый',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'а у вас какой курс',
#  'я на первый иду только',
#  'егэ физику сдавали',
#  'инф',
#  'сумма баллов егэесли не секрет',
#  'я тоже планирую информатику сдаватьс физикой сложно',
#  'совет сдавать физику',
#  'проще в учебе будет',
#  'я плохо сдал 205 но в списках где то выше середины',
#  'если ты обычнаяне квотникто будет достаточно 250 с головойесли ты квотницато 250 тебе хватитчтоб поступить куда угодно',
#  'мы говорим о сертификации и метрологиия смотрела рейтинговые списки180 бал прошли по рейтингу',
#  'да 205 100 попадете но это такой себе факультет',
#  'если вы наберёте больше 240 то лучше поступить в какой нибудь мирэа или маи там шансы тоже хорошие есть',
#  '240 не наберупо этому рассматриваю сертифи метролог',
#  'стандартизация и метрология можете попробовать на техносферную безопасность ещё она лучше вроде бы',
#  'хорошопосмотрю',
#  'вообще если наберёте 220 то можете идти на целевое в бауманку там хоть и работать придется после учёбы но зато сразу опыт и возможность работать в компании дальше',
#  'вообще за год можно спокойно подготовиться у меня друг в феврале начал готовиться к егэ и поднялся с 200 до 271',
#  'не хочу влезать но из бауманки очень студентов много переводится в станкин изза неподобающего отношения к студентам я считаю это показатель',
#  'ну либо переводятся платники которые и так не особо умные либо те кому терять нечего',
#  'нет',
#  'фаната бомонки вон отсюда',
#  'кто сказал что я фанат бауманки',
#  'просто это второй вроде технический вуз в москве',
#  'и оттуда переводиться в станкин ну такое',
#  'ну он правильные вещи говорит но не улавливает силу обучения в станкине и бауманке',
#  'ну мы технологический',
#  'очевидно что в бауманке обучение лучше спорить глупо на эту тему',
#  'вы там учились',
#  'просто одно дело что в станкине легче может из за этого',
#  'нет но вуз со вторым местом не может быть хуже чем вуз на 26 месте',
#  'чтоб судить',
#  'там тоже не дураки сидят',
#  'рейтинги не показывают реальной ситуации',
#  'я общаюсь с реальными студентами',
#  'разрыв 24 места',
#  'выбирать вуз только изза рейтинга глупо',
#  'тогда станкин лучше мфти вшэ мифи',
#  'я такого не говорил',
#  'я со студентами из вшэ общаюсь',
#  'я говорю',
#  'у меня лучший друг студент вшэ',
#  'вшэ это вообще не технический вуз',
#  'ребята не сорьтесь',
#  'это факт',
#  'вшэ универсальный вузик',
#  'коррупционный вузик',
#  'это ты про финашку',
#  'угу',
#  'финашка кста рядом со станком находится',
#  'как в станкинераспределяются общежитие 1 курс',
#  'по потокам',
#  'вы общагу не выбираете',
#  'о этим деканат занимается',
#  'хватает всем 1 курс',
#  'да',
#  'объявили что 4 год всем хватило',
#  nan,
#  'сколько человек в комнате',
#  '34',
#  'коридорного типатуалеткухня на этаже',
#  'вроде разные',
#  'блочные в том числе',
#  'чаще всего да но есть блочного рядом с вузом там по большей части иностранцы живут',
#  'дая читала на сайтек сожалениютолько иностранцам',
#  'но бывают исключения',
#  'спасибовсемза информацию',
#  'ждём вас через годик',
#  'успехов на егэ и в 11 классе',
#  'спасибо',
#  'продолжать отпуск и купать на море в анапе',
#  'продолжать активный отдых в санктпетербурге',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'тут нет ничего выдающегося но хотелось бы поделиться',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'да',
#  'допустил ошибку не взяв фотоаппарат',
#  'так уже был у вас',
#  'с днём государственного флага россии друзья',
#  'прекрасная статьяавторспасибо вам за такие интересные темымне нравитсякак вы ведёте каналспасибоуспехов вам',
#  'сумку для всех этих вещей',
#  'крепкие нервы',
#  'вопрос если ноутбук отсутствует сильно тяжко будет',
#  'а компьютер есть',
#  'неа',
#  'а направление какое',
#  '150305 ноут в ремонт отдали а сделают ближе к новому году',
#  'у меня есть компьютер',
#  'я не знаю насколько будет тяжело но мне кажется может возникнуть нужда в ноутбуке для тех же презентаций если их нужно будет сделать',
#  'если есть планшет или хороший навык делать презентацию на телефоне то думаю можно будет прожить и без ноутбука',
#  'лучше найти людей с твоего направления которые перешли на 2 курс и спросить как часто им приходилась делать чтото для чего нужен ноутбук',
#  'на счёт добавить это каждый сам определится а вот энергетик надо постараться убрать иначе совсем скоро придётся добавлять медикаменты',
#  'пропуск в станок забыли',
#  'нет не очень тяжко',
#  'согласна с вами',
#  'а то как говорит носовицкий смэрть',
#  'согласна с вами иначе гастроэнтеролога и кардиолог надо будет посещать',
#  'а вы знали что кофе с молоком вреднее энергетика',
#  'да',
#  'да особенно кофе с молоком',
#  'если просто еспресо то может и лучше',
#  'почему же',
#  'а молоко как минимум убивает тонизирующий эффект да и еще не усваивает полифенолы и антиоксиданты из крови',
#  'ты имел в виду американо',
#  'необязательно',
#  'американо это тот же эспрессо только с водой',
#  'а',
#  'эспрессо в любом кофе',
#  'так что лучше уж выпить энергетик 300мл чем условно тот же капучино',
#  'если литрами то конечно просто меру надо знать а вы знали что бодрящие свойства кофе сильно преувеличены на самом деле у него обратный эффект',
#  'или любой другой кофейный напиток',
#  'я об этом и написал',
#  'чаёк выпить крепкий и бодренько в уник',
#  'лучше высыпаться',
#  'да какой нибудь пуэр маленькую чашку и в путь',
#  'а не мочу из магазина',
#  'доброго дня в группе 150306 есть же черчение',
#  'я загуглил',
#  'оно было уже',
#  'а когда оно былопочему не уведомляли',
#  'речь об этом',
#  nan,
#  'когда для 090301',
#  'информация об организационных собраниях студентов 1 курса бакалавриата и специалитета уважаемые студенты 1 курса бакалавриата и специалитета организационные собрания студентов 1 курса бакалавриата и специалитета будут проводиться в следующие сроки 1 для студентов зачисленных на направление 150304 26 августа 2023 года в 1100 2 для студентов зачисленных на направления 090304 и 150306 28 августа 2023 года в 1000 3 для студентов зачисленных на направление 090303 28 августа 2023 года в 1500 4 для студентов зачисленных на направление 090301 29 августа 2023 года в 1000 5 для студентов зачисленных на направления 090302 29 августа 2023 года в 1500 6 для студентов зачисленных на направления 270302 270304 380301 380302 380303 30 августа 2023 года в 1000 7 для студентов зачисленных на специальность 150501 и направления 150302 и 200301 31 августа 2023 года в 1000 8 для студентов зачисленных на направления 120301 и 270301 31 августа 2023 года в 1500 9 для студентов зачисленных на направления 150301 150305 01 сентября 2023 года в 1100 номер аудитории в которой будет проводиться собрание будет указан при входе в здание в котором расположена приемная комиссия вадковский пер д 1 на собрание необходимо принести с собой 6 фотографий размера 34 см на обороте каждой фотографии необходимо указать фамилию и инициалы паспорт удостоверение гражданина подлежащего призыву на военную службу приписное свидетельство или военный билет для юношей медицинская справка по форме 086у выданная в 2023 году врачебное профессиональноконсультативное заключение ручку для письма ксерокопию трех разворотов паспорта основного со сведениями о прописке и с информацией о ранее выданных паспортах для студентов являющихся гражданами иностранных государств дополнительно необходима ксерокопия заверенного перевода паспорта на русский язык для оформления банковской карты для получения стипендии',
#  'почему эту информацию здесь не выкладывали',
#  'выкладывали вроде',
#  'все выкладывали',
#  'нет',
#  'вот всё давно выложено',
#  'уважаемые первокурсники бакалавриата и специалитета организационные собрания которые станут вашим первым знакомством с университетом пройдут по расписанию возьмите карточку своего дня встречи и обязательно подпишитесь на официальную группу станкина в вконтакте важно номер аудитории где вас будут ждать на собрании будет указан при входе в здание в котором расположена приемная комиссия вадковский пер д 1 до встречи',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'хорошо спасибо',
#  nan,
#  'имеется ввиду фотографию отсюда',
#  'распечатать надо',
#  'нет просто сохранить чтоб не забыть когда приходить',
#  'аа понятно спасибо',
#  'а что будет 1 сентября',
#  'можно ли будет доделать попозже форму 086у',
#  'аэ не для всех направлений же',
#  'кто в адб2308',
#  'а 150306 когда приходить и что брать',
#  nan,
#  nan,
#  'завтра в 1000',
#  nan,
#  'спасибо',
#  'кто нибудь знает что делать если я по доп набору но сбор на мое направление уже был',
#  'ты с автоматизации',
#  'да один единственный',
#  'может попробовать завтра сходить в то место где было собрание и узнать где можно расспросить про 150304',
#  'либо зайди в старый корпус и поднимись в 218 либо в 233 может там кого то найдешь',
#  'собрание было в новом корпусе где приемная комиссия 2 этаж аудиторию не помню',
#  'большое спасибо',
#  'здравствуйте друзья я вас приглашаю на группу общага 3 если вы заселились на общагу 3 пожалуйста присоединяйтесь чтобы близко познакомиться друг с другу [LINK]',
#  'любимые дети',
#  'любимые студенты',
#  'любплюсмые деструканы',
#  'любимые дестанты',
#  'ребяткак получить призывное свидетельство или военский билет',
#  'в военкомат сходи',
#  'а как им доказатьчто я поступил и мне нужна отсрочкачто для этого предоставить',
#  'не призывное а преписное его дают когда становишься на учёт в военкомат по месту прописки военный билет дают тем у кого диагноз по категории годности или отслужившим строчку для отсрочки как студенту нужна справка по форме 4 из учебного заведения спроси что для военкомата когда будешь брать в уневере эту справку',
#  'любимые студенты',
#  'почему в посте написано что может претендовать первокурсник но в формезаявке первого курса нет',
#  nan,
#  'когото надо предупреждать о том что я не смогу посетить такое знакомство завтра',
#  'позвони в деканат',
#  nan,
#  'суббота учебный день',
#  nan,
#  'хахаха можно',
#  'можно я серьёзно',
#  'очень туда хочу',
#  'да можно',
#  'в каком кобинете',
#  'добрый день а расписание появилось уже и где смотреть',
#  'а до этого не будет учеба для магистров',
#  'в анкете нет направления 220301 материаловедение и технологии новых материалов',
#  'кто нибудь знает куда нужно отдать справку 086у и фотографии я просто собрание пропустила',
#  'позвони в деканат или тьютору и уточни',
#  'по моему все пришли всех с праздником',
#  'хочу через 4 года там петь тоже',
#  ...]

# %%
len(texts)
# Out:
# 1999

# %%
df_test['text_preprocessed'] = texts

# %%
df_test.head()
# Out:
#                                                 text  label  emojis  newlines  \
# 0                                    Очень похоже)❤️      0       1         0
# 1                                 Грозный СТАНКИН)))      0       0         0
# 2                                                         0       0         0
# 3  Здравствуйте, а куда можно написать по вопроса...      0       1         0
# 4  Здравствуйте, напишите свой вопрос в данный ча...      0       0         2
#
#    whitespaces  links  tags                                  text_preprocessed
# 0            0      0     0                                       очень похоже
# 1            0      0     0                                    грозный станкин
# 2            0      0     0                                                NaN
# 3            0      0     0  здравствуйте а куда можно написать по вопросам...
# 4            1      1     0  здравствуйте напишите свой вопрос в данный чат...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1999 entries, 0 to 998
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               1999 non-null   object
#  1   label              1999 non-null   int64
#  2   emojis             1999 non-null   int64
#  3   newlines           1999 non-null   int64
#  4   whitespaces        1999 non-null   int64
#  5   links              1999 non-null   int64
#  6   tags               1999 non-null   int64
#  7   text_preprocessed  1892 non-null   object
# dtypes: int64(6), object(2)
# memory usage: 140.6+ KB

# %% [markdown]
# ### Удаление лишних строк

# %%
sum(df_test.isnull().sum(axis = 1))
# Out:
# 107

# %%
df_test.dropna(subset=['text_preprocessed'], inplace=True)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1892 entries, 0 to 998
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               1892 non-null   object
#  1   label              1892 non-null   int64
#  2   emojis             1892 non-null   int64
#  3   newlines           1892 non-null   int64
#  4   whitespaces        1892 non-null   int64
#  5   links              1892 non-null   int64
#  6   tags               1892 non-null   int64
#  7   text_preprocessed  1892 non-null   object
# dtypes: int64(6), object(2)
# memory usage: 133.0+ KB

# %%
df_test.head()
# Out:
#                                                 text  label  emojis  newlines  \
# 0                                    Очень похоже)❤️      0       1         0
# 1                                 Грозный СТАНКИН)))      0       0         0
# 3  Здравствуйте, а куда можно написать по вопроса...      0       1         0
# 4  Здравствуйте, напишите свой вопрос в данный ча...      0       0         2
# 5                           День рождения СТАНКИНА 🎉      0       1         0
#
#    whitespaces  links  tags                                  text_preprocessed
# 0            0      0     0                                       очень похоже
# 1            0      0     0                                    грозный станкин
# 3            0      0     0  здравствуйте а куда можно написать по вопросам...
# 4            1      1     0  здравствуйте напишите свой вопрос в данный чат...
# 5            0      0     0                             день рождения станкина

# %%
count_zero = df_test[df_test['label'] == 0].shape[0]

# %%
count_zero
# Out:
# 893

# %%
count_one = df_test[df_test['label'] == 1].shape[0]

# %%
count_one
# Out:
# 999

# %% [markdown]
# Итого мы получили 1892 строк, из которых:
# - 893 чистых сообщений
# - 999 сообщений, помеченных как спам

# %% [markdown]
# ## Загрузка моделей

# %%
models_path = "../models"  # Путь к папке с моделями

# %% [markdown]
# Загрузка scaler и vectorizer

# %%
with open(os.path.join(models_path, "scaler.pkl"), "rb") as scaler_file:
    scaler = pickle.load(scaler_file)

with open(os.path.join(models_path, "vectorizer.pkl"), "rb") as vectorizer_file:
    vectorizer = pickle.load(vectorizer_file)

# %% [markdown]
# Загрузка классических моделей

# %%
classic_models = {}
for file in os.listdir(models_path):
    if file.endswith(".pkl") and file not in ["scaler.pkl", "vectorizer.pkl"]:
        with open(os.path.join(models_path, file), "rb") as model_file:
            classic_models[file] = pickle.load(model_file)

# %% [markdown]
# Загрузка моделей rubert

# %%
rubert_models = {
    "rubert_tiny2": {
        "path": os.path.join(models_path, "finetuned_rubert_tiny2"),
    },
    "rubert_tiny2_p": {
        "path": os.path.join(models_path, "finetuned_rubert_tiny2_p"),
    },
}
for name, model_info in rubert_models.items():
    model_info["classifier"] = pipeline("text-classification", model=model_info["path"], truncation=True)
# Out:
# Device set to use cuda:0
# Device set to use cuda:0

# %% [markdown]
# ## Предсказание значений

# %% [markdown]
# ### Функции для предсказания значений

# %% [markdown]
# Функция предсказания для классических моделей

# %%
def predict_message(text: str, vectorizer, scaler, model) -> tuple[int, list[float]]:
    """
    Предсказывает метку и вероятности для текста с использованием модели машинного обучения.

    Параметры:
        text (str): - входной текст для анализа
        vectorizer: - векторизатор для преобразования текста
        scaler: - масштабатор числовых признаков
        model: - модель машинного обучения

    Возвращает:
        tuple[int, list[float]] - метка предсказания и вероятности
    """
    # Предварительная обработка текста
    text_preprocessed = preprocess_text(text)

    # Векторизация текста
    text_vector = vectorizer.transform([text_preprocessed])

    # Создание числовых признаков
    numerical_features = pd.DataFrame(
        [[count_emojis(text), count_newlines(text), count_whitespaces(text), count_links(text), count_tags(text)]],
        columns=['emojis', 'newlines', 'whitespaces', 'links', 'tags']
    )
    # Масштабирование числовых признаков
    numerical_features_scaled = scaler.transform(numerical_features)

    # Объединение текстовых и числовых признаков
    features = hstack([text_vector, numerical_features_scaled])

    # Предсказание
    prediction = model.predict(features)
    probabilities = model.predict_proba(features)
    return int(prediction[0]), *probabilities.tolist()

# %% [markdown]
# Функция предсказания для моделей rubert

# %%
def bert_predict_batch(messages: list[str], classifier, threshold: float = 0.5) -> list[tuple[int, list[float]]]:
    """
    Функция для батчевого предсказания с помощью модели BERT через pipeline classifier.

    Параметры:
        messages (list[str]): – список сообщений для анализа
        classifier (pipeline): – pipeline классификатор
        threshold (float): – пороговое значение для предсказания класса

    Возвращает:
        list[tuple[int, list[float]]] - список предсказаний (0 или 1) и вероятностей
    """
    results = classifier(messages, batch_size=8)
    predictions = []
    for result in results:
        prediction = int(result['label'][-1])  # Извлечение метки предсказания
        score = result['score']  # Вероятность предсказания
        probabilities = [1 - score, score] if prediction == 1 else [score, 1 - score]

        if probabilities[1] < threshold:
            prediction = 0

        predictions.append((prediction, probabilities))

    return predictions

# %% [markdown]
# ### Сбор предсказаний

# %%
# Подготовка данных для BERT моделей
dataset = Dataset.from_pandas(df_test)

for name, model_info in rubert_models.items():
    rubert_results = bert_predict_batch(dataset["text"], model_info["classifier"], threshold=0.945)
    df_test[name] = [pred[0] for pred in rubert_results]

# %% [raw]
# for index, row in df_test.iterrows():
#     text = row["text"]
#     # Предсказания классических моделей
#     classic_preds = {
#         name: predict_message(text, vectorizer, scaler, model)[0] for name, model in classic_models.items()
#     }
#     for model_name, pred in classic_preds.items():
#         df_test.loc[index, model_name] = pred

# %%
df_test.head()
# Out:
#                                                 text  label  emojis  newlines  \
# 0                                    Очень похоже)❤️      0       1         0
# 1                                 Грозный СТАНКИН)))      0       0         0
# 3  Здравствуйте, а куда можно написать по вопроса...      0       1         0
# 4  Здравствуйте, напишите свой вопрос в данный ча...      0       0         2
# 5                           День рождения СТАНКИНА 🎉      0       1         0
#
#    whitespaces  links  tags  \
# 0            0      0     0
# 1            0      0     0
# 3            0      0     0
# 4            1      1     0
# 5            0      0     0
#
#                                    text_preprocessed  rubert_tiny2  \
# 0                                       очень похоже             0
# 1                                    грозный станкин             0
# 3  здравствуйте а куда можно написать по вопросам...             0
# 4  здравствуйте напишите свой вопрос в данный чат...             1
# 5                             день рождения станкина             0
#
#    rubert_tiny2_p
# 0               0
# 1               0
# 3               0
# 4               1
# 5               1

# %% [markdown]
# ### Сравнение

# %%
for name, model_info in rubert_models.items():
    print(name, '\n')
    print('Classification report:\n', classification_report(df_test['label'], df_test[name]))
    print("Confusion Matrix:\n", confusion_matrix(df_test['label'], df_test[name]))
    print('\n\n')
# Out:
# rubert_tiny2
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       893
#            1       0.98      0.94      0.96       999
#
#     accuracy                           0.96      1892
#    macro avg       0.96      0.96      0.96      1892
# weighted avg       0.96      0.96      0.96      1892
#
# Confusion Matrix:
#  [[877  16]
#  [ 60 939]]
#
#
#
# rubert_tiny2_p
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95       893
#            1       0.93      0.99      0.96       999
#
#     accuracy                           0.96      1892
#    macro avg       0.96      0.95      0.96      1892
# weighted avg       0.96      0.96      0.96      1892
#
# Confusion Matrix:
#  [[817  76]
#  [  5 994]]

# %% [markdown]
# **Сравнение метрик**:
#
# - **rubert_tiny2**:
#   - Accuracy (точность): 0.96
#   - Precision: 0.94 (класс 0), 0.98 (класс 1)
#   - Recall: 0.98 (класс 0), 0.95 (класс 1)
#   - F1-Score: 0.96 для обоих классов
#
# - **rubert_tiny2_p**:
#   - Accuracy (точность): 0.95
#   - Precision: 1.00 (класс 0), 0.93 (класс 1)
#   - Recall: 0.91 (класс 0), 1.00 (класс 1)
#   - F1-Score: 0.95 (класс 0), 0.96 (класс 1)
#
# ---
#
# **Анализ путаницы**:
#
# - **rubert_tiny2**:
#   - Ошибок для класса 0: 16 (ложноотрицательные)
#   - Ошибок для класса 1: 60 (ложноположительные)
#
# - **rubert_tiny2_p**:
#   - Ошибок для класса 0: 76 (ложноотрицательные)
#   - Ошибок для класса 1: 5 (ложноположительные)
#
# ---
#
# **Вывод**:
# - **rubert_tiny2** выглядит более универсальной, так как показывает более стабильные метрики на обоих классах.
# - Однако, **rubert_tiny2_p**, минимизирует вероятность ошибки для этого спам сообщений.

# %% [raw]
# for name, pred in classic_preds.items():
#     print(name, '\n')
#     print('Classification report:\n', classification_report(df_test['label'], df_test[name]))
#     print("Confusion Matrix:\n", confusion_matrix(df_test['label'], df_test[name]))
#     print('\n\n')

# %% [markdown]
# #### Строки с FN и FP для модели finetuned_rubert_tiny2

# %%
fn_rows = df_test[(df_test["label"] == 1) & (df_test["rubert_tiny2"] == 0)]
fp_rows = df_test[(df_test["label"] == 0) & (df_test["rubert_tiny2"] == 1)]

# %%
fn_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 1 to 996
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               60 non-null     object
#  1   label              60 non-null     int64
#  2   emojis             60 non-null     int64
#  3   newlines           60 non-null     int64
#  4   whitespaces        60 non-null     int64
#  5   links              60 non-null     int64
#  6   tags               60 non-null     int64
#  7   text_preprocessed  60 non-null     object
#  8   rubert_tiny2       60 non-null     int64
#  9   rubert_tiny2_p     60 non-null     int64
# dtypes: int64(8), object(2)
# memory usage: 5.2+ KB

# %%
fn_rows.head(500)
# Out:
#                                                   text  label  emojis  \
# 1                                            دانیالللل      1       0
# 8                                            اره v2ray      1       0
# 33                                          معايا 2022      1       0
# 60                                              هممونو      1       0
# 72                                          B1 به بالا      1       0
# 78                                            Saba بیا      1       0
# 85                                            13k دهنت      1       0
# 128                                        المفروض 1.2      1       0
# 183                                            23 بهمن      1       0
# 185                                     جايب 0.01 منين      1       0
# 203                                            10ونیم🤣      1       1
# 205                                         سااااقم gn      1       0
# 209                                      Saaaaaaقممممم      1       0
# 211                                         الاختيار D      1       0
# 215                                         am to ازاي      1       0
# 223                                      1/5 قدمت داره      1       0
# 231                                         2222 بودیم      1       0
# 239                                          Wow درورد      1       0
# 262                                     تقريبا 22 عظمه      1       0
# 269                                     20 گیگ بازیه😐😂      1       2
# 284                                           1 ام شب😂      1       1
# 298  Так себе старался, раз ипользует "ЧиТаТь ПрОдО...      1       0
# 303                                             دلسوزی      1       0
# 307                                          هتبقي 0.9      1       0
# 310                                           8 منين 🥲      1       1
# 317                                              𝕤𝕒𝕝𝕒𝕞      1       0
# 332                                       من  8 تقريبا      1       0
# 334                                           5 میلیون      1       0
# 385                                     Eminem میفرستی      1       0
# 395                                            ریاضی 1      1       0
# 400                           DemonKing5989 ریکوست بده      1       0
# 421                                         معايا 2021      1       0
# 435                                          هتطلع 0.6      1       0
# 436                                 مخصوصا after hours      1       0
# 439                                           شوفلنا 5      1       0
# 447                                           110 بردو      1       0
# 448                                         الوسام 110      1       0
# 484  Если так продолжишь, к след году можешь сантой...      1       0
# 489  Уверены? Обычный средний заработок для некотор...      1       0
# 549                                         Secret زدی      1       0
# 617                                              𝗵𝗲𝗹𝗹𝗼      1       0
# 625                                        اثبات 10/10      1       0
# 634                                           170 اینا      1       0
# 646  а причем тут пролетарский район? или вы так хо...      1       0
# 658                                          F أطلع 50      1       0
# 661                                     Computer البته      1       0
# 674                                   Ice tea نخوردی ؟      1       0
# 681                                       Saba فرستادم      1       0
# 682                                     منم 19 خوشبختم      1       0
# 735                                Springmoonth شیرینی      1       0
# 784                                     Saba خانوم‌صبا      1       0
# 786                                           واضح Pdf      1       0
# 798                                  Hardcore دوس داری      1       0
# 811                                     اعملى MODE 5 2      1       0
# 812                                         فرشید lion      1       0
# 833  История вообще длинная когда-то давно ещё до т...      1       0
# 852                                              𝓴𝓲𝓶𝓲𝓪      1       0
# 915                                @SatanIsGood بیاااا      1       0
# 950                                               ℜ𝔢𝔢𝔪      1       0
# 996                                          منم 11:11      1       0
#
#      newlines  whitespaces  links  tags  \
# 1           0            0      0     0
# 8           0            0      0     0
# 33          0            0      0     0
# 60          0            0      0     0
# 72          0            0      0     0
# 78          0            0      0     0
# 85          0            0      0     0
# 128         0            0      0     0
# 183         0            0      0     0
# 185         0            0      0     0
# 203         0            0      0     0
# 205         0            0      0     0
# 209         0            0      0     0
# 211         0            0      0     0
# 215         0            0      0     0
# 223         0            0      0     0
# 231         0            0      0     0
# 239         0            0      0     0
# 262         0            0      0     0
# 269         0            0      0     0
# 284         0            0      0     0
# 298         0            0      0     0
# 303         0            0      0     0
# 307         0            0      0     0
# 310         0            0      0     0
# 317         0            0      0     0
# 332         0            1      0     0
# 334         0            0      0     0
# 385         0            0      0     0
# 395         0            0      0     0
# 400         0            0      0     0
# 421         0            0      0     0
# 435         0            0      0     0
# 436         0            0      0     0
# 439         0            0      0     0
# 447         0            0      0     0
# 448         0            0      0     0
# 484         0            0      0     0
# 489         0            0      0     0
# 549         0            0      0     0
# 617         0            0      0     0
# 625         0            0      0     0
# 634         0            0      0     0
# 646         0            0      0     0
# 658         0            0      0     0
# 661         0            0      0     0
# 674         0            0      0     0
# 681         0            0      0     0
# 682         0            0      0     0
# 735         0            0      0     0
# 784         0            0      0     0
# 786         0            0      0     0
# 798         0            0      0     0
# 811         0            0      0     0
# 812         0            0      0     0
# 833         0            2      0     0
# 852         0            0      0     0
# 915         0            0      0     1
# 950         0            0      0     0
# 996         0            0      0     0
#
#                                      text_preprocessed  rubert_tiny2  \
# 1                                            دانیالللل             0
# 8                                            اره v2ray             0
# 33                                          معايا 2022             0
# 60                                              هممونو             0
# 72                                          b1 به بالا             0
# 78                                            saba بیا             0
# 85                                            13k دهنت             0
# 128                                         المفروض 12             0
# 183                                            23 بهمن             0
# 185                                      جايب 001 منين             0
# 203                                             10ونیم             0
# 205                                         سااااقم gn             0
# 209                                      saaaaaaقممممم             0
# 211                                         الاختيار d             0
# 215                                         am to ازاي             0
# 223                                       15 قدمت داره             0
# 231                                         2222 بودیم             0
# 239                                          wow درورد             0
# 262                                     تقريبا 22 عظمه             0
# 269                                       20 گیگ بازیه             0
# 284                                            1 ام شب             0
# 298  так себе старался раз ипользует читать продолж...             0
# 303                                             دلسوزی             0
# 307                                           هتبقي 09             0
# 310                                             8 منين             0
# 317                                              𝕤𝕒𝕝𝕒𝕞             0
# 332                                        من 8 تقريبا             0
# 334                                           5 میلیون             0
# 385                                     eminem میفرستی             0
# 395                                            ریاضی 1             0
# 400                           demonking5989 ریکوست بده             0
# 421                                         معايا 2021             0
# 435                                           هتطلع 06             0
# 436                                 مخصوصا after hours             0
# 439                                           شوفلنا 5             0
# 447                                           110 بردو             0
# 448                                         الوسام 110             0
# 484  если так продолжишь к след году можешь сантой ...             0
# 489  уверены обычный средний заработок для некоторы...             0
# 549                                         secret زدی             0
# 617                                              𝗵𝗲𝗹𝗹𝗼             0
# 625                                         اثبات 1010             0
# 634                                           170 اینا             0
# 646  а причем тут пролетарский район или вы так хот...             0
# 658                                          f أطلع 50             0
# 661                                     computer البته             0
# 674                                     ice tea نخوردی             0
# 681                                       saba فرستادم             0
# 682                                     منم 19 خوشبختم             0
# 735                                springmoonth شیرینی             0
# 784                                      saba خانومصبا             0
# 786                                           واضح pdf             0
# 798                                  hardcore دوس داری             0
# 811                                     اعملى mode 5 2             0
# 812                                         فرشید lion             0
# 833  история вообще длинная когдато давно ещё до тв...             0
# 852                                              𝓴𝓲𝓶𝓲𝓪             0
# 915                                       [TAG] بیاااا             0
# 950                                               ℜ𝔢𝔢𝔪             0
# 996                                           منم 1111             0
#
#      rubert_tiny2_p
# 1                 1
# 8                 1
# 33                1
# 60                1
# 72                1
# 78                1
# 85                1
# 128               1
# 183               1
# 185               1
# 203               1
# 205               1
# 209               1
# 211               1
# 215               1
# 223               1
# 231               1
# 239               1
# 262               1
# 269               1
# 284               1
# 298               0
# 303               1
# 307               1
# 310               1
# 317               1
# 332               1
# 334               1
# 385               1
# 395               1
# 400               1
# 421               0
# 435               1
# 436               1
# 439               1
# 447               1
# 448               1
# 484               0
# 489               0
# 549               1
# 617               1
# 625               1
# 634               1
# 646               0
# 658               1
# 661               1
# 674               1
# 681               1
# 682               1
# 735               1
# 784               1
# 786               1
# 798               1
# 811               1
# 812               1
# 833               1
# 852               1
# 915               1
# 950               1
# 996               1

# %%
fp_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 4 to 846
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               16 non-null     object
#  1   label              16 non-null     int64
#  2   emojis             16 non-null     int64
#  3   newlines           16 non-null     int64
#  4   whitespaces        16 non-null     int64
#  5   links              16 non-null     int64
#  6   tags               16 non-null     int64
#  7   text_preprocessed  16 non-null     object
#  8   rubert_tiny2       16 non-null     int64
#  9   rubert_tiny2_p     16 non-null     int64
# dtypes: int64(8), object(2)
# memory usage: 1.4+ KB

# %%
fp_rows.head(500)
# Out:
#                                                   text  label  emojis  \
# 4    Здравствуйте, напишите свой вопрос в данный ча...      0       0
# 151  Здорово! Отличная возможность для молодых пред...      0       0
# 153  Отличная возможность отдохнуть на Черноморском...      0       0
# 196  Это отличная возможность вернуться к хакатонам...      0       2
# 314  Ищу кто на 38.03.02\nПишите в личку, будем общ...      0       1
# 444  Если вопросы какие-нибудь есть - пишите) По во...      0       1
# 501  Отличный отдых, полный активного времяпрепрово...      0       0
# 566  Отлично проведенное мероприятие, полное весель...      0       0
# 611   Круто! Цифровой рубль - новинка с потенциалом! 💰      0       1
# 613  Зачем нужен цифровой рубль (ЦР):\n1. Платить Ц...      0       0
# 620  Великолепная встреча! Развитие сотрудничества ...      0       1
# 621  Классные приключения в общежитии, с новыми дру...      0       2
# 622  Hello every one, I am student of PhD program, ...      0       0
# 624  I dunno how many rubles Russian government wil...      0       0
# 642  Please call this number 84999729411 and ask th...      0       0
# 846      Продолжать активный отдых в Санкт-Петербурге)      0       0
#
#      newlines  whitespaces  links  tags  \
# 4           2            1      1     0
# 151         0            0      0     0
# 153         0            0      0     0
# 196         0            0      0     0
# 314         1            0      0     0
# 444         0            0      0     0
# 501         0            0      0     0
# 566         0            0      0     0
# 611         0            0      0     0
# 613         3            1      0     0
# 620         0            0      0     0
# 621         0            0      0     0
# 622         1            0      0     0
# 624         0            0      0     0
# 642         0            0      0     0
# 846         0            0      0     0
#
#                                      text_preprocessed  rubert_tiny2  \
# 4    здравствуйте напишите свой вопрос в данный чат...             1
# 151  здорово отличная возможность для молодых предп...             1
# 153  отличная возможность отдохнуть на черноморском...             1
# 196  это отличная возможность вернуться к хакатонам...             1
# 314  ищу кто на 380302 пишите в личку будем общатьс...             1
# 444  если вопросы какиенибудь есть пишите по возмож...             1
# 501  отличный отдых полный активного времяпрепровож...             1
# 566  отлично проведенное мероприятие полное веселья...             1
# 611         круто цифровой рубль новинка с потенциалом             1
# 613  зачем нужен цифровой рубль цр 1 платить цр деш...             1
# 620  великолепная встреча развитие сотрудничества с...             1
# 621  классные приключения в общежитии с новыми друз...             1
# 622  hello every one i am student of phd program i ...             1
# 624  i dunno how many rubles russian government wil...             1
# 642  please call this number 84999729411 and ask th...             1
# 846        продолжать активный отдых в санктпетербурге             1
#
#      rubert_tiny2_p
# 4                 1
# 151               1
# 153               1
# 196               1
# 314               1
# 444               1
# 501               0
# 566               1
# 611               1
# 613               1
# 620               1
# 621               1
# 622               1
# 624               1
# 642               1
# 846               1

# %%
fp_rows[['text', 'label']].to_dict('records')
# Out:
# [{'text': 'Здравствуйте, напишите свой вопрос в данный чат \n\nhttps://t.me/stankinpkchat',
#   'label': 0},
#  {'text': 'Здорово! Отличная возможность для молодых предпринимателей реализовать свои мечты и найти партнеров. Соревнование в двух лигах, так что каждый найдет свое место. Не упусти шанс и отправляй заявку прямо сейчас!',
#   'label': 0},
#  {'text': 'Отличная возможность отдохнуть на Черноморском побережье! Пожелаем ребятам высоких результатов в соревнованиях и море положительных эмоций на отдыхе!',
#   'label': 0},
#  {'text': 'Это отличная возможность вернуться к хакатонам и открыться новым приключениям с командой единомышленников! Не теряйте времени и подавайте заявку на участие прямо сейчас. Удачи в создании компьютерной игры и получении ценных призов!🎮🔥',
#   'label': 0},
#  {'text': 'Ищу кто на 38.03.02\nПишите в личку, будем общаться, знакомится! ☺️',
#   'label': 0},
#  {'text': 'Если вопросы какие-нибудь есть - пишите) По возможности постараюсь ответить🙃',
#   'label': 0},
#  {'text': 'Отличный отдых, полный активного времяпрепровождения и спортивных достижений! Каждый момент был наполнен весельем и зарядил энергией на весь учебный год. Классно, что такие поездки позволяют завязывать новые дружеские связи и обмениваться опытом с другими студентами. Желаю всем хорошо отдохнуть и с новыми силами приступить к занятиям!',
#   'label': 0},
#  {'text': 'Отлично проведенное мероприятие, полное веселья и культурного обмена. Рад видеть, как молодежь со всего мира объединяется в одно целое. Желаю всем отлично отдохнуть и зарядиться позитивной энергией!',
#   'label': 0},
#  {'text': 'Круто! Цифровой рубль - новинка с потенциалом! 💰', 'label': 0},
#  {'text': 'Зачем нужен цифровой рубль (ЦР):\n1. Платить ЦР дешевле , чем печатными деньгами \n2. Следить за передвижение ЦР проще (так как наличных уже не будет в последствии)\n3. Ограничить человека и лишить его всех благ проще с ЦР',
#   'label': 0},
#  {'text': 'Великолепная встреча! Развитие сотрудничества с Китаем - шаг вперед для нас и для дружбы двух стран. 🌍',
#   'label': 0},
#  {'text': 'Классные приключения в общежитии, с новыми друзьями и смешными историями! Удачи в поиске артефактов! 🕵️\u200d♀️✨',
#   'label': 0},
#  {'text': 'Hello every one, I am student of PhD program, I am coming to university next month, please some one tell me that how many rupees per month for a PhD student is given by the Russian government, please please answer my question\nThanks',
#   'label': 0},
#  {'text': 'I dunno how many rubles Russian government will give u, but I know that u need at least 20-25 thousand rubles per month',
#   'label': 0},
#  {'text': 'Please call this number 84999729411 and ask this question at the Center for International Cooperation',
#   'label': 0},
#  {'text': 'Продолжать активный отдых в Санкт-Петербурге)', 'label': 0}]
