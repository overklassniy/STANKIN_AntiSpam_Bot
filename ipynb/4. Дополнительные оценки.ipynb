# %% [markdown]
# # Дополнительные оценки качества моделей

# %% [markdown]
# ## Импорт необходимых библиотек

# %%
import os
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix
from transformers import pipeline
from scipy.sparse import hstack
from datasets import Dataset
from copy import deepcopy
import regex
import re
import emoji

# %% [markdown]
# ## Чтение тестовых данных

# %% [markdown]
# ### Данные с чистыми сообщениями

# %% [markdown]
# `data/test_clear.json` – `.json` файл структуры `[{"text": "blablabla", "label": 0}]`, где ключ `text` представляет текстовое значение сообщения, а ключ `label` – класс сообщения (0: безопасное, 1: опасное).
# Сообщения были собраны из открытых Telegram чатов различных ВУЗов.

# %%
df_clear = pd.read_json('../data/test_clear.json')

# %%
df_clear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25274 entries, 0 to 25273
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    25274 non-null  object
#  1   label   25274 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 395.0+ KB

# %%
df_clear.head()
# Out:
#                                                 text  label
# 0  Здравствуйте, подскажите, пожалуйста, программ...      0
# 1  Получается, все тоже самое, но теперь диплом т...      0
# 2  Извините, а где можно узнать Актуальные маг пр...      0
# 3  Добрый вечер, подскажите пожалуйста, есть ли з...      0
# 4          Здравствуйте! Только очная форма обучения      0

# %% [markdown]
# ### Данные со спам сообщениями

# %% [markdown]
# `data/parsed_lols_2023.txt` – `.txt` файл с набором спам-сообщений.
# Файл был получен с [lols.bot](https://lols.bot/2023/)

# %%
parsed_lols_2023 = open('../data/parsed_lols_2023.txt', 'r', encoding='utf-8').readlines()

# %%
for i in range(len(parsed_lols_2023)):
    parsed_lols_2023[i] = parsed_lols_2023[i].replace('<br/>', '', 1).strip().replace('<br/>', '\n')

# %%
len(parsed_lols_2023)
# Out:
# 32437

# %%
df_spam = pd.DataFrame()
df_spam['text'] = parsed_lols_2023
df_spam['label'] = [1] * len(parsed_lols_2023)

# %%
df_spam.head()
# Out:
#                                                 text  label
# 0  🤝ƃАЗA ЧAT𝖮B ᎩCЛᎩГ🤝 + Б𝖮Т AВTОРАСCЫЛKИ🚀<br>\n❗️...      1
# 1                                          دانیالللل      1
# 2  🤙🏻🤘🏻Caмo𝚎 cлoжное нa сеpoм рынке — это найти н...      1
# 3                                          𝙇 𝘼 𝙈 𝙄 𝘼      1
# 4  🔲DROP SERVICE🔲<br><br>☕️ 𝔸ℝ𝔸𝔹𝕀ℂ𝔸×ℝ𝕆𝔹𝕌𝕊𝕋𝔸 ☕️ \n...      1

# %% [markdown]
# ### Объединение данных

# %%
df_test = pd.concat([df_clear, df_spam])

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57711 entries, 0 to 32436
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    57711 non-null  object
#  1   label   57711 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df_test.head()
# Out:
#                                                 text  label
# 0  Здравствуйте, подскажите, пожалуйста, программ...      0
# 1  Получается, все тоже самое, но теперь диплом т...      0
# 2  Извините, а где можно узнать Актуальные маг пр...      0
# 3  Добрый вечер, подскажите пожалуйста, есть ли з...      0
# 4          Здравствуйте! Только очная форма обучения      0

# %% [markdown]
# ## Обработка данных

# %% [markdown]
# ### Создание новых столбцов с числовыми данными

# %% [markdown]
# В спам сообщениях очень часто используются эмодзи, ссылки, теги (`@`), много новых строк (`\n`) и лишних пробелов, так что их количество в сообщении может играть большую роль в классификации сообщений

# %% [markdown]
# #### Функции для подготовки текста и дополнительных числовых данных

# %% [markdown]
# > Эти же функции находятся в `../utils/preprocessing.py`.

# %%
def count_emojis(text: str) -> int:
    """
    Считает количество эмодзи в тексте.

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        int: Количество найденных эмодзи.
    """
    # Разбиваем текст на "графемные кластеры" (учитывая составные эмодзи)
    data = regex.findall(r'\X', text)
    # Считаем эмодзи
    emoji_counter = sum(emoji.is_emoji(word) for word in data)
    return emoji_counter

# %%
def count_newlines(text: str) -> int:
    """
    Считает количество символов новой строки (\n) в тексте.

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        int: Количество символов новой строки.
    """
    # Подсчёт символов новой строки
    newline_count = text.count('\n')
    return newline_count

# %%
def count_whitespaces(text: str) -> int:
    """
    Считает количество последовательных пробелов (два или более) в тексте.

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        int: Количество найденных последовательных пробелов.
    """
    # Считаем последовательности из двух и более пробелов
    extra_spaces_count = len(re.findall(r'\s{2,}', text))
    return extra_spaces_count

# %%
# Регулярное выражение для ссылок
url_pattern = r'(https?://[^\s]+|www\.[^\s]+|[a-zA-Z0-9.-]+\.[a-zA-Z]{2,}(?:/[^\s]*)?)'

# %%
def count_links(text: str) -> int:
    """
    Считает количество ссылок в тексте.

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        int: Количество найденных ссылок.
    """
    # Найти все ссылки в тексте
    links = re.findall(url_pattern, text)
    return len(links)

# %%
def count_tags(text: str) -> int:
    """
    Считает количество упоминаний (тегов) в тексте.

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        int: Количество найденных тегов.
    """
    # Подсчёт символов "@" как маркеров тегов
    tag_count = text.count('@')
    return tag_count

# %% [markdown]
# Удаление пунктуации и эмодзи, приведение к нижнему регистру может снизить шум и сложность модели

# %%
def remove_emojis(text: str) -> str:
    """
    Удаляет все эмодзи из текста.

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        str: Текст без эмодзи.
    """
    # Разбиваем текст на "графемные кластеры"
    data = regex.findall(r'\X', text)
    # Удаляем все эмодзи
    text_without_emojis = ''.join(word for word in data if not emoji.is_emoji(word))
    return text_without_emojis

# %% [markdown]
# Ссылки и тэги без пунктуации превращаются в набор латинских символов, что будет мешать работе модели, но при этом их нельзя удалять из текстов, так как это важные маркеры. Поэтому их необходимо заменить на что-то вроде `[LINK]` и `[TAG]`

# %%
def replace_links(text: str) -> str:
    """
    Заменяет все ссылки в тексте на "[LINK]".

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        str: Текст с заменёнными ссылками.
    """
    # Заменить ссылки на [LINK]
    text = re.sub(url_pattern, '[LINK]', text)
    return text

# %%
def replace_tags(text: str) -> str:
    """
    Заменяет все упоминания (теги) в тексте на "[TAG]".

    Параметры:
        text (str): Исходный текст.

    Возвращает:
        str: Текст с заменёнными тегами.
    """
    # Регулярное выражение для тегов
    tag_pattern = r'@[a-zA-Z0-9_]+'
    # Замена тегов на [TAG]
    text = re.sub(tag_pattern, '[TAG]', text)
    return text

# %%
def preprocess_text(
        text: str,
        lower: bool = True,
        remove_punctuation: bool = True,
        remove_emoji: bool = True,
        remove_whitespaces: bool = True,
        remove_links: bool = True,
        remove_tags: bool = True
) -> str:
    """
    Предобрабатывает текст, включая нормализацию регистра, удаление пунктуации, эмодзи, ссылок, тегов и пробелов.

    Параметры:
        text (str): Исходный текст.
        lower (bool): Приводить ли текст к нижнему регистру (по умолчанию True).
        remove_punctuation (bool): Удалять ли пунктуацию (по умолчанию True).
        remove_emoji (bool): Удалять ли эмодзи (по умолчанию True).
        remove_whitespaces (bool): Удалять ли лишние пробелы (по умолчанию True).
        remove_links (bool): Удалять ли ссылки (по умолчанию True).
        remove_tags (bool): Удалять ли теги (по умолчанию True).

    Возвращает:
        str: Обработанный текст.
    """
    # Приведение текста к нижнему регистру
    if lower:
        text = text.lower()
    # Замена ссылок на [LINK]
    if remove_links:
        text = replace_links(text)
    # Замена тегов на [TAG]
    if remove_tags:
        text = replace_tags(text)
    # Удаление пунктуации
    if remove_punctuation:
        text = re.sub(r'[^\w\s]', '', text)  # Удаляет пунктуацию
        # Восстановление [LINK] после очистки пунктуации
        if remove_links:
            text = text.replace('LINK', '[LINK]')
        # Восстановление [TAG] после очистки пунктуации
        if remove_tags:
            text = text.replace('TAG', '[TAG]')
    # Удаление эмодзи
    if remove_emoji:
        text = remove_emojis(text)
    # Удаление лишних пробелов и символов новой строки
    if remove_whitespaces:
        text = re.sub(r'\s+', ' ', text).strip()
    return text

# %% [markdown]
# #### Подготовка текста и дополнительных числовых данных

# %%
emojis_count = []
newlines_count = []
whitespaces_count = []
links_count = []
tags_count = []
for text in df_test['text']:
    emojis_count.append(count_emojis(text))
    newlines_count.append(count_newlines(text))
    whitespaces_count.append(count_whitespaces(text))
    links_count.append(count_links(text))
    tags_count.append(count_tags(text))

# %%
df_test['emojis'] = emojis_count
df_test['newlines'] = newlines_count
df_test['whitespaces'] = whitespaces_count
df_test['links'] = links_count
df_test['tags'] = tags_count

# %%
df_test.head()
# Out:
#                                                 text  label  emojis  newlines  \
# 0  Здравствуйте, подскажите, пожалуйста, программ...      0       0         3
# 1  Получается, все тоже самое, но теперь диплом т...      0       0         0
# 2  Извините, а где можно узнать Актуальные маг пр...      0       0         0
# 3  Добрый вечер, подскажите пожалуйста, есть ли з...      0       0         0
# 4          Здравствуйте! Только очная форма обучения      0       0         0
#
#    whitespaces  links  tags
# 0            2      1     0
# 1            0      0     0
# 2            0      0     0
# 3            0      0     0
# 4            0      0     0

# %%
texts = list(deepcopy(df_test['text']))
for text_i in range(len(texts)):
    temp = preprocess_text(texts[text_i])
    if not temp:
        temp = np.nan
    texts[text_i] = temp

# %%
texts
# Out:
# ['здравствуйте подскажите пожалуйста программу магистерскую с университетом туши не убрали вот эту [LINK]',
#  'получается все тоже самое но теперь диплом только российский',
#  'извините а где можно узнать актуальные маг программы которые не приостановлены',
#  'добрый вечер подскажите пожалуйста есть ли заочная форма обучения по направлению международная безопасность',
#  'здравствуйте только очная форма обучения',
#  'здравствуйте подскажите пожалуйста будут ли в этом году выдавать сертификаты на облегчённое поступление призёрампобедителям заключительного этапа всош по физкультуре',
#  'если будут то какие права даёт этот сертификат спасибо',
#  'здравствуйте скажите пожалуйста а когда будет следующий день открытых дверей и можно ли туда идти тем кто собирается в магистратуру',
#  'from a friend',
#  'здравствуйте надо ли на это мероприятие регистрироваться',
#  'добрый день насколько увеличится количество бюджетных мест в этом году',
#  'здравствуйте не нужно',
#  'здравствуйте 200522 в 1900 будет ночь в универе',
#  'здравствуйте с количеством бюджетных мест по каждому направлению вы можете ознакомиться по ссылке [LINK]',
#  'нужна ли регистрация на мероприятие',
#  nan,
#  'нет до встречи',
#  'добрый день программа только для студентов или абитуриенты тоже могут принять участие',
#  'добрый день в программе могут участвовать все желающие',
#  'здравствуйте можно ли сдать вступительные испытания в магистратуру дистанционно',
#  'я хочу поступить очень очень',
#  'очень хотелось бы увидеть фотографии с секций в частности факультета мировая экономика',
#  'здравствуйте вы можете посмотреть некоторые залы экономического и имэб',
#  'здравствуйте',
#  'я посмотрел на ближайший день открытых дверей и у меня возник вопрос а для посещения данного мероприятия нужно какуюто заявку оставлять или в этом нет необходимости',
#  'здравствуйте день абитуриента 16 июля вход свободный',
#  'спасибо большое',
#  'наверное учиться в вашем институте нужно очень много денегпростым туда не попасть',
#  'ключевое слово у вас наверное учёба это инвестиция для будущего',
#  'здравствуйте у меня сейчас паспорт биометрический для поступления нужен загранпаспорт чтобы получить загранпаспорта мне надо выехать из рф я не хотел время потерять',
#  'я гражданин узбекистана',
#  'согласна с вамино когда одна мама это просто нереально ей выучить меня',
#  'прошу мне простить я не думал об этом',
#  'здравствуйте по данному вопросу просим вас обратиться в отдел стран снг 7 495 7873803 доп 2562 или 2197',
#  'спасибо большое вам',
#  'здравствуйте никак не найду где информация о подаче документов в этом году что и как надо сделать может поможете ссылкой пожалуйста',
#  'здравствуйте что вас именно интересует уточните пожалуйста',
#  'до какого числа и где подать документы какие нужны',
#  'вы поступаете на бакалавриатспециалитет после школы на какое направление',
#  'после школы лингвистика',
#  'а где про всё можно почитать',
#  'приём документов начинается с 2006 подробную информацию про направления вы можете посмотреть на сайте [LINK]',
#  'не смогла открыть в каком разделе это находится вот на сайте не найду ни как',
#  nan,
#  'подскажите пожалуйста где можно найти информацию по поводу перевода из другого вуза',
#  'здравствуйте',
#  'комиссия работает вживую',
#  'здравствуйте по вопросам перевода просим вас обращаться в отдел перевода и восстановления 7 495 4342612',
#  'здравствуйте да работает',
#  'класс',
#  'привет всем скажите пожалуйста как можно поступает рудн _',
#  'добрый день уточните пожалуйста какое у вас гражданство и направление куда поступаете',
#  'по поводу ординатуры тоже можно будет подойти уточнить',
#  'здравствуйте да конечно если вас интересуют детали обучения просим обращаться в медицинский институт ул миклухомаклая д8 либо по номеру 8926132 9378',
#  'гранты предоставляются для граждан рф',
#  'здравствуйте на указанный телефон никто не отвечает',
#  'как узнать точную стоимость на интересующее направление',
#  'также где уточнить профиль по направлению на сайте инфо не смогла найти',
#  'здравствуйте елена коллцентр приёмной комиссии рудн работает с 900 до 1800 стоимость направления и профили бакалавриата указаны [LINK]',
#  'уточните профиль для 420301реклама и связи с общественностью заочное пожалуйста',
#  'по ссылке нет информации',
#  'спасибо',
#  'связи с общественностью есть на филологическом факультете рудн стоимость 155000 руб за один год',
#  'спасибо наталья но я про профиль',
#  'здравствуйтесобираемся к вам поступатьподскажитехимия у нас в резервный день2 июлясоответственнорезультаты егэ мы получим позжечем большинство ребятможно ли заключить предварительный договор до получения результатов егэ по химии',
#  nan,
#  'можно',
#  nan,
#  'здравствуйте приём документов на ординатуру начинается с первого июля',
#  'здравствуйте я гражданин бангладеша выпускник рудн с 1ого июля мы должны подавать документы',
#  'спасибо последний экзамен 15успеем с результатами или можно подать заявку раньше',
#  'может быть только промежуточная аттестация есть уже аттестат только после результатов обязательных экзаменов же',
#  'скажите пожалуйста за два года обучения в ординатуру сколько стоит я иностранка',
#  'не рф',
#  'я хочу пройти ординатуру по узи',
#  'в этом году хочу сдать документы',
#  'моё гражданство таджикистан',
#  'те снг',
#  'я прошла нострификацию и рособрнадзор',
#  'теперь осталась пройти ординатуру',
#  'спасибо большое за информацию',
#  'оплату можно каждый семестр',
#  'или сразу',
#  'надеемся спасибо',
#  'спасибо большое',
#  'экзаменационные тестовые вопросы тоже на сайте',
#  'добрый день куда можно подавать документы на бюджет в аспирантуру сразу подаётся портфолио и мотивационное письмо верно я понимаю юридический ещё вопрос индивидуальные достижения распечатывать все статьи',
#  'добрый деньхотел проконсультироватьсяя абитуриентвыпускник 11класса с освобождённой территории а именно с донецкой областиднргволноваха школа номер 5 я желаю поступить в вуз рудн на факультет международных отношенийкак мне это сделать и какие документы нужно подаватьвозможно ли иностранным гражданам поступать на эту специальность',
#  'здравствуйте пытаемся подать документы через сайт но выбрав факультет русский язык или лингвистика нам выдаёт только оченьзаочную и заочную формы обучения хотя на сайте указаны и очные формы данных факультетов',
#  'благодарю',
#  'здравствуйте можно ли уже сейчас заключить предварительный договор на очную форму обучения и если да то как это сделать спасибо',
#  'здравствуйте подскажите пожалуйста призерство в олимпиаде интеллектуальный мегаполис потенциал учитывается ли при поступлении на бакалавриат в университет начисляются ли за это дополнительные баллы',
#  nan,
#  'добрый день подскажите пожалуйста если я поступаю на ординатуру по квоте россотрудничества с кем и по какому номеру нужно связаться для уточнения некоторых вопросов',
#  'благодарю',
#  'здравствуйте подскажите пожалуйста итоговое сочинение даёт дополнительные баллы',
#  'добрый вечер подскажите пожалуйста работает ли сейчас образовательный кредит',
#  'спасибо',
#  'подскажите какие экзамены нужны на направление ибероамерика',
#  'да после школы 410301 зарубежное регионоведение профиль ибероамерика',
#  'доброе утро как заключить предварительный договор у нас тоже поздно последний экзамен аттестаты и результаты пока не известны',
#  'вместо аттестата постараемся сегодня получить хотя бы справку',
#  'хотели на биологию химию или психологию только эти специальности нам доступны по выбору химия и биологи профильные а математика нет',
#  'здравствуйте где в чате можно задавать вопросы о поступлении',
#  'при поступлении на суд мед эксперта после 11 класса нужно ли сдавать английский язык и в каком объеме он изучается в университете',
#  'уточните справка из военкомата приписноедля призывного возраста требуется',
#  'спасибо большое',
#  nan,
#  'добрый день а если заключил предварительный договор оплатил а стоимость обучения к моменту заключения основного договора стала меньше какие в таком случае действия',
#  'здравствуйте есть ли файл со всеми перечнями нужной информации для дви на факультет журналистики и телевидения и можно ли проходить дви онлайн',
#  'да уже смотрела эти файлы но там представлены лишь парочка вопросов нет определенного перечня',
#  'здравствуйте подскажите пожалуйста на счёт поступление иностранным гражданамв моем случае со освобождённой территории днрпо направлению юриспруденция какие экзамены требуют или никаких',
#  'здравствуйте подскажите пожалуйста для специальности 231 системный анализ управление и обработка информации какое будет направление подготовки раньше например было для специальности 051301 направление 090601',
#  'здравствуйте а вступительные экзамены будут в устной форме или в письменнойтесты',
#  'есть возможность гражданам узбекистана поступить на бюджет на стоматологию',
#  'благодарю за внимание',
#  'родители нужны при личной подаче документов',
#  'сколько бюджетных мест при поступлении на базе спо подскажите пожалуйста',
#  'лечебное дело',
#  'это после спо правильно понимаю',
#  'а если в другом городе находимся3000км нельзя заочно подписать',
#  nan,
#  'хорошо а если бюджет а не контракт',
#  'добрый вечер нужна ли справка 086у для поступления в ординатуру если да то есть перечень специалистов спасибо',
#  'спасибо большое',
#  'здравствуйте хочу поступить в рудн хотел узнать есть ли русскоарабское или англоарабское направление',
#  'здравствуйте с результатами егэ по русскому языку и литературе есть возможность попасть в какой нибудь факультет',
#  'с вступительными',
#  'благодарю',
#  'спасибо большое за информацию',
#  'а есть бюджетная система на этой направлении для иностранцев',
#  'добрый день гражданин таджикистана',
#  'спасибо за информацию',
#  'здравствуйте а когда нужно производить оплату за обучение это ближе к сентябрю уже',
#  'именно для поступающих',
#  'добрый вечер подскажите пожалуйста есть ли какието курсы для подготовки к вступительным экзаменам на архитектуру',
#  'а про психологический факультет пост будет',
#  'здравствуйте подскажите пожалуйста почему на сайте в разделе калькулятор егэ пропал предмет русский язык изза этого нет возможности подобрать по своим баллам факультет',
#  'и очень хочется пост про факультет психологииспасибо',
#  'можно пост про факультет стоматологии пожалуйста',
#  'добрый день подскажите по общежитиям для иногородних',
#  'добрый деньпро лечебный факультетпожалуйста',
#  'спасибо за информацию',
#  'добрый день про факультет химия можно пост',
#  'здравствуйте можно пост про ландшафтную архитектуру',
#  'здравствуйте подскажите пожалуйста по какому адресу можно подать документы на поступление',
#  'добрый день подскажите пожалуйста нужны ли дви для поступления на эту специальность',
#  'добрый день подскажите есть ли у целевое поступление в рудн',
#  'добрый день при подачи оригиналов документов лично есть гарантия что поступим',
#  'спасибо',
#  'здравствуйте скажите пожалуйста лечебный факультет где находится',
#  'здравствуйте скажите пожалуйста а можно ли оплатить контракт по частям за семестр',
#  'здравствуйте а где на сайте просмотреть проходные баллы 2021 года',
#  'добрый ден подскажите пожалуйста подходит ли высшее образование мпф на поступление в ординатуру лабораторный генетик нужна ли переподготовка какая спасибо с уважением ольга',
#  'медико профилактическое дело',
#  'спасибо где можно узнать список направлений с дви и предметами для сдачи',
#  'благодарю',
#  'здравствуйте скажите пожалуйста а на день открытых дверей паспорт с собой брать или не надо',
#  'добрый день с чего начинать абитуриент у который хочет поступить в ваш вуз',
#  'индивидуальне достиженияимеется ввиду грамоты дипломы правильно',
#  'или ещё чтото',
#  'например мой ребенокзакончил в этом году 11 кадетский класс',
#  'спасибо большое вчера долго искала не могла найти',
#  'добрый вечер подскажите пожалуйста в какие сроки проходит подача заявлений о согласии на зачисление магистратура и можно ли подать заявление и необходимые к нему документы онлайн',
#  'здравствуйте какие анализы нужно сдавать к справке 086у для поступления на лечебное дело',
#  'здравствуйте когда вступительные экзамены на телевидение',
#  'здравствуйте так будут в этом году олимпиады по английскому истории русскому и как в них принять участие',
#  'в ординатуру так можно',
#  'благодарю доверенное лицо сможет сдать документы',
#  'по нотариально заверенной доверенности',
#  'добрый день я так понимаю и на бюджет и на платную основу ви сдаются дистанционно',
#  'здраствуйте как поступить если я из украины',
#  'добрый день хотелось уточнить возможно ли зарегистрироваться на ви или уже нет',
#  nan,
#  'здравствуйте я поступаю по целевому заявку в вуз подала вчера на госуслугах а завтра еду забирать договор из офиса предприятия в заявке указано что я по целевому но мне кажется я должна и сам договор приложить мне привезти договор в приемку или сфотографировать и оформить заявку отдельно на сайте вуза',
#  'каждый день',
#  'как подать заявление онлайн на поступление в мединститут проживающему в днр',
#  'здравствуйте скажите пожалуйста у вас есть обучение на логопеда именно на логопеда к сожалению не могу найти на сайте',
#  'здравствуйте уже срок вступительных испытаний закончилось больше нет шансов',
#  'здесь июль написано',
#  nan,
#  'хорошо спасибо',
#  'до скольки будет мероприятие',
#  'здравствуйтедочь получила по егэ по английскому языку 32 б хочет поступить в институт иностранных языков на платной основе на факультетязыки и межкультурная коммуникация лингвистика перевод и переводоведениеесть ли у неё шанс',
#  'тоесть минимальный порог на лингвистику 39 б и даже на платную основу',
#  'так называемый порог да',
#  'и на сайте порог 35 б так вроде пишет',
#  nan,
#  'еще одна причина поступить в рудн',
#  'каждый день можно прийти и узнать нужный факультет',
#  'подскажите пожалуйста где на сайте можно посмотреть списки абитуриентов подавших заявление на конкурс',
#  'поздравляем будьте счастливы',
#  'урааааа',
#  'здравствуйте скажите пожалуйстау вас есть целевые места на программе государственное и муниципальное управление',
#  'шатер каждый день работает',
#  'а у вас там можно покушать',
#  'здравствуйте у меня такой вопрос могу ли я подать документы в ваш вуз но справку 086 у донести позже позже заявленных сроков так как не успеваю мед факультет',
#  'а есть ли возможность перевода из другого университета как это происходит и на какой курс',
#  'да можно поподробнее мы специально медкомиссию для вуза сдавали я думала и на госуслугах прикреплять ее надо',
#  'я думала это необходимо мастхэв так сказать',
#  'добрый день интересует платное отделение эколог психолог ветеринар нужны ли дополнительные испытания и какие сроки подачи документов начало и конец',
#  'не нашла списки на лечебный факультет пожалуйста помогите',
#  'на каком расстоянии от рудн находится шатер',
#  'благодарю',
#  'здравствуйте подскажите пожалуйста по направлению математика и компьютерные науки можно поступить только по целевой квоте или есть и общий конкурс а то на разных страницах сайта разная информация об этом',
#  'здравствуйте есть ли отдельный список поступающих в сочинский филиал рудн',
#  'очень жаль но через личный кабинет абитуриента нет возможности подать документы завис',
#  'здравствуйте хотелось бы спросить как лучше подавать документы через личный кабинет на сайте или через госуслуги ещё хотела уточнить все ли иногородние получают место в общежитии',
#  '1 в процессе онлайнподачи заявления абитуриента по направлению магистратуры 450402 лингвистика предложен раздел портфолио при выборе данного раздела предлагается графа перевод и собеседование по его завершении правильно ли я понимаю что необходимо подать заявление абитуриента с необходимыми имеющимися документами а собеседование будет проведено позже и данную графу заполнять не нужно иначе как заполнять данный раздел когда будут известны точные даты собеседования и вступительного испытания кем они назначаются аналогичный вопрос по направлению подготовки юриспруденция и разделу творческое задание и его защита в форме собеседования 2 в личном кабинете при выборе индивидуальных достижений абитуриентов отсутствует диплом бакалавра с отличием есть магистратура аспирантура бакалавра нет по адресу support[LINK] который был дан консультантом приемной комиссии никто не отвечает я не могу подать заявление абитуриента без данного индивидуального достижения которое предоставляет дополнительные баллы прошу содействия в устранении данной проблемы 3 прошу подсказать как будет осуществляться отбор на разные направления подготовки юриспруденция предложены несколько вариантов направлений программ но вступительное испытание одно для всех правильно ли я понимаю что для всех программ обучения будет единый конкурс как будет происходить распределение по программам если в заявление абитуриента конкретная программа не указывается а только направление подготовки 400401 юриспруденция',
#  'я сейчас буду в вузе',
#  'это департамент там есть',
#  'смогу зайти',
#  'почему',
#  'аналогично все заполнили и в самом конце подать заявление не нажимается',
#  'теперь пойдем лично подавать',
#  'на сайте рудн в пакете документов для заселения в общежитие в строке где указаны сертификат о вакцинации от ковид19 либо медотвод указано также либо иной документ что имеется в виду в словах либо иной документ',
#  'до какого числа можно подать',
#  'и ответьте пожалуйста на мой вопрос выше',
#  'подскажите реквизиты приказа кем принят и если он принят рудн то ссылку на него пришлите пожалуйста',
#  'больше спасибо за ответ',
#  'а ктонибудь подавал через госуслуги нет сложностей я жду результаты по английскому и пока не знаю через что мне будет удобнее подать документы через сайт или госуслуги',
#  'я подавала через госуслуги',
#  'подать удобно но меня например до сих пор нет в конкурсных списках',
#  'мои результаты не прогрузились и написано 0 0 0',
#  'в приемке порекомендовали непосредственно через сайт вуза',
#  'но в гс все и сразу все 5 вузов все направления отмечаешь',
#  'както более универсально',
#  'и у нас такжемы звонили нам сказаличто мы в конкурсе участвуемесли честно до конца не понятно',
#  'здравствуйте сейчас сайт не работает не удается подать документы и не прикрепляется портфолио кстати возможно ли редактировать заявку после отправки и дополнить портфолио',
#  'добрый день скажите пожалуйста на платной основе на лечебное дело существует конкурс или зачисляют всех по принципу кто раньше дал согласие у нас просто еще не известны баллы егэ сдавали в резервные дни не можем пока подать документы а вдруг все места уже будут заняты или если у нас баллы будут выше то мы пройдем',
#  'под иной документ может подойти справка о наличии антител к ковид19',
#  'на сайте под вторым разворотом аттестата имеется ввиду это или просто обе страницы с лицевой стороны',
#  'мы в конце июня подали и до сих пор в списках с нулями',
#  'а где всё это прописано в каком документе так и не могу от вас добиться ответа',
#  'добрый день интересует вопрос есть ли возможность поступить на очнозаочную форму обучения параллельно работая с графиком 52 либо без вариантов придётся подавать на заочную',
#  '204 каб',
#  'здравствуйте у меня диплом спо подали документы через личный кабинет 1 как узнать приняты документы или нет 2 как узнать записан абитуриент на сдачу экзаменов в рудн в личном кабинете не найду информацию',
#  'здравствуйте почему не загружается фото паспорта',
#  'где только найти организации которые согласны на целевое обучение мы по психологии не нашли',
#  'дайте пожалуйста контакты филологического факультета',
#  'спасибо',
#  'а иностранные граждане могут на это претендовать',
#  'искали не нашли наверно раньше нужно было искать но к сожалению недавно только узнала о таком',
#  'здравствуйте я 23 июня подала документы лично в университете в медицинский университет на 2 факультета форма обучения контракт мне дали расписку но меня нет в списках подступающих проверяю каждый день но ничего не изменяется подскажите пожалуйста с чем это связано',
#  '133759078 78',
#  'лечебное дело и стоматология',
#  'хорошо спасибо вам большое успокоили',
#  'добрый день подскажите пожалуйста как можно записаться на вступительные испытания от университета не могу найти на сайте может быть нужно кудато позвонить и записаться',
#  'вот я и не могу найти такой вкладки есть только вкладка с результатами егэ',
#  'а я смогу подавать документы на платное обучение если не смогу на бюджет поступить',
#  'т е если баллы больше минимальных то контракт гарантирован или всётаки на платное есть конкурс',
#  '160687404 76 проверьте пожалуйста есть ли я в списках просто почемуто не могу найти себя хотя заявку подал',
#  'здравствуйте сутки пытаюсь подать заявление через лк все никак не отправляется начинаю волноваться',
#  'лечебное дело стоматология фармация очно бюджет',
#  'я нашёл себя но почемуто у меня не указан в списке снилс',
#  'и вместо егэ биологии указана профильная математика',
#  'и баллов дополнительных нет',
#  'что делать',
#  'добрый день можно уточнить на сколько далеко находятся общежития от вуза',
#  'и есть какоето распределение кто в какое общежитие',
#  'добрый вечер а когда свяжутся с вуза если документы отправлены через личный кабинет хотелось бы узнать все ли правильно и когда экзамены',
#  nan,
#  'такой вопрос кто в курсе как проходит защита творческого задания в аспирантуру на юрфак в устной форме и в каких числах она будет',
#  nan,
#  'здравствуйте подача документов на очное отделение магистратуры до 20 или 2207 везде разная информация',
#  'а может вместо родителей быть старшая родная сестра',
#  'когда предположительно будут вывешены финальные списки сколько времени у меня будет на принятие решения я далеко живу и ехать мне не один день и могу ли удалённо отравить аттестат',
#  'добрый день по пункту 2 до сих пор не устранена ошибка отсутствия возможности выбор диплома бакалавра с отличием в качестве инд достижения мой адрес электронной почты kalinova99[LINK]',
#  'здравствуйте какие заявление нужно распечатывать и подписывать для поступление',
#  'здравствуйте где найти заявление чтобы их распечатать подписать и подать вместе с документами',
#  'здравствуйте статус к зачислению означает что я уже могу подписать согласие и стать студентом',
#  'мне никто не отвечает по электронной почте я писала несколько раз',
#  'с субботы я не могу подать заявление в личном кабинете',
#  'хорошо спасибо',
#  'юриспруденция',
#  'добрый день скажите пожалуйста почему ваш вуз не добавляется на сайт гу при подаче заявления',
#  'все вузы работают ваш именно не добавляется',
#  'спасибо попробуем ещё но просто с одним этим вузом такая неполадка',
#  'спасибо',
# ...
#  'имэб реклама и связи с общественностью',
#  'да',
#  'большое спасибо',
#  'а сколько часов выделяется на каждый предмет доступ открывается в 9 утра до 21 целый день могу сидеть или как',
#  'да но на каждый предмет сколько времени выделяется или это не важно',
#  'математика литература и история',
#  'спасибо',
#  'есть ли какието скидки за хорошее обучение при поступлении на контракт',
#  'первый сдан',
#  'надеюсь',
#  'журфак',
#  'юрфак',
#  'здравствуйте это происходит вне зависимости от браузера провайдера включенногоотключенного антивируса или кукифайлов',
#  'швырков владислав сергеевич [LINK][LINK]',
#  'здравствуйте у меня аналогичная проблема корольков кирилл андреевич kirill14032000[LINK] сменой браузера очисткой кукифайлов включениемотключением антивируса проблема не решается сменой устройства тоже',
#  'выглядит вот так',
#  'здравствуйте ссылка так и не пришла можно номер тел медицинского',
#  'надеюсь что все будет хорошо',
#  'здравствуйте где увидеть что оплата за обучение прошла',
#  'вчера была оплатасо счета списались деньгино никакого сообщения на почту не пришло в течение какого времени оно должно придти',
#  'спасибо',
#  'здравствуйте а если я захочу перевести то сколько будет стоить перевод в рудн и из рудн',
#  'журналисты простите а никто не знает когда появится второй тест первый я решила и в на почте была информация только про один',
#  'спасибо большое',
#  'то есть 15 числа не будет его или вы про сегодня',
#  'здравствуйте оплатили обучение по контракту 2 июля а письма на почту о том что оплата прошла нет при подаче документов была допущена ошибка в названии моей почты но потом я ещё раз приезжала чтобы исправить может быть заявление о внесении изменений в почту не дошло до личного дела',
#  'если я сейчас поступлю у себя в городе а через год захочу перевестись в рудн сколько это примерно по стоимости будет или если я поступлю в рудн и захочу перевестись обратно к себе в город',
#  'добрый день что делать если перейдя по ссылке мне не дают возможности авторизироваться и просто написано время вашего экзамена ещё не наступило или у вас нет назначенных экзаменов',
#  'здравствуйте прохожу процедуру проверки настройка компьютера в экзамус и уже почти час не меняется изображение подскажите пожалуйста в чем может быть дело освещённость чёткость фон всё есть но никак',
#  'журналистика и телевидение',
#  'уже вроде бы разобралась в чем была проблема спасибо',
#  'фио иванникова дарья дмитриевна снилс 172919611 94 телефоны 7985 2431042 7499 3568391 почта [LINK]2002[LINK]',
#  'здравствуйте когда будут результаты теста известны',
#  'где их можно будет посмотреть',
#  'заработало спасибо',
#  'спасибо вам огромное',
#  'здравствуйте можно сегодня же приехать в вуз позадавать вопросы посмотреть кампус и тд',
#  'добрый день можно адрес приемной комиссии',
#  'спасибо большое',
#  'здравствуйте мы тоже оплатили 1 июля сообщение на почту не пришло позвонили в коммерческий отдел там подтвердили что оплата прошла и сказали ждать приказ',
#  'спасибо уже позвонили туда сказали то же самое ждём',
#  'подскажите пожалуйста могу ли я подать заявление в аспирантуру на бюджет и сразу на контракт по одному направлению или я могу в случае если не пройду по конкурсу подать документы позже я просто не понимаю как подать на контракт через систему электронных документов на контракт 2 заявление',
#  'спасибо большое сейчас всё хорошо',
#  'здравствуйте закончила колледж успеваю подать документы на экономический факультет очнозаочную форму какие вступительные нужны и когда они будут сколько стоит обучение на экономическом факультете очнозаочно благодарю за вашу работу',
#  'экономический факультет очнозаочная форма',
#  'экономика',
#  'а я по спо успеваю подать документы',
#  'после колледжа',
#  'это значит никакие экзамены не нужно сдавать да и спасибо что ответили',
#  'здравствуйте у меня проблема с заявлениями вчера мне позвонили из приемной комиссии и сказали что на две специальности из трёх на которые я подала я не подхожу потому что не сдавала подходящие егэ сказали чтобы я переделала заявления и загрузила их но заявления не обновляются как было 3 специальности так 3 специальности и осталось',
#  'спасибо большое',
#  'извините я сейчас написала дви по журналистике но мне кажется что мои ответы не отправились можно ли както проверить дошла ли моя работа',
#  'а в каком разделе',
#  'а как',
#  'проверьте пожалуйста тожесафронов тимур александровичtimursafronov[LINK] снилс 168185 594 14',
#  'gusevanastasi[LINK] гусева анастасия александровна 152823606 56',
#  'добрый день подскажите пожалуйста как будет происходить зачисление если подали заявление на очно бюджет несколько направлений строительство нефтегазовое дело эксплуатация технических машин и комплексов по приоритетности те автоматически заявление и согласие переходит на то направление куда проходишь по баллам егэ или только на то направление куда именно подано согласие',
#  'и еще такая проблема консультант приемной комиссии мне сказала что я есть в базе однако меня нет на сайте в списках подавших документы',
#  'подскажите вечернее обучение это очнозаочная форма',
#  'здравствуйте обращалась в приёмную комиссию два раза не приходит ссылкаприглашение на два вступительных экзамена история литература которые будут проходить завтра что необходимо сделать в данном случае',
#  '176859918 51 [LINK]2002[LINK] алексеева софья михайловна 89774242606 84986491049',
#  'спасибо',
#  'пришли ответы да',
#  'спасибо вам большое очень успокаиваете а насчет этого не подскажете',
#  'если вам пришла ссылка на экзамензначит вы в списках',
#  'а мне не подскажете',
#  'а я на сайте по снилсу смотрю там нет',
#  'ребят есть кто на эконом факультет зарубежное регилноведение ибероамерика',
#  'спасибо вам большое за ответ ещё вопрос а можно будет переписать согласие на другое направление и до какого числа',
#  'здравствуйте есть у вас факультет для иностранцев лингвистика русский язык',
#  'в магистратуре',
#  'а до какого числа можно переписать согласие',
#  'нужно ли повторно с утра обращаться в приёмную комиссию',
#  'спасибо за ответ а оригиналы документов на бюджет необходимо предоставить до 0308',
#  'это сроки кто поступает по бви',
#  'добрый день подскажите как подать согласие на заявление',
#  'здравствуйте с двух компьютеров заходила сто раз все перезагружала но все равно экзамус выдает эту ошибку один раз получилось зайти но потом сразу же выдал ошибку и выкинул назад',
#  'на вечерний учеников тоже даёте общежитие',
#  'хорошо а мне это нужно сделать сейчас или я могу после 28',
#  '179903854 30 воронина арина сергеевна 79262593346 7939645576 [LINK][LINK]',
#  'понял спасибо',
#  'добрый вечер как посмотреть списки подавших документы в медицинский институтлечебное делообщий конкурс',
#  'международные отношения лингвистика',
#  'спасибо все пришло',
#  'здравствуйте до какого числа ведется прием документов для поступления в магистратуру',
#  'здравствуйтекак проходит очнозаочное обучение на лингвистике мы живём в спб занятия онлайн',
#  'здравствуйте я подавала документы на контракт и на общий конкурс хочу узнать почему меня нет в списках на общий конкурс а на контракт есть заранее спасибо',
#  'спасибо',
#  'здравствуйте зашла сдавать экзамен нажала начать тестирование и уже 40 минут висит надпись ожидание прокторинга на горячую линию дозвониться не могу трубку не берут и как быть в таком случае',
#  'до скольки',
#  'спасибо за разъяснения',
#  'спасибо',
#  'если поступитбыстренько приедет и сделает переводвозможен ли допуск к дистанционному тест пока без перевода',
#  nan,
#  'здравствуйтеа можете ли проверить пришли ли мои ответы по экзамену математика курченкова',
#  'здравствуйтеа по каждому предметубудет свое письмо и ссылка',
#  'курченкова ольга александровна kurxenkova[LINK] 163209156 44',
#  'пришлопросто переживаювсе ли дошло',
#  'можно ли использовать чистые листы во время прохождения теста по математике',
#  'у меня странная просьба ни у кого нет фоток холла в кресте',
#  'хочу ремонт показать',
#  'а онлайн обучение есть',
#  'спасибо',
#  'здравствуйте я получила целевой договор на направление экология и природопользование по программе управление природными ресурсами на сайте пк видела 3 целевых места по этому направлению других заявлений там пока нет целевые места же есть я все правильно поняла подаю заявления через госуслуги почемуто не выходит целевой конкурс при поиске запуталась немного заранее спасибо за ответ',
#  'добрый день подскажите когда вступительные испытания на факультет журналистики и философии',
#  nan,
#  'ещё вопрос про целевое в лк нужно указать номер договора что делать если номера в договоре с министерством нет',
#  'на почту',
#  'отправила первую страницу где по идее должен быть номер но его нет',
#  'хорошо спасибо',
#  'а до скольки будет программа примерно',
#  'так должно быть или только наименование заказчика сохранилось',
#  'здравствуйте а на журналистику на платную основу можно подать документы до 19 августа',
#  'когда будут экзамены потом',
#  'благодарю за ответ',
#  'подскажите сегодня экзамен по базовой или профильной математике',
#  'здравствуйте',
#  'скажите пожалуйста как часто проходит у вас день открытых дверей',
#  'добрый вечер скажите пожалуйста где найти результаты дви по журналистике за первый тур',
#  'здравствуйте а получая диплом переводчика сколько языков можно изучать',
#  'когда будут известны результаты экзамена если я сдала его сегодня',
#  'а мне ответить нельзя как нибудь',
#  'а если не получается в эти дни то что делать',
#  'подскажите пожалуйста очень хочу поступить но вот обстоятельства такие',
#  'да',
#  'да',
#  'а во сколько завтра экзамен',
#  'а сколько он длится будет',
#  'ой так быстро а что в него входит и куда надо подключаться',
#  'можно узнать поподробнее',
#  'то есть ровно в 9 я могу подключиться и начать писать тогда в 10 закончу а могу больше писать или ровно час',
#  'а камеры не будет',
#  'ну я имела в виду надо ли включать вебкамеру на ноутбуке',
#  'писала дви и там надо было',
#  'могу ли я поступить в магистратуру на физику имея диплом международных отношений',
#  'надо сдавать вступительные или как где можно найти программу обучения',
#  'мне на почту пришла ссылка на ещё один тест тот который был 13творческий а вот 15 будет профессиональное испытание так и нужно',
#  'да если ты поступаешь на телевидение илии журфак',
#  'здравствуйте напишите пожалуйста контакт тех поддержки для вступительного по журналистике',
#  'пишем доп испытание не пройти проверку системы хотя первое испытание все отлично',
#  'подскажите как зайти чтобы вступительные сдать',
#  'мне на почту ничего не пришло',
#  'социология',
#  'благодарю решили вопрос',
#  'добрый день подскажите пожалуйста а для бюджетной ординатуры тоже есть крайние сроки',
#  'уже 1228 а мне до сих пор не приходило письмо на эл почту по поводу экзамена',
#  'здравствуйте оплатила обучение ещё неделю назад если не больше а приказ о зачислении так и не пришёл что делать в такой ситуации и куда обращаться заранее спасибо',
#  'проверяла и не один раз первое и последнее письмо от рудн сегодня в 0005 про день абитуриента рудн',
#  'здравствуйте это относится и к иностранным абитуриентам сдающим вступительные экзамены',
#  'английский',
#  'добрый день если договор подписан и оплата поступила к вам это означает стопроцентное поступление никаких изменений не может возникнуть с вашей стороны',
#  'а можно эту информацию както в личных сообщениях предоставить не хочется сюда всё это писать',
#  'здравствуйте я гражданин узбекистана и я получил квоту рф по направлению лечебное дело принимаете ли вы абитуриентов по этому направлению',
#  'здравствуйте я гражданин узбекистана и я получил квоту рф по направлению лечебное дело принимаете ли вы абитуриентов по этому направлению',
#  'здравствуйте а можете пожалуйста прислать план проведения мероприятия',
#  'подскажите пожалуйста сколько мест на журналистку контракт сочи',
#  'здравствуйтеа когда будет известно поступил ты или нет если последний экзамен 19 результаты будут тогда когда',
#  'здравствуйте как можно уточнить поступили ли деньги на счёт вуза поступил ли я',
#  'здравствуйте можно ли у вас получить скан приложения к диплому для подачи документов онлайн',
#  'я не смогла забрать оригинал выписки из диплома с оценками чтобы подать заявление онлайн мне нужно приложить скан этой выписки говорили что можно написать вам и запросить этот скан',
#  'здравствуйте подскажите пожалуйста если конкурс многопрофильный по зарубежному регионоведениючеловек сам выбирает страну изучения или куда попадёт по баллам я интересуюсь именно платным обучением',
#  'спасибо',
#  'можно узнать сколько бюджетных мест на очку журналистики и телевидения',
#  'лучшая компания супердискотеки',
#  'азизаа',
#  'когда будут результаты о зачислении на специалитет',
#  'азиза',
#  'добрый вечер отсутсвует на почте ссылка на внутренний экзамен который будет проводиться завтра в спаме и рассылках тоже ничего нет заранее благодарю за помощь 176859918 51 [LINK]2002[LINK] алексеева софья михайловна 89774242606 84986491049',
#  'здравствуйте подскажите пожалуйста если я после колледжа ещё не поздно подать заявление на поступление и сдавать вступительные очно заочное политология',
#  'а когда вступительный экзамен можно сдать',
#  'на контракт я',
#  'хорошо спасибо а вы завтра работаете можно приехать и подать заявление',
#  'ул миклухомаклая 6',
#  'по этому адресу',
#  'здравствуйте звонила на горячую линию проверила все папки логин и пароль так и не прислали экзамен завтра',
#  'что делать',
#  '145214272 30 abdulmalikkhadizov[LINK] хадизов абдулмалик муслимович 89280175212 89899162234',
#  'анастасия',
#  'здравствуйтеможете пожалуйста скинуть расписание вступительных экз магистратуры на лингвистику',
#  'на факультет филологии тож есть бюджет',
#  'лингвистика',
#  'русс английский',
#  'и ещё мне интересует факультет строительство направление строительство зданий и сооружений есть такое направление',
#  'мне сказали что иностранных студентов только учиться в контракте',
#  'сертификат тоже нужен что ли в поступать в рудн на очно заочно',
#  'иностранные студенты тоже относится к бюджету tarjima ruuz chet ellik talabalar ham byudjetga kiritilgan',
#  'регистрация нужна на день открытых дверей',
#  'здравствуйте сколько бюджетных конкурсных мест на очное журналистка и филология филиал сочи',
#  'а когда будут результаты',
#  'я из узбекистана',
#  'в любое время сегодня можно заглянуть туда',
#  'я только собиралась ехать',
#  'всем привет вчера я отправил согласие на зачисление в сочинский институт через личный кабинет оно отобразилось как принятое в списке поступающих но сегодня пропало оттуда в чем может быть причина',
#  'жаль что не смогла приехать и повеселиться',
#  'подскажите пожалуйста по направлению фармация в 2021 году какие были вступительные испытания егэ при поступлении на бюджет бакалавриата по общему конкурсу такие же как и в этом году',
#  'можно ли получить список поступивших в 2021 году на бюджет по направлению фармация бакалавриата с количеством баллов поступивших в личные сообщения этого телеграмканала либо по почте [LINK][LINK] буду очень благодарен',
#  'здравствуйте подскажите пожалуйста 26 августана выборе языка изучения обязательно присутствовать в институте или это можно сделать онлайн',
#  'здравствуйте для очнозаочной формы обучения журфактелевидение будут другие отличные от очников дви',
#  'здравствуйте а есть ли крайние сроки для подачи документов на коммерцию стоматология',
#  'здраствуйте а можете сказать крайний срок подачи докум для инностранцев на стомфак',
#  '[LINK]',
#  'здравствуйте у меня тоже вопрос платят ли стипендию контрактникам если нет то платят ли её тем кто на скидке 50',
#  'а можно сдать экзамен не в 9 00 а в другой час',
#  'привет платят только бюджетникам',
#  'даже если учишься на отлично на платке',
#  'да',
#  'так везде',
#  'доброго времени суток если подать документы на бюджетную форму обучения магистратура в случае недобора баллов можно будет потом выбрать обучение на договорной основе',
#  'привет так подавай сразу на оба варианта заяления просто не будешь заключать договорную основу если пройдешь на бюджет',
#  'здравствуйте во сколько будут результаты творческих экзаменов на направление архитектура',
#  'здравствуйте почему у вас за скопус в приказе 3 балла дают а у всех 20б',
#  ...]

# %%
len(texts)
# Out:
# 57711

# %%
df_test['text_preprocessed'] = texts

# %%
df_test.head()
# Out:
#                                                 text  label  emojis  newlines  \
# 0  Здравствуйте, подскажите, пожалуйста, программ...      0       0         3
# 1  Получается, все тоже самое, но теперь диплом т...      0       0         0
# 2  Извините, а где можно узнать Актуальные маг пр...      0       0         0
# 3  Добрый вечер, подскажите пожалуйста, есть ли з...      0       0         0
# 4          Здравствуйте! Только очная форма обучения      0       0         0
#
#    whitespaces  links  tags                                  text_preprocessed
# 0            2      1     0  здравствуйте подскажите пожалуйста программу м...
# 1            0      0     0  получается все тоже самое но теперь диплом тол...
# 2            0      0     0  извините а где можно узнать актуальные маг про...
# 3            0      0     0  добрый вечер подскажите пожалуйста есть ли зао...
# 4            0      0     0           здравствуйте только очная форма обучения

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57711 entries, 0 to 32436
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               57711 non-null  object
#  1   label              57711 non-null  int64
#  2   emojis             57711 non-null  int64
#  3   newlines           57711 non-null  int64
#  4   whitespaces        57711 non-null  int64
#  5   links              57711 non-null  int64
#  6   tags               57711 non-null  int64
#  7   text_preprocessed  57252 non-null  object
# dtypes: int64(6), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# ### Удаление лишних строк

# %%
sum(df_test.isnull().sum(axis = 1))
# Out:
# 459

# %%
df_test.dropna(subset=['text_preprocessed'], inplace=True)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57252 entries, 0 to 32436
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               57252 non-null  object
#  1   label              57252 non-null  int64
#  2   emojis             57252 non-null  int64
#  3   newlines           57252 non-null  int64
#  4   whitespaces        57252 non-null  int64
#  5   links              57252 non-null  int64
#  6   tags               57252 non-null  int64
#  7   text_preprocessed  57252 non-null  object
# dtypes: int64(6), object(2)
# memory usage: 3.9+ MB

# %%
df_test.head()
# Out:
#                                                 text  label  emojis  newlines  \
# 0  Здравствуйте, подскажите, пожалуйста, программ...      0       0         3
# 1  Получается, все тоже самое, но теперь диплом т...      0       0         0
# 2  Извините, а где можно узнать Актуальные маг пр...      0       0         0
# 3  Добрый вечер, подскажите пожалуйста, есть ли з...      0       0         0
# 4          Здравствуйте! Только очная форма обучения      0       0         0
#
#    whitespaces  links  tags                                  text_preprocessed
# 0            2      1     0  здравствуйте подскажите пожалуйста программу м...
# 1            0      0     0  получается все тоже самое но теперь диплом тол...
# 2            0      0     0  извините а где можно узнать актуальные маг про...
# 3            0      0     0  добрый вечер подскажите пожалуйста есть ли зао...
# 4            0      0     0           здравствуйте только очная форма обучения

# %%
count_zero = df_test[df_test['label'] == 0].shape[0]

# %%
count_zero
# Out:
# 24830

# %%
count_one = df_test[df_test['label'] == 1].shape[0]

# %%
count_one
# Out:
# 32422

# %% [markdown]
# Итого мы получили 1978 строк, из которых:
# - 979 чистых сообщений
# - 999 сообщений, помеченных как спам

# %% [markdown]
# ## Загрузка моделей

# %%
models_path = "../models"  # Путь к папке с моделями

# %% [markdown]
# Загрузка scaler и vectorizer

# %%
with open(os.path.join(models_path, "scaler.pkl"), "rb") as scaler_file:
    scaler = pickle.load(scaler_file)

with open(os.path.join(models_path, "vectorizer.pkl"), "rb") as vectorizer_file:
    vectorizer = pickle.load(vectorizer_file)

# %% [markdown]
# Загрузка классических моделей

# %%
classic_models = {}
for file in os.listdir(models_path):
    if file.endswith(".pkl") and file not in ["scaler.pkl", "vectorizer.pkl"]:
        with open(os.path.join(models_path, file), "rb") as model_file:
            classic_models[file] = pickle.load(model_file)

# %% [markdown]
# Загрузка моделей rubert

# %%
rubert_models = {
    "rubert_tiny2": {
        "path": os.path.join(models_path, "finetuned_rubert_tiny2"),
    },
    "rubert_tiny2_p": {
        "path": os.path.join(models_path, "finetuned_rubert_tiny2_p"),
    },
}
for name, model_info in rubert_models.items():
    model_info["classifier"] = pipeline("text-classification", model=model_info["path"], truncation=True)
# Out:
# Device set to use cuda:0
# Device set to use cuda:0

# %% [markdown]
# ## Предсказание значений

# %% [markdown]
# ### Функции для предсказания значений

# %% [markdown]
# Функция предсказания для классических моделей

# %%
def predict_message(text: str, vectorizer, scaler, model) -> tuple[int, list[float]]:
    """
    Предсказывает метку и вероятности для текста с использованием модели машинного обучения.

    Параметры:
        text (str): - входной текст для анализа
        vectorizer: - векторизатор для преобразования текста
        scaler: - масштабатор числовых признаков
        model: - модель машинного обучения

    Возвращает:
        tuple[int, list[float]] - метка предсказания и вероятности
    """
    # Предварительная обработка текста
    text_preprocessed = preprocess_text(text)

    # Векторизация текста
    text_vector = vectorizer.transform([text_preprocessed])

    # Создание числовых признаков
    numerical_features = pd.DataFrame(
        [[count_emojis(text), count_newlines(text), count_whitespaces(text), count_links(text), count_tags(text)]],
        columns=['emojis', 'newlines', 'whitespaces', 'links', 'tags']
    )
    # Масштабирование числовых признаков
    numerical_features_scaled = scaler.transform(numerical_features)

    # Объединение текстовых и числовых признаков
    features = hstack([text_vector, numerical_features_scaled])

    # Предсказание
    prediction = model.predict(features)
    probabilities = model.predict_proba(features)
    return int(prediction[0]), *probabilities.tolist()

# %% [markdown]
# Функция предсказания для моделей rubert

# %%
def bert_predict_batch(messages: list[str], classifier, threshold: float = 0.5) -> list[tuple[int, list[float]]]:
    """
    Функция для батчевого предсказания с помощью модели BERT через pipeline classifier.

    Параметры:
        messages (list[str]): – список сообщений для анализа
        classifier (pipeline): – pipeline классификатор
        threshold (float): – пороговое значение для предсказания класса

    Возвращает:
        list[tuple[int, list[float]]] - список предсказаний (0 или 1) и вероятностей
    """
    results = classifier(messages, batch_size=8)
    predictions = []
    for result in results:
        prediction = int(result['label'][-1])  # Извлечение метки предсказания
        score = result['score']  # Вероятность предсказания
        probabilities = [1 - score, score] if prediction == 1 else [score, 1 - score]

        if probabilities[1] < threshold:
            prediction = 0

        predictions.append((prediction, probabilities))

    return predictions

# %% [markdown]
# ### Сбор предсказаний

# %%
# Подготовка данных для BERT моделей
dataset = Dataset.from_pandas(df_test)

for name, model_info in rubert_models.items():
    rubert_results = bert_predict_batch(list(dataset["text"]), model_info["classifier"], threshold=0.945)
    df_test[name] = [pred[0] for pred in rubert_results]

# %% [raw]
# for index, row in df_test.iterrows():
#     text = row["text"]
#     # Предсказания классических моделей
#     classic_preds = {
#         name: predict_message(text, vectorizer, scaler, model)[0] for name, model in classic_models.items()
#     }
#     for model_name, pred in classic_preds.items():
#         df_test.loc[index, model_name] = pred

# %%
df_test.head()
# Out:
#                                                 text  label  emojis  newlines  \
# 0  Здравствуйте, подскажите, пожалуйста, программ...      0       0         3
# 1  Получается, все тоже самое, но теперь диплом т...      0       0         0
# 2  Извините, а где можно узнать Актуальные маг пр...      0       0         0
# 3  Добрый вечер, подскажите пожалуйста, есть ли з...      0       0         0
# 4          Здравствуйте! Только очная форма обучения      0       0         0
#
#    whitespaces  links  tags  \
# 0            2      1     0
# 1            0      0     0
# 2            0      0     0
# 3            0      0     0
# 4            0      0     0
#
#                                    text_preprocessed  rubert_tiny2  \
# 0  здравствуйте подскажите пожалуйста программу м...             0
# 1  получается все тоже самое но теперь диплом тол...             0
# 2  извините а где можно узнать актуальные маг про...             0
# 3  добрый вечер подскажите пожалуйста есть ли зао...             0
# 4           здравствуйте только очная форма обучения             0
#
#    rubert_tiny2_p
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %% [markdown]
# ### Сравнение

# %%
for name, model_info in rubert_models.items():
    print(name, '\n')
    print('Classification report:\n', classification_report(df_test['label'], df_test[name]))
    print("Confusion Matrix:\n", confusion_matrix(df_test['label'], df_test[name]))
    print('\n\n')
# Out:
# rubert_tiny2
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     24830
#            1       1.00      0.97      0.98     32422
#
#     accuracy                           0.98     57252
#    macro avg       0.98      0.98      0.98     57252
# weighted avg       0.98      0.98      0.98     57252
#
# Confusion Matrix:
#  [[24684   146]
#  [  890 31532]]
#
#
#
# rubert_tiny2_p
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97     24830
#            1       0.96      0.99      0.98     32422
#
#     accuracy                           0.97     57252
#    macro avg       0.98      0.97      0.97     57252
# weighted avg       0.97      0.97      0.97     57252
#
# Confusion Matrix:
#  [[23551  1279]
#  [  208 32214]]

# %% [markdown]
# **🔍 1. Обзор общей точности**
#
# | Метрика        | rubert\_tiny2 | rubert\_tiny2\_p |
# | -------------- | ------------- | ---------------- |
# | Accuracy       | **0.98**      | 0.97             |
# | Macro F1-score | **0.98**      | 0.97             |
# | Weighted F1    | **0.98**      | 0.97             |
#
# → `rubert_tiny2` показывает **лучшую общую производительность**.
#
# ---
#
# **📊 2. Классы по отдельности**
#
# **Класс 0**:
#
# | Метрика   | rubert\_tiny2 | rubert\_tiny2\_p |
# | --------- | ------------- | ---------------- |
# | Precision | 0.97          | **0.99**         |
# | Recall    | **0.99**      | 0.95             |
# | F1-score  | **0.98**      | 0.97             |
#
# → `rubert_tiny2` лучше **находит** все объекты класса 0 (Recall 0.99), а `rubert_tiny2_p` больше **точен**, но упускает часть объектов.
#
# ---
#
# **Класс 1**:
#
# | Метрика   | rubert\_tiny2 | rubert\_tiny2\_p |
# | --------- | ------------- | ---------------- |
# | Precision | **1.00**      | 0.96             |
# | Recall    | 0.97          | **0.99**         |
# | F1-score  | **0.98**      | 0.97             |
#
# → `rubert_tiny2` вообще не делает ложных положительных для класса 1 (Precision = 1.00), но немного теряет в Recall (пропускает 3%).
#
# ---
#
# **🧮 Матрицы ошибок**
#
# **rubert\_tiny2**:
#
# ```
# [[24684   146]  → 133 false positive
#  [  890 31532]] → 970 false negative
# ```
#
# **rubert\_tiny2\_p**:
#
# ```
# [[23551  1279]  → **1308 false positive** ← значительно больше
#  [  208 32214]] → **402 false negative**
# ```
#
# → `rubert_tiny2_p` делает **намного больше ложных срабатываний** на класс 1 (принимает класс 0 за 1).
# → Но зато она **меньше пропускает** объектов класса 1 (Recall выше).
#
# ---
#
# **✅ Вывод:**
#
# | Критерий                      | Лучшая модель      |
# | ----------------------------- | ------------------ |
# | Общая точность                | `rubert_tiny2` ✅   |
# | Поиск класса 0 (Recall)       | `rubert_tiny2` ✅   |
# | Поиск класса 1 (Recall)       | `rubert_tiny2_p` ✅ |
# | Точность класса 1 (Precision) | `rubert_tiny2` ✅   |
# | Баланс (меньше FP + FN)       | `rubert_tiny2` ✅   |
#
# 🔹 **Если важнее избегать ложных срабатываний:** `rubert_tiny2`
# 🔹 **Если важнее не упустить ни одного объекта класса 1:** `rubert_tiny2_p` может быть предпочтительнее, но с оговорками

# %% [markdown]
# #### Строки с FN и FP для модели finetuned_rubert_tiny2

# %%
fn_rows = df_test[(df_test["label"] == 1) & (df_test["rubert_tiny2"] == 0)]
fp_rows = df_test[(df_test["label"] == 0) & (df_test["rubert_tiny2"] == 1)]

# %%
fn_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 890 entries, 1 to 32436
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               890 non-null    object
#  1   label              890 non-null    int64
#  2   emojis             890 non-null    int64
#  3   newlines           890 non-null    int64
#  4   whitespaces        890 non-null    int64
#  5   links              890 non-null    int64
#  6   tags               890 non-null    int64
#  7   text_preprocessed  890 non-null    object
#  8   rubert_tiny2       890 non-null    int64
#  9   rubert_tiny2_p     890 non-null    int64
# dtypes: int64(8), object(2)
# memory usage: 76.5+ KB

# %%
fn_rows.head(500)
# Out:
#                                 text  label  emojis  newlines  whitespaces  \
# 1                          دانیالللل      1       0         0            0
# 33                        معايا 2022      1       0         0            0
# 60                            هممونو      1       0         0            0
# 72                        B1 به بالا      1       0         0            0
# 78                          Saba بیا      1       0         0            0
# ...                              ...    ...     ...       ...          ...
# 12042                             𝒉𝒂      1       0         0            0
# 12045                          𝒉𝒆𝒍𝒍𝒐      1       0         0            0
# 12048                           𝒕𝒉𝒆𝒌      1       0         0            0
# 12049                             𝑯𝒊      1       0         0            0
# 12110  У меня тоже ссылка в профиле)      1       0         0            0
#
#        links  tags             text_preprocessed  rubert_tiny2  rubert_tiny2_p
# 1          0     0                     دانیالللل             0               1
# 33         0     0                    معايا 2022             0               1
# 60         0     0                        هممونو             0               1
# 72         0     0                    b1 به بالا             0               1
# 78         0     0                      saba بیا             0               1
# ...      ...   ...                           ...           ...             ...
# 12042      0     0                            𝒉𝒂             0               1
# 12045      0     0                         𝒉𝒆𝒍𝒍𝒐             0               1
# 12048      0     0                          𝒕𝒉𝒆𝒌             0               1
# 12049      0     0                            𝑯𝒊             0               1
# 12110      0     0  у меня тоже ссылка в профиле             0               0
#
# [500 rows x 10 columns]

# %%
fp_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146 entries, 596 to 25269
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               146 non-null    object
#  1   label              146 non-null    int64
#  2   emojis             146 non-null    int64
#  3   newlines           146 non-null    int64
#  4   whitespaces        146 non-null    int64
#  5   links              146 non-null    int64
#  6   tags               146 non-null    int64
#  7   text_preprocessed  146 non-null    object
#  8   rubert_tiny2       146 non-null    int64
#  9   rubert_tiny2_p     146 non-null    int64
# dtypes: int64(8), object(2)
# memory usage: 12.5+ KB

# %%
fp_rows.head()
# Out:
#                                                    text  label  emojis  \
# 596   Assalomu aleykum aka ,umumiy qancha summa keta...      0       0
# 653                              milana56orsk@gmail.com      0       0
# 802   Швырков Владислав Сергеевич shvyrkov.vs@gmail.com      0       0
# 1492  Гасымова Нурана Назимовна 89393662727, nunu.ga...      0       0
# 1929                        Хочется такую же,  взять!!@      0       0
#
#       newlines  whitespaces  links  tags  \
# 596          0            1      0     0
# 653          0            0      1     1
# 802          0            0      2     1
# 1492         0            0      2     1
# 1929         0            1      0     1
#
#                                       text_preprocessed  rubert_tiny2  \
# 596   assalomu aleykum aka umumiy qancha summa ketar...             1
# 653                                  milana56orsk[LINK]             1
# 802            швырков владислав сергеевич [LINK][LINK]             1
# 1492  гасымова нурана назимовна 89393662727 [LINK]19...             1
# 1929                             хочется такую же взять             1
#
#       rubert_tiny2_p
# 596                1
# 653                1
# 802                0
# 1492               0
# 1929               1

# %%
fp_rows[['text', 'label']].to_dict('records')
# Out:
# [{'text': 'Assalomu aleykum aka ,umumiy qancha summa ketarkan  tooshirishga rudnga',
#   'label': 0},
#  {'text': 'milana56orsk@gmail.com', 'label': 0},
#  {'text': 'Швырков Владислав Сергеевич shvyrkov.vs@gmail.com', 'label': 0},
#  {'text': 'Гасымова Нурана Назимовна 89393662727, nunu.gasimova1999@gmail.com',
#   'label': 0},
#  {'text': 'Хочется такую же,  взять!!@', 'label': 0},
#  {'text': 'РУДН жди меня 😂', 'label': 0},
#  {'text': 'Написать на почту: mfc@rudn.ru', 'label': 0},
#  {'text': 'mfc@rudn.ru', 'label': 0},
#  {'text': 'Здравствуйте,я взял кредит и мне его одобрили, когда у меня спишется оплата за 1 год?',
#   'label': 0},
#  {'text': 'Кто может помочь подать это все за деньги ?', 'label': 0},
#  {'text': 'Находиться на сайте РУДН - одно сплошное удовольствие', 'label': 0},
#  {'text': 'https://vk.com/abi_pfur_mi_2022', 'label': 0},
#  {'text': 'Беседа мехмата в ТГ: https://t.me/+wrA-Fcx_PYA0YTYy', 'label': 0},
#  {'text': 'Где общаться со "своими"?\n💬 https://vk.cc/cfwcpn', 'label': 0},
#  {'text': 'Hello can you please reply me', 'label': 0},
#  {'text': 'Усенгалиев Бибарыс Асангали улы\nusengaliev.bibars@mail.ru',
#   'label': 0},
#  {'text': 'Всем привет, если есть желающие учиться в Рудне, смело пишите мне, поможем без проблем поступить.',
#   'label': 0},
#  {'text': 'ХОЧУ УЗНАТЬ КАК УЧАТСЯ СТУДЕНТЫ НА ОЧНОМ НА ПЛАТНОМ !', 'label': 0},
#  {'text': 'ПРОСТО ЕСТЬ ДОСТОЙНЫЕ ЛЮДИ, КОТОРЫЕ ЗАСЛУЖИВАЮТ УЧИТЬСЯ В ПРЕСТИЖНЫХ УНИВЕРАХ',
#   'label': 0},
#  {'text': 'Добрый день! К кому можно обратиться, узнать некоторые подробности поступления на направление E-commerce?',
#   'label': 0},
#  {'text': 'https://unikum.rudn.ru/form-page', 'label': 0},
#  {'text': 'Копить деньги. 😂', 'label': 0},
#  {'text': 'Gracias por el tip, muy importante, en mi caso para el aprendizaje de idiomas.',
#   'label': 0},
#  {'text': 'Милашки😭😭😭😭\n\n#РУДН', 'label': 0},
#  {'text': 'https://dod.rudn.ru/, верьте в чудо😉✨️', 'label': 0},
#  {'text': 'Здравствуйте! Интересует обучения на факультете психологии на основе высшего образования. Условия поступления? Оплата? Сроки? Есть ли филиалы в регионах? Онлайн?',
#   'label': 0},
#  {'text': 'Salom. Lic yozvoring.', 'label': 0},
#  {'text': 'Медсправка при прогулах в универе. Писать в лс.', 'label': 0},
#  {'text': 'На РУДН сейчас учишься можно с тобой поговорить на лч кк',
#   'label': 0},
#  {'text': 'imtihon bilan byutjedka o,giymam', 'label': 0},
#  {'text': 'ВАКАНСИЯ АССИСТЕНТ-ПЕРЕВОДЧИК\n\nТребования:\n\n- знание русского языка и хинди/тамильского\n- проживание в Индии (Дели / Мумбаи)\n- готовность к командировкам по Индии\n- есть опыт работы с финансами\n- есть опыт управления командой\n- есть опыт ведения переговоров\n- умеете обращаться с excel\n- являетесь опытным пользователем ПК\n- умеете расставлять приоритеты между задачами\n- пользуется task-менеджерами\n- умеете в тайм-менеджмент\n- ответственный\n- нацелены на результат\n\nЗадачи:\nНеобходимо присутствовать на встречах в качестве переводчика, вникнуть в суть процессов бизнеса.\nВзять на себя контроль движения финансовых средств, контроль ведения отчетности, контроль выполнения задач и напоминание о них (как команде, так и руководителю), контроль работы команды, планирование задач совместно с руководителем нацеленные на рост компании.\nКоммуникация с штатом юристов по возникающим вопросам.\nС позиции есть возможность вырасти до операционного директора.\n\nпо всем вопросам обращаться:\n@vedernikov\n@vedernikov\n@vedernikov\n@vedernikov\n@vedernikov\n@vedernikov',
#   'label': 0},
#  {'text': 'Привет. Со всеросом по ин язу можно в РУДН поступить БВИ?',
#   'label': 0},
#  {'text': 'Предоставьте подробную информацию о юриспруденции?', 'label': 0},
#  {'text': 'Ale-rogova@yandex.ru', 'label': 0},
#  {'text': 'Здравствуйте кто поможет мне \nУзнать как получить бюджетное место у вас в РУДНе ?! Я иностранец',
#   'label': 0},
#  {'text': 'Напишите мне в ЛС пожалуйста', 'label': 0},
#  {'text': 'usacheva-ia@rudn.ru', 'label': 0},
#  {'text': 'Стоимость интенсива-18.600р.\nПроживание-исключительно по Вашему желанию и необходимости)',
#   'label': 0},
#  {'text': 'Напишите в лс', 'label': 0},
#  {'text': 'Бу савол жавобини 87% одамлар топа олмас экан🤯 Топканга совға бор👇🏻\n\nДиққат савол: Расмда нечта қиз бор ❓\n\nЖавобни билиш👇👇👇',
#   'label': 0},
#  {'text': 'Хочу устроиться на первую работу, привести в порядок свой сон (уже в процессе), начать осознанно относится к потреблению интернет контента, поступить на бюджет, и наконец использовать заметки obsidian каждый вечер, а не раз в месяц',
#   'label': 0},
#  {'text': 'Напишите в лс)', 'label': 0},
#  {'text': 'Диққат қизиқарли савол!\n\nДиққат билан қаранг ва  қайси пиёла биринчи бўлиб чой билан тўлишини топинг!\n\nДўстларингизни хам синаб кўринг👇',
#   'label': 0},
#  {'text': '/start@Shazamkabot', 'label': 0},
#  {'text': '/start@Shazamkabot', 'label': 0},
#  {'text': 'Есть, пиши в лс', 'label': 0},
#  {'text': 'Напишите мне в личные сообщения, я вам ФИО скажу', 'label': 0},
#  {'text': '✨служба заботы✨', 'label': 0},
#  {'text': 'нет, support@examus.net эта', 'label': 0},
#  {'text': 'ТВОЮ МАТЬ, У МЕНЯ ДАЖЕ ПИСЬМО НЕ ОТПРАВЛЯЕТСЯ ИЗ-ЗА СБОЕВ \nПИШЕТ, ЧТО В ОЧЕРЕДИ',
#   'label': 0},
#  {'text': 'Пишите в личные сообщения я вам Gmail свой скину!', 'label': 0},
#  {'text': 'Юлдошев Давлатджон Шухратович\ndavlatpubg2210@gmail.com',
#   'label': 0},
#  {'text': 'https://t.me/+dVQCnRwntB0xNWQy', 'label': 0},
#  {'text': 'Chechnya is close to my heart!\nLove you Chechnya💐', 'label': 0},
#  {'text': 'Я сегодня приеду к вам💙🫶🏻', 'label': 0},
#  {'text': 'Пишешь в гугле , Проходные баллы РУДН " там выводит сайт под названием tabiturient там всё подробно!',
#   'label': 0},
#  {'text': '"Создать аккаунт в РУДН ID"?', 'label': 0},
#  {'text': 'السلام عليكم', 'label': 0},
#  {'text': 'Я не могу написать вам в личку, пожалуйста свяжитесь со мной',
#   'label': 0},
#  {'text': 'Добрый день! Можете, пожалуйста, написать в лс для уточнения информации🙏',
#   'label': 0},
#  {'text': 'uqishga topshirish jarayoni qanday bulopte', 'label': 0},
#  {'text': 'kontrak summasi qancha ekan', 'label': 0},
#  {'text': '370000, со скидкой 259000', 'label': 0},
#  {'text': 'С кем можно связаться по квартирам Qolife', 'label': 0},
#  {'text': 'Good morning, please can i still apply for preparatory course?',
#   'label': 0},
#  {'text': 'Присоединяйтесь к самой большой группе(семье) РУДН:\n\nhttps://t.me/RUDNCAMPUS',
#   'label': 0},
#  {'text': 'support@rudn.ru', 'label': 0},
#  {'text': 'Напишите в лс пожалуйста, хочу кое-что спросить', 'label': 0},
#  {'text': 'РУДН + ДВИЖЕНИЕ ПЕРВЫХ + БОЛЬШАЯ ПЕРЕМЕНА = 💜🤍', 'label': 0},
#  {'text': 'РУДН + ДВИЖЕНИЕ ПЕРВЫХ + БОЛЬШАЯ ПЕРЕМЕНА = 💜🤍', 'label': 0},
#  {'text': 'РУДН+ ДВИЖЕНИЕ ПЕРВЫХ +  БОЛЬШАЯ ПЕРЕМЕНА ❤️❤️❤️❤️❤️', 'label': 0},
#  {'text': 'РУДН +Движение Первых +Большая Перемена =🤍🤍🤍', 'label': 0},
#  {'text': 'МЕДИЦИНСКИЙ ИНСТИТУТ😎❣️', 'label': 0},
#  {'text': "Я люблю РУДН, это тРУДНое слово...\nНо тРУДНее всего мне его позабыть!\nЦелый мир обойду – не найду я другого,\nЧтобы память сумела его заменить.\nЯ люблю РУДН за напевность наречий,\nЗа мозаику лиц и его доброту.\nИ за то, что дела ценит выше, чем речи,\nВсех народов Земли воплощая мечту.\nЯ люблю РУДН! I love you RUDN!\nOui je t'aime RUDN! Yo te amo RUDN!\nЯ люблю РУДН! I love you RUDN!\nOui je t'aime RUDN! Yo te amo RUDN!\nЯ ЛЮБЛЮ РУДН!",
#   'label': 0},
#  {'text': 'РУДН❤️ АТИ🫶🏻', 'label': 0},
#  {'text': 'Рудн❤️хочу толстовку😘', 'label': 0},
#  {'text': 'Хочу толстовку РУДН ❤️', 'label': 0},
#  {'text': 'Хочу, хочу, 😅', 'label': 0},
#  {'text': "Я люблю РУДН! I love you RUDN!\nOui je t'aime RUDN! Yo te amo RUDN!\nЯ ЛЮБЛЮ РУДН!",
#   'label': 0},
#  {'text': 'РУДН Я ЛЮБЛЮ ТЕБЯ 💗', 'label': 0},
#  {'text': 'я люблю РУДН 🫶🏿', 'label': 0},
#  {'text': "Я люблю РУДН, I love you RUDN, Qui je t'aime RUDN, Yo te amo RUDN! ❤️❤️❤️",
#   'label': 0},
#  {'text': 'Хочу быть самым модным ночью в универе😍', 'label': 0},
#  {'text': 'Хочу быть самым модным ночью в универе😍', 'label': 0},
#  {'text': 'Настроение замечательное! РУДН - отличная возможность, чтобы найти единомышленников и обучиться профессии, в которую по-настоящему влюблен❤️\u200d🔥',
#   'label': 0},
#  {'text': 'Я люблю РУДН.\nРУДН это жызнь 🥺❤️', 'label': 0},
#  {'text': 'КТО ПОСТУПИТ В РУДН, БУДЕТ МНОГО-МНОГО ДЕЛ', 'label': 0},
#  {'text': 'РУДН - Водолей🌎\nRUDN - it’s Aquarius 🙂', 'label': 0},
#  {'text': 'Работа в Москве! В столовую на раздачу и кассу требуются сотрудники. С 10.00 до 19.00. 2500 смена, питание бесплатно. м. Озёрная.',
#   'label': 0},
#  {'text': 'Я знаю чего у вас нет, пишите - помогу организовать', 'label': 0},
#  {'text': 'единороги делают меня счастливым каждый день. ЕДИНОРОГИ, ВПЕРЕД!!!!',
#   'label': 0},
#  {'text': 'Добрый вечер, Тася! Эту встречу организую я с коллегами. Напишите мне, пожалуйста, в личные сообщения - подскажу подробности, как попасть к нам.\nВалерия Владимировна',
#   'label': 0},
#  {'text': '❤️ПГ- любовь)РУДН-любовь)', 'label': 0},
#  {'text': 'Сориентируйте пожалуйста,есть ли у вас направление ,,финансы и кредит,, и сколько стоит платное?',
#   'label': 0},
#  {'text': '汉语，只汉语✅', 'label': 0},
#  {'text': 'Нажимаю на подписать договор и переводит в уведомления',
#   'label': 0},
#  {'text': 'Здравствуйте! Можете написать мне в лч у меня очень много вопросов🙂',
#   'label': 0},
#  {'text': "Ziyodulloyev Ubaydulla Baxrom o'g'li", 'label': 0},
#  {'text': 'Popovamarina213@gmail.com', 'label': 0},
#  {'text': 'Спасибо🙏🏼\nПочта если что verevka.viktoria14@gmail.com',
#   'label': 0},
#  {'text': 'Именно оно. Напишите мне в ЛС, чтобы не захламлять комментарии',
#   'label': 0},
#  {'text': 'Нажал кнопку оплатить, высветился qr код', 'label': 0},
#  {'text': 'Оплата занимает несколько рабочих дней, не волнуйтесь!',
#   'label': 0},
#  {'text': 'Лингвистика, иняз, 281 с ид, без - 271', 'label': 0},
#  {'text': 'Кость контакты отдела юридической помощи РУДН?', 'label': 0},
#  {'text': 'Политологи аспиранты, ждущие зачисления— пишите мне в личку, добавлю вас в чат, там собираем людей',
#   'label': 0},
#  {'text': 'https://t.me/c/1630294075/41199', 'label': 0},
#  {'text': 'Здравствуйте, как с вами в лс связаться?', 'label': 0},
#  {'text': 'Прикрепляю ссылочки \n\nКорпоративная экономика и управление бизнесом (з.ф.о.) https://admission.rudn.ru/master/directions/programs/korporativnaya_ekonomika_i_upravlenie_biznesom_zaochnaya122035_123160/111958/\n\nSmart-бизнес (з.ф.о.) https://admission.rudn.ru/master/directions/programs/smart_biznes_zaochnaya102268_6213621/111958/',
#   'label': 0},
#  {'text': 'https://t.me/jobrudn/2600', 'label': 0},
#  {'text': 'https://t.me/jobrudn/2599', 'label': 0},
#  {'text': 'Здравствуйте, вступайте в группу Центр Карьеры РУДН и угадывайте чьё фото сегодня зашифровано! Репосты приветствуются 😉',
#   'label': 0},
#  {'text': "Я люблю РУДН, это тРУДНое слово...\nНо тРУДНее всего мне его позабыть!\nЦелый мир обойду – не найду я другого,\nЧтобы память сумела его заменить.\n\nЯ люблю РУДН за напевность наречий,\nЗа мозаику лиц и его доброту.\nИ за то, что дела ценит выше, чем речи,\nВсех народов Земли воплощая мечту.\n\nЯ люблю РУДН! I love you RUDN!\nOui je t'aime RUDN! Yo te amo RUDN!\n\nЯ люблю РУДН! I love you RUDN!\nOui je t'aime RUDN! Yo te amo RUDN!\nЯ ЛЮБЛЮ РУДН!",
#   'label': 0},
#  {'text': '📍ул. Миклухо-Маклая, 6🤩🌟\n_______________________\nСегодня я побывала на дне открытых дверей в Российском университете дружбы народов. Безумно сильно понравилась их подготовленность, я познакомилась  с  ребятами  из  разных  уголков мира  -  Индии, Китая, Мексики, Вьетнама, Африки, Южной Кореи, Парижа, которые с  гордостью  рассказали о  своей  культуре,  продемонстрировали традиционные  танцы  и  песни. \n\n#фото #газета #статья #эстетика #университет #РУДН',
#   'label': 0},
#  {'text': 'https://youtu.be/bdGOGqkN6Po?si=3n2beFqMTtiFtbzh', 'label': 0},
#  {'text': 'https://t.me/fsgn_active', 'label': 0},
#  {'text': 'Dear organizers! Can you say what are the points of 1,2,3 places at the Olympics?',
#   'label': 0},
#  {'text': 'Выиграл?)', 'label': 0},
#  {'text': 'Пицца "дружба народов"\nОбязательно халяль, мясо - шиштаук , разные виды сыров, обилие специй, на выбор обычное тесто/лаваш чтоб завернуть и есть как шаурму🥴',
#   'label': 0},
#  {'text': 'Свежий сочный грейпфрут в сочетании со сладостью ванили , пряностью пачули и фруктового аккорда манго . Название : Экзотический Fresh .',
#   'label': 0},
#  {'text': 'Пицца «РУДН: Дружба Народов»\n\nФирменный ингредиент:\nКускус – символ Африки и Ближнего Востока, который добавит пицце уникальную текстуру и вкус.\n\n«РУДН: Дружба Народов»\n\n Ингредиенты:\n- Тесто: традиционное итальянское тесто для пиццы\n- Соус: томатный соус с добавлением специй (базилик, орегано)\n- Сыр: моцарелла, чеддер, пармезан (символизирует разные страны)\n- Начинка:\n  - Кускус (Африка/Ближний Восток)\n  - Курица карри (Индия)\n  - Ананас (Бразилия/Таиланд)\n  - Шпинат (Европа)\n  - Оливки (Греция)\n  - Перец халапеньо (Мексика)\n  - Фета (Греция)\n\nПриготовление:\n1. Разогрейте духовку до 220°C.\n2. Раскатайте тесто и выложите его на противень.\n3. Смажьте основу томатным соусом.\n4. Равномерно распределите сыр моцарелла.\n5. Добавьте приготовленный кускус, кусочки курицы карри, ананас, шпинат, бекон, оливки и перец халапеньо.\n6. Посыпьте сверху тертым сыром чеддер и пармезаном.\n7. Выпекайте пиццу около 15 минут, пока корочка не станет золотистой, а сыр полностью не расплавится.\n8. После выпечки добавьте немного феты и украсьте свежей зеленью.\n\nЭта пицца объединяет вкусы разных стран, символизируя дружбу народов и международный характер РУДН. Удачи в конкурсе!',
#   'label': 0},
#  {'text': '"Дружба"\n\nкуриное филе, коктейльные креветки, битые огурцы, болгарский перец, сливки, моцарелла, соус соевый, соус Терияки, кунжутные семечки',
#   'label': 0},
#  {'text': 'Пицца «Дружба народов»\n\n Ингредиенты:\n- Основа:\n  - 1 готовая пицца основа (круглая)\n- Соус:\n  - 3 ст. л. томатного соуса\n  - 1 ст. л. соуса песто\n- Начинка:\n  - 100 г моцареллы\n  - 50 г сыра фета, нарезанного кубиками\n  - 1 небольшая красная луковица, нарезанная тонкими кольцами\n  - 1 сладкий перец, нарезанный кубиками\n  - 50 г шампиньонов, нарезанных ломтиками\n  - 50 г вареного кус-куса\n  - 10 маслин, нарезанных кольцами\n  - 1 маленький авокадо, нарезанный кубиками\n\nТоппинг:\n  - 1 ч. л. паприки\n  - 1 ч. л. орегано\n  - Щепотка чили хлопьев\n  - Свежий базилик для украшения\n\nИнструкции:\n1. Разогрейте духовку до 220°C \n2. Нанесите томатный соус на основу для пиццы, затем добавьте соус песто.\n3. Равномерно распределите моцареллу и сыр фета.\n4. Добавьте нарезанный лук, сладкий перец, шампиньоны и кус-кус.\n5. Разложите маслины и кубики авокадо.\n6. Посыпьте пиццу паприкой, орегано и чили хлопьями.\n7. Выпекайте пиццу в духовке 12-15 минут, пока сыр не расплавится, а корочка не станет золотистой.\n8. Украсьте свежим базиликом перед подачей.',
#   'label': 0},
#  {'text': 'Только улыбайся, улыбайся, невесомости поверь и отдайся!☺️',
#   'label': 0},
#  {'text': 'На данный момент действует скидка на платное участие. Цена составляет всего лишь 9900. \nКроме того, участники получат фирменные толстовки РУДН и другие сувениры.\nЕсли у вас остались еще вопросы, рекомендую обратиться в ЛС за подробной консультацией.🤗',
#   'label': 0},
#  {'text': 'https://t.me/fcrudn', 'label': 0},
#  {'text': 'При попытке ввода пароля и логина, появляется ошибка “Authorization error”',
#   'label': 0},
#  {'text': 'Малика, добрый вечер! \n\nПортфолио Вы можете загрузить через личный кабинет, предварительно выбрав направление подготовки, в котором хотите участвовать. В разделе «портфолио» Вы сможете выбрать тип файла и загрузить все документы 🤝\nВ случае технических проблем пишите, пожалуйста, на адрес: org.rudnon@rudn.ru',
#   'label': 0},
#  {'text': 'melike-1@mail.ru', 'label': 0},
#  {'text': 'РУДН объединяет людей 🫶🌏', 'label': 0},
#  {'text': 'Any English webinar available to connect?', 'label': 0},
#  {'text': 'Пишу завтра', 'label': 0},
#  {'text': 'Hehehe it’s me 🫢🫡🫣', 'label': 0},
#  {'text': 'Подготавливать документы для поступления в РУДН 🙏', 'label': 0},
#  {'text': 'Hello, could you tell me where I can see the fee/price accomadation for each type of rooms and blocks?',
#   'label': 0},
#  {'text': "is there something you couldn't find here? https://www.rudn.ru/life/accomodation",
#   'label': 0},
#  {'text': 'melike-1@mail.ru', 'label': 0},
#  {'text': 'Всех приветствую!😀✨\nУльяна, 18 лет. Очень хочу поступить в РУДН на направление «Международные отношения»',
#   'label': 0},
#  {'text': 'В свободной форме просите подтвердить. Указать надо ваш УИН',
#   'label': 0},
#  {'text': 'https://lk.rudn.ru', 'label': 0},
#  {'text': 'Пробовала в разных: в png, jpg - не принимает(', 'label': 0},
#  {'text': 'marusija2005@yandex.ru', 'label': 0},
#  {'text': '@meksushokpp', 'label': 0},
#  {'text': 'Пишу данные и сверху при входе выходит "пользователь не найден"',
#   'label': 0},
#  {'text': 'СПАСИБО, ЧТО ОТВЕЧАЕТЕ НАМ!!!', 'label': 0},
#  {'text': 'https://www.rudn.ru/sveden/files/Obrazec_dogovora_na_obuchenie_po_obrazovatelynym_programmam_vysshego_obrazovaniya(1).docx',
#   'label': 0}]
